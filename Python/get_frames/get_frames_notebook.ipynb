# %%
import cv2
import time
import os

# %%
def get_frames(vid_name, folder_name, ext):
    cam = cv2.VideoCapture(vid_name) 

    currentframe = 0

    while(True): 
        # reading from frame 
        ret,frame = cam.read() 

        if ret: 
            # if video is still left continue creating images 
            name = os.path.join(folder_name,str(currentframe+1).rjust(4,'0') + '.' + ext)
            # print ('Creating...' + name)

            # writing the extracted images 
            cv2.imwrite(name, frame) 

            # increasing counter so that it will 
            # show how many frames are created 
            currentframe += 1
        else: 
            break

    # Release all space and windows once done 
    cam.release() 
    cv2.destroyAllWindows()

# %% [markdown]
# ## Example with only one video

# %%
vid_name = 'Muestra_Video.mp4'
folder_name = 'New_Images' # destination folder
ext = 'jpg'

start_time = time.time()

get_frames(vid_name, folder_name, ext)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 14.487820386886597 seconds ---

# %% [markdown]
# ## Example with multiple videos

# %% [markdown]
# The image folder and the folder with the videos must exist. Folder in Img_folder will be created

# %%
Img_folder = 'Images'
Vid_folder = 'Videos'
ext = 'jpg'

files = sorted(os.listdir(Vid_folder))

# Creates the folder to save the images
for f in files:
    if not os.path.exists(os.path.join(Img_folder, f[0:4])):
        os.makedirs(os.path.join(Img_folder, f[0:4]))

# %% [markdown]
# Gets all the frames from all the videos

# %%
for vid_name in files:
    vid_location = os.path.join(Vid_folder,vid_name)
    frames_location = os.path.join(Img_folder,vid_name[0:4])
    get_frames(vid_location,
               frames_location,
               ext)

# %%
import cv2
import time
import os
import sys
cwd = os.getcwd()
print (cwd)
def get_frames(vid_name, folder_name, ext):
    cam = cv2.VideoCapture(vid_name) 

    currentframe = 0

    while(True): 
        # reading from frame 
        ret,frame = cam.read() 

        if ret: 
            # if video is still left continue creating images 
            name = os.path.join(folder_name,str(currentframe+1).rjust(4,'0') + '.' + ext)
            # print ('Creating...' + name)

            # writing the extracted images 
            cv2.imwrite(name, frame) 

            # increasing counter so that it will 
            # show how many frames are created 
            currentframe += 1
        else: 
            break

    # Release all space and windows once done 
    cam.release() 
    cv2.destroyAllWindows() 
	
Img_folder = '/media/r/DV_SSD_2TB/ADVS_Video_frames'
Vid_folder = '/home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos'
ext = 'jpg'

files = sorted(os.listdir(Vid_folder))
#cuantas letras del nombre se usan para la carpeta
ext_name = 12
# Creates the folder to save the images
for f in files:
    if not os.path.exists(os.path.join(Img_folder, f)):
        os.makedirs(os.path.join(Img_folder, f))

for vid_name in files:
    vid_location = os.path.join(Vid_folder,vid_name)
    frames_location = os.path.join(Img_folder,vid_name)
    get_frames(vid_location,
               frames_location,
               ext)
    print(vid_name)
# Out:
# /home/r/Dropbox/git/Python/get_frames
# 0001Pri_IndWL_MQ_C4.mp4
# 0002Pri_IndWL_MQ_C3.mp4
# 0003Pri_IndWL_MQ_C2.mp4
# 0004Pri_IndWL_MQ_C1.mp4
# 0005Pri_IndLPP_MQ_C4.mp4
# 0006Pri_IndLPP_MQ_C3.mp4
# 0007Pri_IndLPP_MQ_C2.mp4
# 0008Pri_IndLPP_MQ_C1.mp4
# 0009Pri_IndPR_MQ_C4.mp4
# 0010Pri_IndPR_MQ_C3.mp4
# 0011Pri_IndPR_MQ_C2.mp4
# 0012Pri_IndPR_MQ_C1.mp4
# 0013Pri_IndPO_MQ_C4.mp4
# 0014Pri_IndPO_MQ_C3.mp4
# 0015Pri_IndPO_MQ_C2.mp4
# 0016Pri_IndPO_MQ_C1.mp4
# 0017Exp_IndWL_MQ_C4.mp4
# 0018Exp_IndWL_MQ_C3.mp4
# 0019Exp_IndWL_MQ_C2.mp4
# 0020Exp_IndWL_MQ_C1.mp4
# 0021Exp_IndPR_MQ_C4.mp4
# 0022Exp_IndPR_MQ_C3.mp4
# 0023Exp_IndPR_MQ_C2.mp4
# 0024Exp_IndPR_MQ_C1.mp4
# 0025Exp_IndPO_MQ_C4.mp4
# 0026Exp_IndPO_MQ_C3.mp4
# 0027Exp_IndPO_MQ_C2.mp4
# 0028Exp_IndPO_MQ_C1.mp4
# 0029Exp_IndLPP_MQ_C4.mp4
# 0030Exp_IndLPP_MQ_C3.mp4
# 0031Exp_IndLPP_MQ_C2.mp4
# 0032Exp_IndLPP_MQ_C1.mp4
# 0033Exp_IndPW_MQ_C4.mp4
# 0034Exp_IndPW_MQ_C3.mp4
# 0035Exp_IndPW_MQ_C2.mp4
# 0036Exp_IndPW_MQ_C1.mp4
# 0037Exp_IndWL_MQ_C4.mp4
# 0038Exp_IndWL_MQ_C3.mp4
# 0039Exp_IndWL_MQ_C2.mp4
# 0040Exp_IndWL_MQ_C1.mp4
# 0041Exp_IndPR_MQ_C4.mp4
# 0042Exp_IndPR_MQ_C3.mp4
# 0043Exp_IndPR_MQ_C2.mp4
# 0044Exp_IndPR_MQ_C1.mp4
# 0045Exp_IndPO_MQ_C4.mp4
# 0046Exp_IndPO_MQ_C3.mp4
# 0047Exp_IndPO_MQ_C2.mp4
# 0048Exp_IndPO_MQ_C1.mp4
# 0049Exp_IndLPP_MQ_C4.mp4
# 0050Exp_IndLPP_MQ_C3.mp4
# 0051Pri_IndPW_C1.mp4
# 0052Pri_IndPW_C2.mp4
# 0053Pri_IndPW_C3.mp4
# 0054Pri_IndPW_C4.mp4
# 0055Exp_IndPW_HQ_C1.mp4
# 0056Exp_IndPW_HQ_C2.mp4
# 0057Exp_IndPW_HQ_C3.mp4
# 0058Exp_IndPW_HQ_C4.mp4
# 0059Exp_IndPW_MQ_C1.mp4
# 0060Exp_IndPW_MQ_C2.mp4
# 0061Exp_IndPW_MQ_C3.mp4
# 0062Exp_IndPW_MQ_C4.mp4
# 0063Exp_IndPW_LQ_C1.mp4
# 0064Exp_IndPW_LQ_C2.mp4
# 0065Exp_IndPW_LQ_C3.mp4
# 0066Exp_IndPW_LQ_C4.mp4
# 0067Exp_IndPW_HQ_C1.mp4
# 0068Exp_IndPW_HQ_C2.mp4
# 0069Exp_IndPW_HQ_C3.mp4
# 0070Exp_IndPW_HQ_C4.mp4
# 0071Exp_IndPW_MQ_C1.mp4
# 0072Exp_IndPW_MQ_C2.mp4
# 0073Exp_IndPW_MQ_C3.mp4
# 0074Exp_IndPW_MQ_C4.mp4
# 0075Exp_IndPW_LQ_C1.mp4
# 0076Exp_IndPW_LQ_C2.mp4
# 0077Exp_IndPW_LQ_C3.mp4
# 0078Exp_IndPW_LQ_C4.mp4
# 0079Exp_IndPW_HQ_C1.mp4
# 0080Exp_IndPW_HQ_C2.mp4
# 0081Exp_IndPW_HQ_C3.mp4
# 0082Exp_IndPW_HQ_C4.mp4
# 0083Exp_IndPW_MQ_C1.mp4
# 0084Exp_IndPW_MQ_C2.mp4
# 0085Exp_IndPW_MQ_C3.mp4
# 0086Exp_IndPW_MQ_C4.mp4
# 0087Exp_IndPW_LQ_C1.mp4
# 0088Exp_IndPW_LQ_C2.mp4
# 0089Exp_IndPW_LQ_C3.mp4
# 0090Exp_IndPW_LQ_C4.mp4
# 0091Fo_IndPW_HQ_C1.mp4
# 0092Fo_IndPW_HQ_C2.mp4
# 0093Fo_IndPW_HQ_C3.mp4
# 0094Fo_IndPW_HQ_C4.mp4
# 0095Fo_IndPW_MQ_C1.mp4
# 0096Fo_IndPW_MQ_C2.mp4
# 0097Fo_IndPW_MQ_C3.mp4
# 0098Fo_IndPW_MQ_C4.mp4
# 0099Fo_IndPW_LQ_C1.mp4
# 0100Fo_IndPW_LQ_C2.mp4
# 0101Fo_IndPW_LQ_C3.mp4
# 0102Fo_IndPW_LQ_C4.mp4
# 0103Fo_IndPW_HQ_C1.mp4
# 0104Fo_IndPW_HQ_C2.mp4
# 0105Fo_IndPW_HQ_C3.mp4
# 0106Fo_IndPW_HQ_C4.mp4
# 0107Fo_IndPW_MQ_C1.mp4
# 0108Fo_IndPW_MQ_C2.mp4
# 0109Fo_IndPW_MQ_C3.mp4
# 0110Fo_IndPW_MQ_C4.mp4
# 0111Fo_IndPW_LQ_C1.mp4
# 0112Fo_IndPW_LQ_C2.mp4
# 0113Fo_IndPW_LQ_C3.mp4
# 0114Fo_IndPW_LQ_C4.mp4
# 0115Fo_IndPW_HQ_C1.mp4
# 0116Fo_IndPW_HQ_C2.mp4
# 0117Fo_IndPW_HQ_C3.mp4
# 0118Fo_IndPW_HQ_C4.mp4
# 0119Fo_IndPW_MQ_C1.mp4
# 0120Fo_IndPW_MQ_C2.mp4
# 0121Fo_IndPW_MQ_C3.mp4
# 0122Fo_IndPW_MQ_C4.mp4
# 0123Fo_IndPW_LQ_C1.mp4
# 0124Fo_IndPW_LQ_C2.mp4
# 0125Fo_IndPW_LQ_C3.mp4
# 0126Fo_IndPW_LQ_C4.mp4
# 0127ExFo_IndPW_HQ_C1.mp4
# 0128ExFo_IndPW_HQ_C2.mp4
# 0129ExFo_IndPW_HQ_C3.mp4
# 0130ExFo_IndPW_HQ_C4.mp4
# 0131ExFo_IndPW_MQ_C1.mp4
# 0132ExFo_IndPW_MQ_C2.mp4
# 0133ExFo_IndPW_MQ_C3.mp4
# 0134ExFo_IndPW_MQ_C4.mp4
# 0135ExFo_IndPW_LQ_C1.mp4
# 0136ExFo_IndPW_LQ_C2.mp4
# 0137ExFo_IndPW_LQ_C3.mp4
# 0138ExFo_IndPW_LQ_C4.mp4
# 0139ExFo_IndPW_HQ_C1.mp4
# 0140ExFo_IndPW_HQ_C2.mp4
# 0141ExFo_IndPW_HQ_C3.mp4
# 0142ExFo_IndPW_HQ_C4.mp4
# 0143ExFo_IndPW_MQ_C1.mp4
# 0144ExFo_IndPW_MQ_C2.mp4
# 0145ExFo_IndPW_MQ_C3.mp4
# 0146ExFo_IndPW_MQ_C4.mp4
# 0147ExFo_IndPW_LQ_C1.mp4
# 0148ExFo_IndPW_LQ_C2.mp4
# 0149ExFo_IndPW_LQ_C3.mp4
# 0150ExFo_IndPW_LQ_C4.mp4
# 0151ExFo_IndPW_HQ_C1.mp4
# 0152ExFo_IndPW_HQ_C2.mp4
# 0153ExFo_IndPW_HQ_C3.mp4
# 0154ExFo_IndPW_HQ_C4.mp4
# 0155ExFo_IndPW_MQ_C1.mp4
# 0156ExFo_IndPW_MQ_C2.mp4
# 0157ExFo_IndPW_MQ_C3.mp4
# 0158ExFo_IndPW_MQ_C4.mp4
# 0159ExFo_IndPW_LQ_C1.mp4
# 0160ExFo_IndPW_LQ_C2.mp4
# 0161ExFo_IndPW_LQ_C3.mp4
# 0162ExFo_IndPW_LQ_C4.mp4
# 0163Pri_IndLPP_C1.mp4
# 0164Pri_IndLPP_C2.mp4
# 0165Pri_IndLPP_C4.mp4
# 0166Exp_IndLPP_HQ_C1.mp4
# 0167Exp_IndLPP_HQ_C2.mp4
# 0168Exp_IndLPP_HQ_C3.mp4
# 0169Exp_IndLPP_HQ_C4.mp4
# 0170Exp_IndLPP_MQ_C1.mp4
# 0171Exp_IndLPP_MQ_C2.mp4
# 0172Exp_IndLPP_MQ_C3.mp4
# 0173Exp_IndLPP_MQ_C4.mp4
# 0174Exp_IndLPP_LQ_C1.mp4
# 0175Exp_IndLPP_LQ_C2.mp4
# 0176Exp_IndLPP_LQ_C3.mp4
# 0177Exp_IndLPP_LQ_C4.mp4
# 0178Exp_IndLPP_HQ_C1.mp4
# 0179Exp_IndLPP_HQ_C2.mp4
# 0180Exp_IndLPP_HQ_C3.mp4
# 0181Exp_IndLPP_HQ_C4.mp4
# 0182Exp_IndLPP_MQ_C1.mp4
# 0183Exp_IndLPP_MQ_C2.mp4
# 0184Exp_IndLPP_MQ_C3.mp4
# 0185Exp_IndLPP_MQ_C4.mp4
# 0186Exp_IndLPP_LQ_C1.mp4
# 0187Exp_IndLPP_LQ_C2.mp4
# 0188Exp_IndLPP_LQ_C3.mp4
# 0189Exp_IndLPP_LQ_C4.mp4
# 0190Exp_IndLPP_HQ_C1.mp4
# 0191Exp_IndLPP_HQ_C2.mp4
# 0192Exp_IndLPP_HQ_C3.mp4
# 0193Exp_IndLPP_HQ_C4.mp4
# 0194Exp_IndLPP_MQ_C1.mp4
# 0195Exp_IndLPP_MQ_C2.mp4
# 0196Exp_IndLPP_MQ_C3.mp4
# 0197Exp_IndLPP_MQ_C4.mp4
# 0198Exp_IndLPP_LQ_C1.mp4
# 0199Exp_IndLPP_LQ_C2.mp4
# 0200Exp_IndLPP_LQ_C3.mp4
# 0201Exp_IndLPP_LQ_C4.mp4
# 0202Fo_IndLPP_HQ_C1.mp4
# 0203Fo_IndLPP_HQ_C2.mp4
# 0204Fo_IndLPP_HQ_C3.mp4
# 0205Fo_IndLPP_HQ_C4.mp4
# 0206Fo_IndLPP_MQ_C1.mp4
# 0207Fo_IndLPP_MQ_C2.mp4
# 0208Fo_IndLPP_MQ_C3.mp4
# 0209Fo_IndLPP_MQ_C4.mp4
# 0210Fo_IndLPP_LQ_C1.mp4
# 0211Fo_IndLPP_LQ_C2.mp4
# 0212Fo_IndLPP_LQ_C3.mp4
# 0213Fo_IndLPP_LQ_C4.mp4
# 0214Fo_IndLPP_HQ_C1.mp4
# 0215Fo_IndLPP_HQ_C2.mp4
# 0216Fo_IndLPP_HQ_C3.mp4
# 0217Fo_IndLPP_HQ_C4.mp4
# 0218Fo_IndLPP_MQ_C1.mp4
# 0219Fo_IndLPP_MQ_C2.mp4
# 0220Fo_IndLPP_MQ_C3.mp4
# 0221Fo_IndLPP_MQ_C4.mp4
# 0222Fo_IndLPP_LQ_C1.mp4
# 0223Fo_IndLPP_LQ_C2.mp4
# 0224Fo_IndLPP_LQ_C3.mp4
# 0225Fo_IndLPP_LQ_C4.mp4
# 0226Fo_IndLPP_HQ_C1.mp4
# 0227Fo_IndLPP_HQ_C2.mp4
# 0228Fo_IndLPP_HQ_C3.mp4
# 0229Fo_IndLPP_HQ_C4.mp4
# 0230Fo_IndLPP_MQ_C1.mp4
# 0231Fo_IndLPP_MQ_C2.mp4
# 0232Fo_IndLPP_MQ_C3.mp4
# 0233Fo_IndLPP_MQ_C4.mp4
# 0234Fo_IndLPP_LQ_C1.mp4
# 0235Fo_IndLPP_LQ_C2.mp4
# 0236Fo_IndLPP_LQ_C3.mp4
# 0237Fo_IndLPP_LQ_C4.mp4
# 0238ExFo_IndLPP_HQ_C1.mp4
# 0239ExFo_IndLPP_HQ_C2.mp4
# 0240ExFo_IndLPP_HQ_C3.mp4
# 0241ExFo_IndLPP_HQ_C4.mp4
# 0242ExFo_IndLPP_MQ_C1.mp4
# 0243ExFo_IndLPP_MQ_C2.mp4
# 0244ExFo_IndLPP_MQ_C3.mp4
# 0245ExFo_IndLPP_MQ_C4.mp4
# 0246ExFo_IndLPP_LQ_C1.mp4
# 0247ExFo_IndLPP_LQ_C2.mp4
# 0248ExFo_IndLPP_LQ_C3.mp4
# 0249ExFo_IndLPP_LQ_C4.mp4
# 0250ExFo_IndLPP_HQ_C1.mp4
# 0251ExFo_IndLPP_HQ_C2.mp4
# 0252ExFo_IndLPP_HQ_C3.mp4
# 0253ExFo_IndLPP_HQ_C4.mp4
# 0254ExFo_IndLPP_MQ_C1.mp4
# 0255ExFo_IndLPP_MQ_C2.mp4
# 0256ExFo_IndLPP_MQ_C3.mp4
# 0257ExFo_IndLPP_MQ_C4.mp4
# 0258ExFo_IndLPP_LQ_C1.mp4
# 0259ExFo_IndLPP_LQ_C2.mp4
# 0260ExFo_IndLPP_LQ_C3.mp4
# 0261ExFo_IndLPP_LQ_C4.mp4
# 0262ExFo_IndLPP_HQ_C1.mp4
# 0263ExFo_IndLPP_HQ_C2.mp4
# 0264ExFo_IndLPP_HQ_C3.mp4
# 0265ExFo_IndLPP_HQ_C4.mp4
# 0266ExFo_IndLPP_MQ_C1.mp4
# 0267ExFo_IndLPP_MQ_C2.mp4
# 0268ExFo_IndLPP_MQ_C3.mp4
# 0269ExFo_IndLPP_MQ_C4.mp4
# 0270ExFo_IndLPP_LQ_C1.mp4
# 0271ExFo_IndLPP_LQ_C2.mp4
# 0272ExFo_IndLPP_LQ_C3.mp4
# 0273ExFo_IndLPP_LQ_C4.mp4
# 0274Pri_IndWL_C1.mp4
# 0275Pri_IndWL_C2.mp4
# 0276Pri_IndWL_C3.mp4
# 0277Pri_IndWL_C4.mp4
# 0278Exp_IndWL_HQ_C1.mp4
# 0279Exp_IndWL_HQ_C2.mp4
# 0280Exp_IndWL_HQ_C3.mp4
# 0281Exp_IndWL_HQ_C4.mp4
# 0282Exp_IndWL_MQ_C1.mp4
# 0283Exp_IndWL_MQ_C2.mp4
# 0284Exp_IndWL_MQ_C3.mp4
# 0285Exp_IndWL_MQ_C4.mp4
# 0286Exp_IndWL_LQ_C1.mp4
# 0287Exp_IndWL_LQ_C2.mp4
# 0288Exp_IndWL_LQ_C3.mp4
# 0289Exp_IndWL_LQ_C4.mp4
# 0290Exp_IndWL_HQ_C1.mp4
# 0291Exp_IndWL_HQ_C2.mp4
# 0292Exp_IndWL_HQ_C3.mp4
# 0293Exp_IndWL_HQ_C4.mp4
# 0294Exp_IndWL_MQ_C1.mp4
# 0295Exp_IndWL_MQ_C2.mp4
# 0296Exp_IndWL_MQ_C3.mp4
# 0297Exp_IndWL_MQ_C4.mp4
# 0298Exp_IndWL_LQ_C1.mp4
# 0299Exp_IndWL_LQ_C2.mp4
# 0300Exp_IndWL_LQ_C3.mp4
# 0301Exp_IndWL_LQ_C4.mp4
# 0302Exp_IndWL_HQ_C1.mp4
# 0303Exp_IndWL_HQ_C2.mp4
# 0304Exp_IndWL_HQ_C3.mp4
# 0305Exp_IndWL_HQ_C4.mp4
# 0306Exp_IndWL_MQ_C1.mp4
# 0307Exp_IndWL_MQ_C2.mp4
# 0308Exp_IndWL_MQ_C3.mp4
# 0309Exp_IndWL_MQ_C4.mp4
# 0310Exp_IndWL_LQ_C1.mp4
# 0311Exp_IndWL_LQ_C2.mp4
# 0312Exp_IndWL_LQ_C3.mp4
# 0313Exp_IndWL_LQ_C4.mp4
# 0314Fo_IndWL_HQ_C1.mp4
# 0315Fo_IndWL_HQ_C2.mp4
# 0316Fo_IndWL_HQ_C3.mp4
# 0317Fo_IndWL_HQ_C4.mp4
# 0318Fo_IndWL_MQ_C1.mp4
# 0319Fo_IndWL_MQ_C2.mp4
# 0320Fo_IndWL_MQ_C3.mp4
# 0321Fo_IndWL_MQ_C4.mp4
# 0322Fo_IndWL_LQ_C1.mp4
# 0323Fo_IndWL_LQ_C2.mp4
# 0324Fo_IndWL_LQ_C3.mp4
# 0325Fo_IndWL_LQ_C4.mp4
# 0326Fo_IndWL_HQ_C1.mp4
# 0327Fo_IndWL_HQ_C2.mp4
# 0328Fo_IndWL_HQ_C3.mp4
# 0329Fo_IndWL_HQ_C4.mp4
# 0330Fo_IndWL_MQ_C1.mp4
# 0331Fo_IndWL_MQ_C2.mp4
# 0332Fo_IndWL_MQ_C3.mp4
# 0333Fo_IndWL_MQ_C4.mp4
# 0334Fo_IndWL_LQ_C1.mp4
# 0335Fo_IndWL_LQ_C2.mp4
# 0336Fo_IndWL_LQ_C3.mp4
# 0337Fo_IndWL_LQ_C4.mp4
# 0338Fo_IndWL_HQ_C1.mp4
# 0339Fo_IndWL_HQ_C2.mp4
# 0340Fo_IndWL_HQ_C3.mp4
# 0341Fo_IndWL_HQ_C4.mp4
# 0342Fo_IndWL_MQ_C1.mp4
# 0343Fo_IndWL_MQ_C2.mp4
# 0344Fo_IndWL_MQ_C3.mp4
# 0345Fo_IndWL_MQ_C4.mp4
# 0346Fo_IndWL_LQ_C1.mp4
# 0347Fo_IndWL_LQ_C2.mp4
# 0348Fo_IndWL_LQ_C3.mp4
# 0349Fo_IndWL_LQ_C4.mp4
# 0350ExFo_IndWL_HQ_C1.mp4
# 0351ExFo_IndWL_HQ_C2.mp4
# 0352ExFo_IndWL_HQ_C3.mp4
# 0353ExFo_IndWL_HQ_C4.mp4
# 0354ExFo_IndWL_MQ_C1.mp4
# 0355ExFo_IndWL_MQ_C2.mp4
# 0356ExFo_IndWL_MQ_C3.mp4
# 0357ExFo_IndWL_MQ_C4.mp4
# 0358ExFo_IndWL_LQ_C1.mp4
# 0359ExFo_IndWL_LQ_C2.mp4
# 0360ExFo_IndWL_LQ_C3.mp4
# 0361ExFo_IndWL_LQ_C4.mp4
# 0362ExFo_IndWL_HQ_C1.mp4
# 0363ExFo_IndWL_HQ_C2.mp4
# 0364ExFo_IndWL_HQ_C3.mp4
# 0365ExFo_IndWL_HQ_C4.mp4
# 0366ExFo_IndWL_MQ_C1.mp4
# 0367ExFo_IndWL_MQ_C2.mp4
# 0368ExFo_IndWL_MQ_C3.mp4
# 0369ExFo_IndWL_MQ_C4.mp4
# 0370ExFo_IndWL_LQ_C1.mp4
# 0371ExFo_IndWL_LQ_C2.mp4
# 0372ExFo_IndWL_LQ_C3.mp4
# 0373ExFo_IndWL_LQ_C4.mp4
# 0374Pri_IndPR_C1.mp4
# 0375Pri_IndPR_C2.mp4
# 0376Pri_IndPR_C4.mp4
# 0377Exp_IndPR_HQ_C1.mp4
# 0378Exp_IndPR_HQ_C2.mp4
# 0379Exp_IndPR_HQ_C3.mp4
# 0380Exp_IndPR_HQ_C4.mp4
# 0381Exp_IndPR_MQ_C1.mp4
# 0382Exp_IndPR_MQ_C2.mp4
# 0383Exp_IndPR_MQ_C3.mp4
# 0384Exp_IndPR_MQ_C4.mp4
# 0385Exp_IndPR_LQ_C1.mp4
# 0386Exp_IndPR_LQ_C2.mp4
# 0387Exp_IndPR_LQ_C3.mp4
# 0388Exp_IndPR_LQ_C4.mp4
# 0389Exp_IndPR_HQ_C1.mp4
# 0390Exp_IndPR_HQ_C2.mp4
# 0391Exp_IndPR_HQ_C3.mp4
# 0392Exp_IndPR_HQ_C4.mp4
# 0393Exp_IndPR_MQ_C1.mp4
# 0394Exp_IndPR_MQ_C2.mp4
# 0395Exp_IndPR_MQ_C3.mp4
# 0396Exp_IndPR_MQ_C4.mp4
# 0397Exp_IndPR_LQ_C1.mp4
# 0398Exp_IndPR_LQ_C2.mp4
# 0399Exp_IndPR_LQ_C3.mp4
# 0400Exp_IndPR_LQ_C4.mp4
# 0401Exp_IndPR_HQ_C1.mp4
# 0402Exp_IndPR_HQ_C2.mp4
# 0403Exp_IndPR_HQ_C3.mp4
# 0404Exp_IndPR_HQ_C4.mp4
# 0405Exp_IndPR_MQ_C1.mp4
# 0406Exp_IndPR_MQ_C2.mp4
# 0407Exp_IndPR_MQ_C3.mp4
# 0408Exp_IndPR_MQ_C4.mp4
# 0409Exp_IndPR_LQ_C1.mp4
# 0410Exp_IndPR_LQ_C2.mp4
# 0411Exp_IndPR_LQ_C3.mp4
# 0412Exp_IndPR_LQ_C4.mp4
# 0413Fo_IndPR_HQ_C1.mp4
# 0414Fo_IndPR_HQ_C2.mp4
# 0415Fo_IndPR_HQ_C4.mp4
# 0416Fo_IndPR_MQ_C1.mp4
# 0417Fo_IndPR_MQ_C2.mp4
# 0418Fo_IndPR_MQ_C4.mp4
# 0419Fo_IndPR_LQ_C1.mp4
# 0420Fo_IndPR_LQ_C2.mp4
# 0421Fo_IndPR_LQ_C4.mp4
# 0422Fo_IndPR_HQ_C1.mp4
# 0423Fo_IndPR_HQ_C2.mp4
# 0424Fo_IndPR_HQ_C3.mp4
# 0425Fo_IndPR_HQ_C4.mp4
# 0426Fo_IndPR_MQ_C1.mp4
# 0427Fo_IndPR_MQ_C2.mp4
# 0428Fo_IndPR_MQ_C3.mp4
# 0429Fo_IndPR_MQ_C4.mp4
# 0430Fo_IndPR_LQ_C1.mp4
# 0431Fo_IndPR_LQ_C2.mp4
# 0432Fo_IndPR_LQ_C3.mp4
# 0433Fo_IndPR_LQ_C4.mp4
# 0434Fo_IndPR_HQ_C1.mp4
# 0435Fo_IndPR_HQ_C2.mp4
# 0436Fo_IndPR_HQ_C3.mp4
# 0437Fo_IndPR_HQ_C4.mp4
# 0438Fo_IndPR_MQ_C1.mp4
# 0439Fo_IndPR_MQ_C2.mp4
# 0440Fo_IndPR_MQ_C3.mp4
# 0441Fo_IndPR_MQ_C4.mp4
# 0442Fo_IndPR_LQ_C1.mp4
# 0443Fo_IndPR_LQ_C2.mp4
# 0444Fo_IndPR_LQ_C3.mp4
# 0445Fo_IndPR_LQ_C4.mp4
# 0446ExFo_IndPR_HQ_C1.mp4
# 0447ExFo_IndPR_HQ_C2.mp4
# 0448ExFo_IndPR_HQ_C3.mp4
# 0449ExFo_IndPR_HQ_C4.mp4
# 0450ExFo_IndPR_MQ_C1.mp4
# 0451ExFo_IndPR_MQ_C2.mp4
# 0452ExFo_IndPR_MQ_C3.mp4
# 0453ExFo_IndPR_MQ_C4.mp4
# 0454ExFo_IndPR_LQ_C1.mp4
# 0455ExFo_IndPR_LQ_C2.mp4
# 0456ExFo_IndPR_LQ_C3.mp4
# 0457ExFo_IndPR_LQ_C4.mp4
# 0458ExFo_IndPR_HQ_C1.mp4
# 0459ExFo_IndPR_HQ_C2.mp4
# 0460ExFo_IndPR_HQ_C3.mp4
# 0461ExFo_IndPR_HQ_C4.mp4
# 0462ExFo_IndPR_MQ_C1.mp4
# 0463ExFo_IndPR_MQ_C2.mp4
# 0464ExFo_IndPR_MQ_C3.mp4
# 0465ExFo_IndPR_MQ_C4.mp4
# 0466ExFo_IndPR_LQ_C1.mp4
# 0467ExFo_IndPR_LQ_C2.mp4
# 0468ExFo_IndPR_LQ_C3.mp4
# 0469ExFo_IndPR_LQ_C4.mp4
# 0470Pri_IndPO_C1.mp4
# 0471Pri_IndPO_C2.mp4
# 0472Pri_IndPO_C4.mp4
# 0473Exp_IndPO_HQ_C1.mp4
# 0474Exp_IndPO_HQ_C2.mp4
# 0475Exp_IndPO_HQ_C3.mp4
# 0476Exp_IndPO_HQ_C4.mp4
# 0477Exp_IndPO_MQ_C1.mp4
# 0478Exp_IndPO_MQ_C2.mp4
# 0479Exp_IndPO_MQ_C3.mp4
# 0480Exp_IndPO_MQ_C4.mp4
# 0481Exp_IndPO_LQ_C1.mp4
# 0482Exp_IndPO_LQ_C2.mp4
# 0483Exp_IndPO_LQ_C3.mp4
# 0484Exp_IndPO_LQ_C4.mp4
# 0485Exp_IndPO_HQ_C1.mp4
# 0486Exp_IndPO_HQ_C2.mp4
# 0487Exp_IndPO_HQ_C3.mp4
# 0488Exp_IndPO_HQ_C4.mp4
# 0489Exp_IndPO_MQ_C1.mp4
# 0490Exp_IndPO_MQ_C2.mp4
# 0491Exp_IndPO_MQ_C3.mp4
# 0492Exp_IndPO_MQ_C4.mp4
# 0493Exp_IndPO_LQ_C1.mp4
# 0494Exp_IndPO_LQ_C2.mp4
# 0495Exp_IndPO_LQ_C3.mp4
# 0496Exp_IndPO_LQ_C4.mp4
# 0497Exp_IndPO_HQ_C1.mp4
# 0498Exp_IndPO_HQ_C2.mp4
# 0499Exp_IndPO_HQ_C3.mp4
# 0500Exp_IndPO_HQ_C4.mp4
# 0501Exp_IndPO_MQ_C1.mp4
# 0502Exp_IndPO_MQ_C2.mp4
# 0503Exp_IndPO_MQ_C3.mp4
# 0504Exp_IndPO_MQ_C4.mp4
# 0505Exp_IndPO_LQ_C1.mp4
# 0506Exp_IndPO_LQ_C2.mp4
# 0507Exp_IndPO_LQ_C3.mp4
# 0508Exp_IndPO_LQ_C4.mp4
# 0509Fo_IndPO_HQ_C1.mp4
# 0510Fo_IndPO_HQ_C2.mp4
# 0511Fo_IndPO_HQ_C3.mp4
# 0512Fo_IndPO_HQ_C4.mp4
# 0513Fo_IndPO_MQ_C1.mp4
# 0514Fo_IndPO_MQ_C2.mp4
# 0515Fo_IndPO_MQ_C3.mp4
# 0516Fo_IndPO_MQ_C4.mp4
# 0517Fo_IndPO_LQ_C1.mp4
# 0518Fo_IndPO_LQ_C2.mp4
# 0519Fo_IndPO_LQ_C3.mp4
# 0520Fo_IndPO_LQ_C4.mp4
# 0521Fo_IndPO_HQ_C1.mp4
# 0522Fo_IndPO_HQ_C2.mp4
# 0523Fo_IndPO_HQ_C3.mp4
# 0524Fo_IndPO_HQ_C4.mp4
# 0525Fo_IndPO_MQ_C1.mp4
# 0526Fo_IndPO_MQ_C2.mp4
# 0527Fo_IndPO_MQ_C3.mp4
# 0528Fo_IndPO_MQ_C4.mp4
# 0529Fo_IndPO_LQ_C1.mp4
# 0530Fo_IndPO_LQ_C2.mp4
# 0531Fo_IndPO_LQ_C3.mp4
# 0532Fo_IndPO_LQ_C4.mp4
# 0533Fo_IndPO_HQ_C1.mp4
# 0534Fo_IndPO_HQ_C2.mp4
# 0535Fo_IndPO_HQ_C3.mp4
# 0536Fo_IndPO_HQ_C4.mp4
# 0537Fo_IndPO_MQ_C1.mp4
# 0538Fo_IndPO_MQ_C2.mp4
# 0539Fo_IndPO_MQ_C3.mp4
# 0540Fo_IndPO_MQ_C4.mp4
# 0541Fo_IndPO_LQ_C1.mp4
# 0542Fo_IndPO_LQ_C2.mp4
# 0543Fo_IndPO_LQ_C3.mp4
# 0544Fo_IndPO_LQ_C4.mp4
# 0545ExFo_IndPO_HQ_C1.mp4
# 0546ExFo_IndPO_HQ_C2.mp4
# 0547ExFo_IndPO_HQ_C3.mp4
# 0548ExFo_IndPO_HQ_C4.mp4
# 0549ExFo_IndPO_MQ_C1.mp4
# 0550ExFo_IndPO_MQ_C2.mp4
# 0551ExFo_IndPO_MQ_C3.mp4
# 0552ExFo_IndPO_MQ_C4.mp4
# 0553ExFo_IndPO_LQ_C1.mp4
# 0554ExFo_IndPO_LQ_C2.mp4
# 0555ExFo_IndPO_LQ_C3.mp4
# 0556ExFo_IndPO_LQ_C4.mp4
# 0557ExFo_IndPO_HQ_C1.mp4
# 0558ExFo_IndPO_HQ_C2.mp4
# 0559ExFo_IndPO_HQ_C3.mp4
# 0560ExFo_IndPO_HQ_C4.mp4
# 0561ExFo_IndPO_MQ_C1.mp4
# 0562ExFo_IndPO_MQ_C2.mp4
# 0563ExFo_IndPO_MQ_C3.mp4
# 0564ExFo_IndPO_MQ_C4.mp4
# 0565ExFo_IndPO_LQ_C1.mp4
# 0566ExFo_IndPO_LQ_C2.mp4
# 0567ExFo_IndPO_LQ_C3.mp4
# 0568ExFo_IndPO_LQ_C4.mp4
# 0569ExFo_IndPO_HQ_C1.mp4
# 0570ExFo_IndPO_HQ_C2.mp4
# 0571ExFo_IndPO_HQ_C3.mp4
# 0572ExFo_IndPO_HQ_C4.mp4
# 0573ExFo_IndPO_MQ_C1.mp4
# 0574ExFo_IndPO_MQ_C2.mp4
# 0575ExFo_IndPO_MQ_C3.mp4
# 0576ExFo_IndPO_MQ_C4.mp4
# 0577ExFo_IndPO_LQ_C1.mp4
# 0578ExFo_IndPO_LQ_C2.mp4
# 0579ExFo_IndPO_LQ_C3.mp4
# 0580ExFo_IndPO_LQ_C4.mp4
# 0581Pri_IndPPP_C1.mp4
# 0582Pri_IndPPP_C2.mp4
# 0583Pri_IndPPP_C4.mp4
# 0584Exp_IndPPP_HQ_C1.mp4
# 0585Exp_IndPPP_HQ_C2.mp4
# 0586Exp_IndPPP_HQ_C3.mp4
# 0587Exp_IndPPP_HQ_C4.mp4
# 0588Exp_IndPPP_MQ_C1.mp4
# 0589Exp_IndPPP_MQ_C2.mp4
# 0590Exp_IndPPP_MQ_C3.mp4
# 0591Exp_IndPPP_MQ_C4.mp4
# 0592Exp_IndPPP_LQ_C1.mp4
# 0593Exp_IndPPP_LQ_C2.mp4
# 0594Exp_IndPPP_LQ_C3.mp4
# 0595Exp_IndPPP_LQ_C4.mp4
# 0596Exp_IndPPP_HQ_C1.mp4
# 0597Exp_IndPPP_HQ_C2.mp4
# 0598Exp_IndPPP_HQ_C3.mp4
# 0599Exp_IndPPP_HQ_C4.mp4
# 0600Exp_IndPPP_MQ_C1.mp4
# 0601Exp_IndPPP_MQ_C2.mp4
# 0602Exp_IndPPP_MQ_C3.mp4
# 0603Exp_IndPPP_MQ_C4.mp4
# 0604Exp_IndPPP_LQ_C1.mp4
# 0605Exp_IndPPP_LQ_C2.mp4
# 0606Exp_IndPPP_LQ_C3.mp4
# 0607Exp_IndPPP_LQ_C4.mp4
# 0608Exp_IndPPP_HQ_C1.mp4
# 0609Exp_IndPPP_HQ_C2.mp4
# 0610Exp_IndPPP_HQ_C3.mp4
# 0611Exp_IndPPP_HQ_C4.mp4
# 0612Exp_IndPPP_MQ_C1.mp4
# 0613Exp_IndPPP_MQ_C2.mp4
# 0614Exp_IndPPP_MQ_C3.mp4
# 0615Exp_IndPPP_MQ_C4.mp4
# 0616Exp_IndPPP_LQ_C1.mp4
# 0617Exp_IndPPP_LQ_C2.mp4
# 0618Exp_IndPPP_LQ_C3.mp4
# 0619Exp_IndPPP_LQ_C4.mp4
# 0620Fo_IndPPP_HQ_C1.mp4
# 0621Fo_IndPPP_HQ_C2.mp4
# 0622Fo_IndPPP_HQ_C4.mp4
# 0623Fo_IndPPP_MQ_C1.mp4
# 0624Fo_IndPPP_MQ_C2.mp4
# 0625Fo_IndPPP_MQ_C4.mp4
# 0626Fo_IndPPP_LQ_C1.mp4
# 0627Fo_IndPPP_LQ_C2.mp4
# 0628Fo_IndPPP_LQ_C4.mp4
# 0629Fo_IndPPP_HQ_C1.mp4
# 0630Fo_IndPPP_HQ_C2.mp4
# 0631Fo_IndPPP_HQ_C3.mp4
# 0632Fo_IndPPP_HQ_C4.mp4
# 0633Fo_IndPPP_MQ_C1.mp4
# 0634Fo_IndPPP_MQ_C2.mp4
# 0635Fo_IndPPP_MQ_C3.mp4
# 0636Fo_IndPPP_MQ_C4.mp4
# 0637Fo_IndPPP_LQ_C1.mp4
# 0638Fo_IndPPP_LQ_C2.mp4
# 0639Fo_IndPPP_LQ_C3.mp4
# 0640Fo_IndPPP_LQ_C4.mp4
# 0641Fo_IndPPP_HQ_C1.mp4
# 0642Fo_IndPPP_HQ_C2.mp4
# 0643Fo_IndPPP_HQ_C3.mp4
# 0644Fo_IndPPP_HQ_C4.mp4
# 0645Fo_IndPPP_MQ_C1.mp4
# 0646Fo_IndPPP_MQ_C2.mp4
# 0647Fo_IndPPP_MQ_C3.mp4
# 0648Fo_IndPPP_MQ_C4.mp4
# 0649Fo_IndPPP_LQ_C1.mp4
# 0650Fo_IndPPP_LQ_C2.mp4
# 0651Fo_IndPPP_LQ_C3.mp4
# 0652Fo_IndPPP_LQ_C4.mp4
# 0653ExFo_IndPPP_HQ_C1.mp4
# 0654ExFo_IndPPP_HQ_C2.mp4
# 0655ExFo_IndPPP_HQ_C3.mp4
# 0656ExFo_IndPPP_HQ_C4.mp4
# 0657ExFo_IndPPP_MQ_C1.mp4
# 0658ExFo_IndPPP_MQ_C2.mp4
# 0659ExFo_IndPPP_MQ_C3.mp4
# 0660ExFo_IndPPP_MQ_C4.mp4
# 0661ExFo_IndPPP_LQ_C1.mp4
# 0662ExFo_IndPPP_LQ_C2.mp4
# 0663ExFo_IndPPP_LQ_C3.mp4
# 0664ExFo_IndPPP_LQ_C4.mp4
# 0665ExFo_IndPPP_HQ_C1.mp4
# 0666ExFo_IndPPP_HQ_C2.mp4
# 0667ExFo_IndPPP_HQ_C3.mp4
# 0668ExFo_IndPPP_HQ_C4.mp4
# 0669ExFo_IndPPP_MQ_C1.mp4
# 0670ExFo_IndPPP_MQ_C2.mp4
# 0671ExFo_IndPPP_MQ_C3.mp4
# 0672ExFo_IndPPP_MQ_C4.mp4
# 0673ExFo_IndPPP_LQ_C1.mp4
# 0674ExFo_IndPPP_LQ_C2.mp4
# 0675ExFo_IndPPP_LQ_C3.mp4
# 0676ExFo_IndPPP_LQ_C4.mp4
# 0677ExFo_IndPPP_HQ_C1.mp4
# 0678ExFo_IndPPP_HQ_C2.mp4
# 0679ExFo_IndPPP_HQ_C3.mp4
# 0680ExFo_IndPPP_HQ_C4.mp4
# 0681ExFo_IndPPP_MQ_C1.mp4
# 0682ExFo_IndPPP_MQ_C2.mp4
# 0683ExFo_IndPPP_MQ_C3.mp4
# 0684ExFo_IndPPP_MQ_C4.mp4
# 0685ExFo_IndPPP_LQ_C1.mp4
# 0686ExFo_IndPPP_LQ_C2.mp4
# 0687ExFo_IndPPP_LQ_C3.mp4
# 0688ExFo_IndPPP_LQ_C4.mp4
# 0689Pri_IndRK_C1.mp4
# 0690Pri_IndRK_C2.mp4
# 0691Pri_IndRK_C4.mp4
# 0692Exp_IndRK_HQ_C1.mp4
# 0693Exp_IndRK_HQ_C2.mp4
# 0694Exp_IndRK_HQ_C3.mp4
# 0695Exp_IndRK_HQ_C4.mp4
# 0696Exp_IndRK_MQ_C1.mp4
# 0697Exp_IndRK_MQ_C2.mp4
# 0698Exp_IndRK_MQ_C3.mp4
# 0699Exp_IndRK_MQ_C4.mp4
# 0700Exp_IndRK_LQ_C1.mp4
# 0701Exp_IndRK_LQ_C2.mp4
# 0702Exp_IndRK_LQ_C3.mp4
# 0703Exp_IndRK_LQ_C4.mp4
# 0704Exp_IndRK_HQ_C1.mp4
# 0705Exp_IndRK_HQ_C2.mp4
# 0706Exp_IndRK_HQ_C3.mp4
# 0707Exp_IndRK_HQ_C4.mp4
# 0708Exp_IndRK_MQ_C1.mp4
# 0709Exp_IndRK_MQ_C2.mp4
# 0710Exp_IndRK_MQ_C3.mp4
# 0711Exp_IndRK_MQ_C4.mp4
# 0712Exp_IndRK_LQ_C1.mp4
# 0713Exp_IndRK_LQ_C2.mp4
# 0714Exp_IndRK_LQ_C3.mp4
# 0715Exp_IndRK_LQ_C4.mp4
# 0716Exp_IndRK_HQ_C1.mp4
# 0717Exp_IndRK_HQ_C2.mp4
# 0718Exp_IndRK_HQ_C3.mp4
# 0719Exp_IndRK_HQ_C4.mp4
# 0720Exp_IndRK_MQ_C1.mp4
# 0721Exp_IndRK_MQ_C2.mp4
# 0722Exp_IndRK_MQ_C3.mp4
# 0723Exp_IndRK_MQ_C4.mp4
# 0724Exp_IndRK_LQ_C1.mp4
# 0725Exp_IndRK_LQ_C2.mp4
# 0726Exp_IndRK_LQ_C3.mp4
# 0727Exp_IndRK_LQ_C4.mp4
# 0728Fo_IndRK_HQ_C1.mp4
# 0729Fo_IndRK_HQ_C2.mp4
# 0730Fo_IndRK_HQ_C3.mp4
# 0731Fo_IndRK_HQ_C4.mp4
# 0732Fo_IndRK_MQ_C1.mp4
# 0733Fo_IndRK_MQ_C2.mp4
# 0734Fo_IndRK_MQ_C3.mp4
# 0735Fo_IndRK_MQ_C4.mp4
# 0736Fo_IndRK_LQ_C1.mp4
# 0737Fo_IndRK_LQ_C2.mp4
# 0738Fo_IndRK_LQ_C3.mp4
# 0739Fo_IndRK_LQ_C4.mp4
# 0740Fo_IndRK_HQ_C1.mp4
# 0741Fo_IndRK_HQ_C2.mp4
# 0742Fo_IndRK_HQ_C3.mp4
# 0743Fo_IndRK_HQ_C4.mp4
# 0744Fo_IndRK_MQ_C1.mp4
# 0745Fo_IndRK_MQ_C2.mp4
# 0746Fo_IndRK_MQ_C3.mp4
# 0747Fo_IndRK_MQ_C4.mp4
# 0748Fo_IndRK_LQ_C1.mp4
# 0749Fo_IndRK_LQ_C2.mp4
# 0750Fo_IndRK_LQ_C3.mp4
# 0751Fo_IndRK_LQ_C4.mp4
# 0752Fo_IndRK_HQ_C1.mp4
# 0753Fo_IndRK_HQ_C2.mp4
# 0754Fo_IndRK_HQ_C4.mp4
# 0755Fo_IndRK_MQ_C1.mp4
# 0756Fo_IndRK_MQ_C2.mp4
# 0757Fo_IndRK_MQ_C4.mp4
# 0758Fo_IndRK_LQ_C1.mp4
# 0759Fo_IndRK_LQ_C2.mp4
# 0760Fo_IndRK_LQ_C4.mp4
# 0761ExFo_IndRK_HQ_C1.mp4
# 0762ExFo_IndRK_HQ_C2.mp4
# 0763ExFo_IndRK_HQ_C3.mp4
# 0764ExFo_IndRK_HQ_C4.mp4
# 0765ExFo_IndRK_MQ_C1.mp4
# 0766ExFo_IndRK_MQ_C2.mp4
# 0767ExFo_IndRK_MQ_C3.mp4
# 0768ExFo_IndRK_MQ_C4.mp4
# 0769ExFo_IndRK_LQ_C1.mp4
# 0770ExFo_IndRK_LQ_C2.mp4
# 0771ExFo_IndRK_LQ_C3.mp4
# 0772ExFo_IndRK_LQ_C4.mp4
# 0773ExFo_IndRK_HQ_C1.mp4
# 0774ExFo_IndRK_HQ_C2.mp4
# 0775ExFo_IndRK_HQ_C3.mp4
# 0776ExFo_IndRK_HQ_C4.mp4
# 0777ExFo_IndRK_MQ_C1.mp4
# 0778ExFo_IndRK_MQ_C2.mp4
# 0779ExFo_IndRK_MQ_C3.mp4
# 0780ExFo_IndRK_MQ_C4.mp4
# 0781ExFo_IndRK_LQ_C1.mp4
# 0782ExFo_IndRK_LQ_C2.mp4
# 0783ExFo_IndRK_LQ_C3.mp4
# 0784ExFo_IndRK_LQ_C4.mp4
# 0785ExFo_IndRK_HQ_C1.mp4
# 0786ExFo_IndRK_HQ_C2.mp4
# 0787ExFo_IndRK_HQ_C3.mp4
# 0788ExFo_IndRK_HQ_C4.mp4
# 0789ExFo_IndRK_MQ_C1.mp4
# 0790ExFo_IndRK_MQ_C2.mp4
# 0791ExFo_IndRK_MQ_C3.mp4
# 0792ExFo_IndRK_MQ_C4.mp4
# 0793ExFo_IndRK_LQ_C1.mp4
# 0794ExFo_IndRK_LQ_C2.mp4
# 0795ExFo_IndRK_LQ_C3.mp4
# 0796ExFo_IndRK_LQ_C4.mp4
# 0797Pri_IndFG_C1.mp4
# 0798Pri_IndFG_C2.mp4
# 0799Pri_IndFG_C4.mp4
# 0800Exp_IndFG_HQ_C1.mp4
# 0801Exp_IndFG_HQ_C2.mp4
# 0802Exp_IndFG_HQ_C3.mp4
# 0803Exp_IndFG_HQ_C4.mp4
# 0804Exp_IndFG_MQ_C1.mp4
# 0805Exp_IndFG_MQ_C2.mp4
# 0806Exp_IndFG_MQ_C3.mp4
# 0807Exp_IndFG_MQ_C4.mp4
# 0808Exp_IndFG_LQ_C1.mp4
# 0809Exp_IndFG_LQ_C2.mp4
# 0810Exp_IndFG_LQ_C3.mp4
# 0811Exp_IndFG_LQ_C4.mp4
# 0812Exp_IndFG_HQ_C1.mp4
# 0813Exp_IndFG_HQ_C2.mp4
# 0814Exp_IndFG_HQ_C3.mp4
# 0815Exp_IndFG_HQ_C4.mp4
# 0816Exp_IndFG_MQ_C1.mp4
# 0817Exp_IndFG_MQ_C2.mp4
# 0818Exp_IndFG_MQ_C3.mp4
# 0819Exp_IndFG_MQ_C4.mp4
# 0820Exp_IndFG_LQ_C1.mp4
# 0821Exp_IndFG_LQ_C2.mp4
# 0822Exp_IndFG_LQ_C3.mp4
# 0823Exp_IndFG_LQ_C4.mp4
# 0824Exp_IndFG_HQ_C1.mp4
# 0825Exp_IndFG_HQ_C2.mp4
# 0826Exp_IndFG_HQ_C3.mp4
# 0827Exp_IndFG_HQ_C4.mp4
# 0828Exp_IndFG_MQ_C1.mp4
# 0829Exp_IndFG_MQ_C2.mp4
# 0830Exp_IndFG_MQ_C3.mp4
# 0831Exp_IndFG_MQ_C4.mp4
# 0832Exp_IndFG_LQ_C1.mp4
# 0833Exp_IndFG_LQ_C2.mp4
# 0834Exp_IndFG_LQ_C3.mp4
# 0835Exp_IndFG_LQ_C4.mp4
# 0836Fo_IndFG_HQ_C1.mp4
# 0837Fo_IndFG_HQ_C2.mp4
# 0838Fo_IndFG_HQ_C4.mp4
# 0839Fo_IndFG_MQ_C1.mp4
# 0840Fo_IndFG_MQ_C2.mp4
# 0841Fo_IndFG_MQ_C4.mp4
# 0842Fo_IndFG_LQ_C1.mp4
# 0843Fo_IndFG_LQ_C2.mp4
# 0844Fo_IndFG_LQ_C4.mp4
# 0845Fo_IndFG_HQ_C1.mp4
# 0846Fo_IndFG_HQ_C2.mp4
# 0847Fo_IndFG_HQ_C3.mp4
# 0848Fo_IndFG_HQ_C4.mp4
# 0849Fo_IndFG_MQ_C1.mp4
# 0850Fo_IndFG_MQ_C2.mp4
# 0851Fo_IndFG_MQ_C3.mp4
# 0852Fo_IndFG_MQ_C4.mp4
# 0853Fo_IndFG_LQ_C1.mp4
# 0854Fo_IndFG_LQ_C2.mp4
# 0855Fo_IndFG_LQ_C3.mp4
# 0856Fo_IndFG_LQ_C4.mp4
# 0857Fo_IndFG_HQ_C1.mp4
# 0858Fo_IndFG_HQ_C2.mp4
# 0859Fo_IndFG_HQ_C4.mp4
# 0860Fo_IndFG_MQ_C1.mp4
# 0861Fo_IndFG_MQ_C2.mp4
# 0862Fo_IndFG_MQ_C4.mp4
# 0863Fo_IndFG_LQ_C1.mp4
# 0864Fo_IndFG_LQ_C2.mp4
# 0865Fo_IndFG_LQ_C4.mp4
# 0866ExFo_IndFG_HQ_C1.mp4
# 0867ExFo_IndFG_HQ_C2.mp4
# 0868ExFo_IndFG_HQ_C3.mp4
# 0869ExFo_IndFG_HQ_C4.mp4
# 0870ExFo_IndFG_MQ_C1.mp4
# 0871ExFo_IndFG_MQ_C2.mp4
# 0872ExFo_IndFG_MQ_C3.mp4
# 0873ExFo_IndFG_MQ_C4.mp4
# 0874ExFo_IndFG_LQ_C1.mp4
# 0875ExFo_IndFG_LQ_C2.mp4
# 0876ExFo_IndFG_LQ_C3.mp4
# 0877ExFo_IndFG_LQ_C4.mp4
# 0878ExFo_IndFG_HQ_C1.mp4
# 0879ExFo_IndFG_HQ_C2.mp4
# 0880ExFo_IndFG_HQ_C3.mp4
# 0881ExFo_IndFG_HQ_C4.mp4
# 0882ExFo_IndFG_MQ_C1.mp4
# 0883ExFo_IndFG_MQ_C2.mp4
# 0884ExFo_IndFG_MQ_C3.mp4
# 0885ExFo_IndFG_MQ_C4.mp4
# 0886ExFo_IndFG_LQ_C1.mp4
# 0887ExFo_IndFG_LQ_C2.mp4
# 0888ExFo_IndFG_LQ_C3.mp4
# 0889ExFo_IndFG_LQ_C4.mp4
# 0890ExFo_IndFG_HQ_C1.mp4
# 0891ExFo_IndFG_HQ_C2.mp4
# 0892ExFo_IndFG_HQ_C3.mp4
# 0893ExFo_IndFG_HQ_C4.mp4
# 0894ExFo_IndFG_MQ_C1.mp4
# 0895ExFo_IndFG_MQ_C2.mp4
# 0896ExFo_IndFG_MQ_C3.mp4
# 0897ExFo_IndFG_MQ_C4.mp4
# 0898ExFo_IndFG_LQ_C1.mp4
# 0899ExFo_IndFG_LQ_C2.mp4
# 0900ExFo_IndFG_LQ_C3.mp4
# 0901ExFo_IndFG_LQ_C4.mp4
# 0902Pri_OutPW_C1.mp4
# 0903Pri_OutPW_C2.mp4
# 0904Pri_OutPW_C4.mp4
# 0905Exp_OutPW_HQ_C1.mp4
# 0906Exp_OutPW_HQ_C2.mp4
# 0907Exp_OutPW_HQ_C4.mp4
# 0908Exp_OutPW_MQ_C1.mp4
# 0909Exp_OutPW_MQ_C2.mp4
# 0910Exp_OutPW_MQ_C4.mp4
# 0911Exp_OutPW_LQ_C1.mp4
# 0912Exp_OutPW_LQ_C2.mp4
# 0913Exp_OutPW_LQ_C4.mp4
# 0914Exp_OutPW_HQ_C1.mp4
# 0915Exp_OutPW_HQ_C2.mp4
# 0916Exp_OutPW_HQ_C3.mp4
# 0917Exp_OutPW_HQ_C4.mp4
# 0918Exp_OutPW_MQ_C1.mp4
# 0919Exp_OutPW_MQ_C2.mp4
# 0920Exp_OutPW_MQ_C3.mp4
# 0921Exp_OutPW_MQ_C4.mp4
# 0922Exp_OutPW_LQ_C1.mp4
# 0923Exp_OutPW_LQ_C2.mp4
# 0924Exp_OutPW_LQ_C3.mp4
# 0925Exp_OutPW_LQ_C4.mp4
# 0926Exp_OutPW_HQ_C1.mp4
# 0927Exp_OutPW_HQ_C2.mp4
# 0928Exp_OutPW_HQ_C3.mp4
# 0929Exp_OutPW_HQ_C4.mp4
# 0930Exp_OutPW_MQ_C1.mp4
# 0931Exp_OutPW_MQ_C2.mp4
# 0932Exp_OutPW_MQ_C3.mp4
# 0933Exp_OutPW_MQ_C4.mp4
# 0934Exp_OutPW_LQ_C1.mp4
# 0935Exp_OutPW_LQ_C2.mp4
# 0936Exp_OutPW_LQ_C3.mp4
# 0937Exp_OutPW_LQ_C4.mp4
# 0938Fo_OutPW_HQ_C1.mp4
# 0939Fo_OutPW_HQ_C2.mp4
# 0940Fo_OutPW_HQ_C3.mp4
# 0941Fo_OutPW_HQ_C4.mp4
# 0942Fo_OutPW_MQ_C1.mp4
# 0943Fo_OutPW_MQ_C2.mp4
# 0944Fo_OutPW_MQ_C3.mp4
# 0945Fo_OutPW_MQ_C4.mp4
# 0946Fo_OutPW_LQ_C1.mp4
# 0947Fo_OutPW_LQ_C2.mp4
# 0948Fo_OutPW_LQ_C3.mp4
# 0949Fo_OutPW_LQ_C4.mp4
# 0950Fo_OutPW_HQ_C1.mp4
# 0951Fo_OutPW_HQ_C2.mp4
# 0952Fo_OutPW_HQ_C3.mp4
# 0953Fo_OutPW_HQ_C4.mp4
# 0954Fo_OutPW_MQ_C1.mp4
# 0955Fo_OutPW_MQ_C2.mp4
# 0956Fo_OutPW_MQ_C3.mp4
# 0957Fo_OutPW_MQ_C4.mp4
# 0958Fo_OutPW_LQ_C1.mp4
# 0959Fo_OutPW_LQ_C2.mp4
# 0960Fo_OutPW_LQ_C3.mp4
# 0961Fo_OutPW_LQ_C4.mp4
# 0962Fo_OutPW_HQ_C1.mp4
# 0963Fo_OutPW_HQ_C2.mp4
# 0964Fo_OutPW_HQ_C3.mp4
# 0965Fo_OutPW_HQ_C4.mp4
# 0966Fo_OutPW_MQ_C1.mp4
# 0967Fo_OutPW_MQ_C2.mp4
# 0968Fo_OutPW_MQ_C3.mp4
# 0969Fo_OutPW_MQ_C4.mp4
# 0970Fo_OutPW_LQ_C1.mp4
# 0971Fo_OutPW_LQ_C2.mp4
# 0972Fo_OutPW_LQ_C3.mp4
# 0973Fo_OutPW_LQ_C4.mp4
# 0974ExFo_OutPW_HQ_C1.mp4
# 0975ExFo_OutPW_HQ_C2.mp4
# 0976ExFo_OutPW_HQ_C3.mp4
# 0977ExFo_OutPW_HQ_C4.mp4
# 0978ExFo_OutPW_MQ_C1.mp4
# 0979ExFo_OutPW_MQ_C2.mp4
# 0980ExFo_OutPW_MQ_C3.mp4
# 0981ExFo_OutPW_MQ_C4.mp4
# 0982ExFo_OutPW_LQ_C1.mp4
# 0983ExFo_OutPW_LQ_C2.mp4
# 0984ExFo_OutPW_LQ_C3.mp4
# 0985ExFo_OutPW_LQ_C4.mp4
# 0986ExFo_OutPW_HQ_C1.mp4
# 0987ExFo_OutPW_HQ_C2.mp4
# 0988ExFo_OutPW_HQ_C3.mp4
# 0989ExFo_OutPW_HQ_C4.mp4
# 0990ExFo_OutPW_MQ_C1.mp4
# 0991ExFo_OutPW_MQ_C2.mp4
# 0992ExFo_OutPW_MQ_C3.mp4
# 0993ExFo_OutPW_MQ_C4.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-500486b6112c> in <module>
#      47     vid_location = os.path.join(Vid_folder,vid_name)
#      48     frames_location = os.path.join(Img_folder,vid_name)
# ---> 49     get_frames(vid_location,
#      50                frames_location,
#      51                ext)
#
# <ipython-input-6-500486b6112c> in get_frames(vid_name, folder_name, ext)
#      20
#      21             # writing the extracted images
# ---> 22             cv2.imwrite(name, frame)
#      23
#      24             # increasing counter so that it will
#
# KeyboardInterrupt:
