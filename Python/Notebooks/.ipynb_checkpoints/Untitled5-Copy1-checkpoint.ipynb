# %%
import numpy as np
import os
import time



with open('/home/r/Dropbox/Javeriana/current_work/tracker_prediction/VariacionResolucion_ImpactoTracker/script_convert_2_ogv.txt') as f:
    lines = f.readlines()


os.chdir(r'/home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos')

# %%
for i in range (1,200):
    start = time.time()
    print(lines[i])
    print(os.system(lines[i]))
    end = time.time()
    print(end - start)
end
# Out:
# ffmpeg -i 0053Pri_IndPW_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0053Pri_IndPW_C3.ogv
#
# 256
# 0.06774044036865234
# ffmpeg -i 0067Exp_IndPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0067Exp_IndPW_HQ_C1.ogv
#
# 256
# 0.05578160285949707
# ffmpeg -i 0070Exp_IndPW_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0070Exp_IndPW_HQ_C4.ogv
#
# 256
# 0.056923866271972656
# ffmpeg -i 0071Exp_IndPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0071Exp_IndPW_MQ_C1.ogv
#
# 256
# 0.056944847106933594
# ffmpeg -i 0074Exp_IndPW_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0074Exp_IndPW_MQ_C4.ogv
#
# 256
# 0.05855989456176758
# ffmpeg -i 0075Exp_IndPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0075Exp_IndPW_LQ_C1.ogv
#
# 256
# 0.056513309478759766
# ffmpeg -i 0078Exp_IndPW_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0078Exp_IndPW_LQ_C4.ogv
#
# 256
# 0.058731794357299805
# ffmpeg -i 0145ExFo_IndPW_MQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0145ExFo_IndPW_MQ_C3.ogv
#
# 256
# 0.056824445724487305
# ffmpeg -i 0149ExFo_IndPW_LQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0149ExFo_IndPW_LQ_C3.ogv
#
# 256
# 0.05858922004699707
# ffmpeg -i 0163Pri_IndLPP_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0163Pri_IndLPP_C1.ogv
#
# 256
# 0.06111407279968262
# ffmpeg -i 0164Pri_IndLPP_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0164Pri_IndLPP_C2.ogv
#
# 256
# 0.058095455169677734
# ffmpeg -i 0165Pri_IndLPP_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0165Pri_IndLPP_C4.ogv
#
# 256
# 0.06511282920837402
# ffmpeg -i 0166Exp_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0166Exp_IndLPP_HQ_C1.ogv
#
# 256
# 0.05863142013549805
# ffmpeg -i 0167Exp_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0167Exp_IndLPP_HQ_C2.ogv
#
# 256
# 0.05683159828186035
# ffmpeg -i 0169Exp_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0169Exp_IndLPP_HQ_C4.ogv
#
# 256
# 0.057071685791015625
# ffmpeg -i 0170Exp_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0170Exp_IndLPP_MQ_C1.ogv
#
# 256
# 0.06068611145019531
# ffmpeg -i 0171Exp_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0171Exp_IndLPP_MQ_C2.ogv
#
# 256
# 0.05770373344421387
# ffmpeg -i 0173Exp_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0173Exp_IndLPP_MQ_C4.ogv
#
# 256
# 0.057454824447631836
# ffmpeg -i 0174Exp_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0174Exp_IndLPP_LQ_C1.ogv
#
# 256
# 0.057097673416137695
# ffmpeg -i 0175Exp_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0175Exp_IndLPP_LQ_C2.ogv

# %%
for i in range (201,400):
    start = time.time()
    print(lines[i])
    print(os.system(lines[i]))
    end = time.time()
    print(end - start)
end
