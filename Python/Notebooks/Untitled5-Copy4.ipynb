# %%
import numpy as np
import os
import time



with open('/home/r/Dropbox/Javeriana/current_work/tracker_prediction/VariacionResolucion_ImpactoTracker/script_convert_2_ogv.txt') as f:
    lines = f.readlines()


os.chdir(r'/home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos')

# %%
for i in range (801,1000):
    start = time.time()
    print(lines[i])
    print(os.system(lines[i]))
    end = time.time()
    print(end - start)
end
# Out:
# ffmpeg -i 2025Fo_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2025Fo_IndWL_HQ_C4.ogv
#
# 0
# 81.52205896377563
# ffmpeg -i 2033Fo_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2033Fo_IndWL_LQ_C4.ogv
#
# 0
# 63.93130326271057
# ffmpeg -i 2035Fo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2035Fo_IndWL_HQ_C2.ogv
#
# 0
# 61.247713565826416
# ffmpeg -i 2039Fo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2039Fo_IndWL_MQ_C2.ogv
#
# 0
# 61.985986948013306
# ffmpeg -i 2042Fo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2042Fo_IndWL_LQ_C1.ogv
#
# 0
# 62.64679479598999
# ffmpeg -i 2043Fo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2043Fo_IndWL_LQ_C2.ogv
#
# 0
# 64.7469425201416
# ffmpeg -i 2046Fo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2046Fo_IndWL_HQ_C1.ogv
#
# 0
# 63.063579082489014
# ffmpeg -i 2050Fo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2050Fo_IndWL_MQ_C1.ogv
#
# 0
# 64.55938291549683
# ffmpeg -i 2054Fo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2054Fo_IndWL_LQ_C1.ogv
#
# 0
# 59.16781973838806
# ffmpeg -i 2058ExFo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2058ExFo_IndWL_HQ_C1.ogv
#
# 0
# 60.442057847976685
# ffmpeg -i 2062ExFo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2062ExFo_IndWL_MQ_C1.ogv
#
# 0
# 60.402204275131226
# ffmpeg -i 2066ExFo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2066ExFo_IndWL_LQ_C1.ogv
#
# 0
# 72.65093994140625
# ffmpeg -i 2070ExFo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2070ExFo_IndWL_HQ_C1.ogv
#
# 0
# 68.52905058860779
# ffmpeg -i 2071ExFo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2071ExFo_IndWL_HQ_C2.ogv
#
# 0
# 70.94469165802002
# ffmpeg -i 2074ExFo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2074ExFo_IndWL_MQ_C1.ogv
#
# 0
# 70.14791798591614
# ffmpeg -i 2075ExFo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2075ExFo_IndWL_MQ_C2.ogv
#
# 0
# 85.89178609848022
# ffmpeg -i 2078ExFo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2078ExFo_IndWL_LQ_C1.ogv
#
# 0
# 63.26573967933655
# ffmpeg -i 2079ExFo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2079ExFo_IndWL_LQ_C2.ogv
#
# 0
# 60.496296644210815
# ffmpeg -i 2083ExFo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2083ExFo_IndWL_HQ_C2.ogv
#
# 0
# 60.09881949424744
# ffmpeg -i 2087ExFo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2087ExFo_IndWL_MQ_C2.ogv
#
# 0
# 64.1243691444397
# ffmpeg -i 2091ExFo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2091ExFo_IndWL_LQ_C2.ogv
#
# 0
# 63.4442572593689
# ffmpeg -i 2134Fo_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2134Fo_IndPR_HQ_C1.ogv
#
# 0
# 62.864906787872314
# ffmpeg -i 2138Fo_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2138Fo_IndPR_MQ_C1.ogv
#
# 0
# 72.36911916732788
# ffmpeg -i 2142Fo_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2142Fo_IndPR_LQ_C1.ogv
#
# 0
# 68.60466623306274
# ffmpeg -i 2146Fo_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2146Fo_IndPR_HQ_C1.ogv
#
# 0
# 74.01386189460754
# ffmpeg -i 2150Fo_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2150Fo_IndPR_MQ_C1.ogv
#
# 0
# 64.42451119422913
# ffmpeg -i 2154Fo_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2154Fo_IndPR_LQ_C1.ogv
#
# 0
# 63.830268144607544
# ffmpeg -i 2182ExFo_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2182ExFo_IndPR_HQ_C1.ogv
#
# 0
# 63.55185389518738
# ffmpeg -i 2183ExFo_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2183ExFo_IndPR_HQ_C2.ogv
#
# 0
# 63.96787095069885
# ffmpeg -i 2186ExFo_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2186ExFo_IndPR_MQ_C1.ogv
#
# 0
# 62.55162072181702
# ffmpeg -i 2187ExFo_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2187ExFo_IndPR_MQ_C2.ogv
#
# 0
# 75.965017080307
# ffmpeg -i 2190ExFo_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2190ExFo_IndPR_LQ_C1.ogv
#
# 0
# 72.56968402862549
# ffmpeg -i 2191ExFo_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2191ExFo_IndPR_LQ_C2.ogv
#
# 0
# 67.78712463378906
# ffmpeg -i 2225Exp_IndPO_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2225Exp_IndPO_HQ_C4.ogv
#
# 0
# 65.44422316551208
# ffmpeg -i 2229Exp_IndPO_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2229Exp_IndPO_MQ_C4.ogv
#
# 0
# 68.81151485443115
# ffmpeg -i 2233Exp_IndPO_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2233Exp_IndPO_LQ_C4.ogv
#
# 0
# 71.54682183265686
# ffmpeg -i 2318Pri_IndPPP_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2318Pri_IndPPP_C1.ogv
#
# 0
# 99.43886280059814
# ffmpeg -i 2346Exp_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2346Exp_IndPPP_HQ_C1.ogv
# 0
# 68.61702704429626
# ffmpeg -i 2349Exp_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2349Exp_IndPPP_HQ_C4.ogv
#
# 0
# 69.310213804245
# ffmpeg -i 2350Exp_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2350Exp_IndPPP_MQ_C1.ogv
#
# 0
# 70.0577483177185
# ffmpeg -i 2353Exp_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2353Exp_IndPPP_MQ_C4.ogv
#
# 0
# 65.4711651802063
# ffmpeg -i 2354Exp_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2354Exp_IndPPP_LQ_C1.ogv
#
# 0
# 73.92679595947266
# ffmpeg -i 2357Exp_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2357Exp_IndPPP_LQ_C4.ogv
#
# 0
# 77.82077860832214
# ffmpeg -i 2358Fo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2358Fo_IndPPP_HQ_C1.ogv
#
# 0
# 79.60058379173279
# ffmpeg -i 2359Fo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2359Fo_IndPPP_HQ_C2.ogv
#
# 0
# 66.36409592628479
# ffmpeg -i 2361Fo_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2361Fo_IndPPP_HQ_C4.ogv
#
# 0
# 82.12448048591614
# ffmpeg -i 2362Fo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2362Fo_IndPPP_MQ_C1.ogv
#
# 0
# 61.987990617752075
# ffmpeg -i 2363Fo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2363Fo_IndPPP_MQ_C2.ogv
#
# 0
# 71.27985215187073
# ffmpeg -i 2365Fo_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2365Fo_IndPPP_MQ_C4.ogv
#
# 0
# 75.31241941452026
# ffmpeg -i 2366Fo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2366Fo_IndPPP_LQ_C1.ogv
#
# 0
# 77.6466703414917
# ffmpeg -i 2367Fo_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2367Fo_IndPPP_LQ_C2.ogv
#
# 0
# 70.56613516807556
# ffmpeg -i 2369Fo_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2369Fo_IndPPP_LQ_C4.ogv
#
# 0
# 70.0414662361145
# ffmpeg -i 2370Fo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2370Fo_IndPPP_HQ_C1.ogv
#
# 0
# 67.3719253540039
# ffmpeg -i 2374Fo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2374Fo_IndPPP_MQ_C1.ogv
#
# 0
# 69.65626907348633
# ffmpeg -i 2378Fo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2378Fo_IndPPP_LQ_C1.ogv
#
# 0
# 70.2175829410553
# ffmpeg -i 2406ExFo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2406ExFo_IndPPP_HQ_C1.ogv
#
# 0
# 66.35383343696594
# ffmpeg -i 2407ExFo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2407ExFo_IndPPP_HQ_C2.ogv
#
# 0
# 79.87805724143982
# ffmpeg -i 2409ExFo_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2409ExFo_IndPPP_HQ_C4.ogv
#
# 0
# 68.03365230560303
# ffmpeg -i 2410ExFo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2410ExFo_IndPPP_MQ_C1.ogv
#
# 0
# 63.04980993270874
# ffmpeg -i 2411ExFo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2411ExFo_IndPPP_MQ_C2.ogv
#
# 0
# 81.33278775215149
# ffmpeg -i 2413ExFo_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2413ExFo_IndPPP_MQ_C4.ogv
#
# 0
# 60.85250735282898
# ffmpeg -i 2414ExFo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2414ExFo_IndPPP_LQ_C1.ogv
#
# 0
# 62.16637945175171
# ffmpeg -i 2415ExFo_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2415ExFo_IndPPP_LQ_C2.ogv
#
# 0
# 60.91168975830078
# ffmpeg -i 2417ExFo_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2417ExFo_IndPPP_LQ_C4.ogv
#
# 0
# 65.42176795005798
# ffmpeg -i 2418ExFo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2418ExFo_IndPPP_HQ_C1.ogv
#
# 0
# 67.93696784973145
# ffmpeg -i 2419ExFo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2419ExFo_IndPPP_HQ_C2.ogv
#
# 0
# 70.2040536403656
# ffmpeg -i 2422ExFo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2422ExFo_IndPPP_MQ_C1.ogv
#
# 0
# 64.55174493789673
# ffmpeg -i 2423ExFo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2423ExFo_IndPPP_MQ_C2.ogv
#
# 0
# 63.268959283828735
# ffmpeg -i 2426ExFo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2426ExFo_IndPPP_LQ_C1.ogv
#
# 0
# 67.98820328712463
# ffmpeg -i 2430Pri_IndRK_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2430Pri_IndRK_C1.ogv
#
# 0
# 93.72892618179321
# ffmpeg -i 2434Exp_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2434Exp_IndRK_HQ_C1.ogv
#
# 0
# 69.8936288356781
# ffmpeg -i 2435Exp_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2435Exp_IndRK_HQ_C2.ogv
#
# 0
# 66.85445022583008
# ffmpeg -i 2438Exp_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2438Exp_IndRK_MQ_C1.ogv
#
# 0
# 80.31171584129333
# ffmpeg -i 2439Exp_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2439Exp_IndRK_MQ_C2.ogv
#
# 0
# 80.20162153244019
# ffmpeg -i 2442Exp_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2442Exp_IndRK_LQ_C1.ogv
#
# 0
# 73.21110796928406
# ffmpeg -i 2443Exp_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2443Exp_IndRK_LQ_C2.ogv
# 0
# 60.800766944885254
# ffmpeg -i 2458Exp_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2458Exp_IndRK_HQ_C1.ogv
#
# 0
# 60.517945766448975
# ffmpeg -i 2459Exp_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2459Exp_IndRK_HQ_C2.ogv
#
# 0
# 65.0476303100586
# ffmpeg -i 2461Exp_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2461Exp_IndRK_HQ_C4.ogv
#
# 0
# 60.090110063552856
# ffmpeg -i 2462Exp_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2462Exp_IndRK_MQ_C1.ogv
#
# 0
# 60.528024435043335
# ffmpeg -i 2463Exp_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2463Exp_IndRK_MQ_C2.ogv
#
# 0
# 60.83920097351074
# ffmpeg -i 2465Exp_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2465Exp_IndRK_MQ_C4.ogv
#
# 0
# 57.938414096832275
# ffmpeg -i 2466Exp_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2466Exp_IndRK_LQ_C1.ogv
#
# 0
# 62.30297899246216
# ffmpeg -i 2467Exp_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2467Exp_IndRK_LQ_C2.ogv
#
# 0
# 57.75075149536133
# ffmpeg -i 2469Exp_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2469Exp_IndRK_LQ_C4.ogv
#
# 0
# 56.49829459190369
# ffmpeg -i 2473Fo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2473Fo_IndRK_HQ_C4.ogv
#
# 0
# 104.28792262077332
# ffmpeg -i 2477Fo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2477Fo_IndRK_MQ_C4.ogv
#
# 0
# 85.6542284488678
# ffmpeg -i 2481Fo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2481Fo_IndRK_LQ_C4.ogv
#
# 0
# 72.33614230155945
# ffmpeg -i 2482Fo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2482Fo_IndRK_HQ_C1.ogv
#
# 0
# 73.74602484703064
# ffmpeg -i 2483Fo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2483Fo_IndRK_HQ_C2.ogv
#
# 0
# 63.89251136779785
# ffmpeg -i 2486Fo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2486Fo_IndRK_MQ_C1.ogv
#
# 0
# 60.749353647232056
# ffmpeg -i 2487Fo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2487Fo_IndRK_MQ_C2.ogv
#
# 0
# 61.16952395439148
# ffmpeg -i 2490Fo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2490Fo_IndRK_LQ_C1.ogv
#
# 0
# 65.56690168380737
# ffmpeg -i 2491Fo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2491Fo_IndRK_LQ_C2.ogv
#
# 0
# 63.80923652648926
# ffmpeg -i 2531ExFo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2531ExFo_IndRK_HQ_C2.ogv
#
# 0
# 61.27165126800537
# ffmpeg -i 2535ExFo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2535ExFo_IndRK_MQ_C2.ogv
#
# 0
# 58.33659887313843
# ffmpeg -i 2541ExFo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2541ExFo_IndRK_LQ_C4.ogv
#
# 0
# 57.41997456550598
# ffmpeg -i 2604Fo_IndFG_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2604Fo_IndFG_HQ_C4.ogv
#
# 0
# 65.8777506351471
# ffmpeg -i 2607Fo_IndFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2607Fo_IndFG_MQ_C4.ogv
#
# 0
# 72.82203793525696
# ffmpeg -i 2610Fo_IndFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2610Fo_IndFG_LQ_C4.ogv
#
# 0
# 63.1977174282074
# ffmpeg -i 2659Exp_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2659Exp_OutPW_HQ_C1.ogv
#
# 0
# 68.503427028656
# ffmpeg -i 2660Exp_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2660Exp_OutPW_HQ_C2.ogv
#
# 0
# 58.15632677078247
# ffmpeg -i 2662Exp_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2662Exp_OutPW_MQ_C1.ogv
#
# 0
# 58.33944392204285
# ffmpeg -i 2663Exp_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2663Exp_OutPW_MQ_C2.ogv
#
# 0
# 57.29783272743225
# ffmpeg -i 2665Exp_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2665Exp_OutPW_LQ_C1.ogv
#
# 0
# 61.09048843383789
# ffmpeg -i 2666Exp_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2666Exp_OutPW_LQ_C2.ogv
#
# 0
# 52.58501863479614
# ffmpeg -i 2677Fo_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2677Fo_OutPW_HQ_C1.ogv
#
# 0
# 49.950023889541626
# ffmpeg -i 2678Fo_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2678Fo_OutPW_HQ_C2.ogv
#
# 0
# 49.84312677383423
# ffmpeg -i 2680Fo_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2680Fo_OutPW_MQ_C1.ogv
#
# 0
# 46.17233872413635
# ffmpeg -i 2681Fo_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2681Fo_OutPW_MQ_C2.ogv
#
# 0
# 53.8531448841095
# ffmpeg -i 2683Fo_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2683Fo_OutPW_LQ_C1.ogv
#
# 0
# 59.967416763305664
# ffmpeg -i 2684Fo_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2684Fo_OutPW_LQ_C2.ogv
#
# 0
# 64.04066848754883
# ffmpeg -i 2687Fo_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2687Fo_OutPW_HQ_C2.ogv
#
# 0
# 69.22554874420166
# ffmpeg -i 2689Fo_OutPW_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2689Fo_OutPW_HQ_C4.ogv
#
# 0
# 67.41669249534607
# ffmpeg -i 2691Fo_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2691Fo_OutPW_MQ_C2.ogv
# 0
# 63.38018608093262
# ffmpeg -i 2693Fo_OutPW_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2693Fo_OutPW_MQ_C4.ogv
#
# 0
# 59.691628217697144
# ffmpeg -i 2695Fo_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2695Fo_OutPW_LQ_C2.ogv
#
# 0
# 61.98883652687073
# ffmpeg -i 2697Fo_OutPW_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2697Fo_OutPW_LQ_C4.ogv
#
# 0
# 56.610785484313965
# ffmpeg -i 2719ExFo_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2719ExFo_OutPW_HQ_C1.ogv
#
# 0
# 57.633808612823486
# ffmpeg -i 2723ExFo_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2723ExFo_OutPW_MQ_C1.ogv
#
# 0
# 62.74225878715515
# ffmpeg -i 2727ExFo_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2727ExFo_OutPW_LQ_C1.ogv
#
# 0
# 58.422868967056274
# ffmpeg -i 2755Exp_OutLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2755Exp_OutLPP_HQ_C1.ogv
#
# 0
# 73.04208707809448
# ffmpeg -i 2756Exp_OutLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2756Exp_OutLPP_HQ_C2.ogv
#
# 0
# 70.31060838699341
# ffmpeg -i 2759Exp_OutLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2759Exp_OutLPP_MQ_C1.ogv
#
# 0
# 67.6749279499054
# ffmpeg -i 2760Exp_OutLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2760Exp_OutLPP_MQ_C2.ogv
#
# 0
# 71.62537169456482
# ffmpeg -i 2763Exp_OutLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2763Exp_OutLPP_LQ_C1.ogv
#
# 0
# 63.26849126815796
# ffmpeg -i 2764Exp_OutLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2764Exp_OutLPP_LQ_C2.ogv
#
# 0
# 55.35437631607056
# ffmpeg -i 2786Fo_OutLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2786Fo_OutLPP_HQ_C2.ogv
#
# 0
# 47.35847091674805
# ffmpeg -i 2790Fo_OutLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2790Fo_OutLPP_MQ_C2.ogv
#
# 0
# 47.218435525894165
# ffmpeg -i 2794Fo_OutLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2794Fo_OutLPP_LQ_C2.ogv
#
# 0
# 58.319735527038574
# ffmpeg -i 2842Pri_OutWL_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2842Pri_OutWL_C1.ogv
#
# 0
# 101.78052687644958
# ffmpeg -i 2845Exp_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2845Exp_OutWL_HQ_C1.ogv
#
# 0
# 70.79179239273071
# ffmpeg -i 2848Exp_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2848Exp_OutWL_MQ_C1.ogv
#
# 0
# 61.36428689956665
# ffmpeg -i 2851Exp_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2851Exp_OutWL_LQ_C1.ogv
#
# 0
# 60.28581643104553
# ffmpeg -i 2852Exp_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2852Exp_OutWL_LQ_C2.ogv
#
# 0
# 49.26001238822937
# ffmpeg -i 2854Exp_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2854Exp_OutWL_HQ_C1.ogv
#
# 0
# 63.34555673599243
# ffmpeg -i 2855Exp_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2855Exp_OutWL_HQ_C2.ogv
#
# 0
# 50.48426032066345
# ffmpeg -i 2858Exp_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2858Exp_OutWL_MQ_C1.ogv
#
# 0
# 54.27983379364014
# ffmpeg -i 2859Exp_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2859Exp_OutWL_MQ_C2.ogv
#
# 0
# 53.13785362243652
# ffmpeg -i 2862Exp_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2862Exp_OutWL_LQ_C1.ogv
#
# 0
# 54.3463191986084
# ffmpeg -i 2863Exp_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2863Exp_OutWL_LQ_C2.ogv
#
# 0
# 49.607752084732056
# ffmpeg -i 2866Exp_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2866Exp_OutWL_HQ_C1.ogv
#
# 0
# 69.76240873336792
# ffmpeg -i 2867Exp_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2867Exp_OutWL_HQ_C2.ogv
#
# 0
# 50.04368257522583
# ffmpeg -i 2870Exp_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2870Exp_OutWL_MQ_C1.ogv
#
# 0
# 59.70610213279724
# ffmpeg -i 2871Exp_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2871Exp_OutWL_MQ_C2.ogv
#
# 0
# 50.60813927650452
# ffmpeg -i 2874Exp_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2874Exp_OutWL_LQ_C1.ogv
#
# 0
# 65.79361724853516
# ffmpeg -i 2875Exp_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2875Exp_OutWL_LQ_C2.ogv
#
# 0
# 45.5334997177124
# ffmpeg -i 2899Fo_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2899Fo_OutWL_HQ_C1.ogv
#
# 0
# 49.086278438568115
# ffmpeg -i 2900Fo_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2900Fo_OutWL_HQ_C2.ogv
#
# 0
# 47.14572477340698
# ffmpeg -i 2902Fo_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2902Fo_OutWL_MQ_C1.ogv
#
# 0
# 45.40598273277283
# ffmpeg -i 2903Fo_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2903Fo_OutWL_MQ_C2.ogv
#
# 0
# 48.88004422187805
# ffmpeg -i 2905Fo_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2905Fo_OutWL_LQ_C1.ogv
#
# 0
# 43.687565326690674
# ffmpeg -i 2909ExFo_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2909ExFo_OutWL_HQ_C2.ogv
# 0
# 53.798481702804565
# ffmpeg -i 2911ExFo_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2911ExFo_OutWL_MQ_C2.ogv
#
# 0
# 47.20202159881592
# ffmpeg -i 2913ExFo_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2913ExFo_OutWL_LQ_C2.ogv
#
# 0
# 52.62354898452759
# ffmpeg -i 2914ExFo_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2914ExFo_OutWL_HQ_C1.ogv
#
# 0
# 48.471333742141724
# ffmpeg -i 2918ExFo_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2918ExFo_OutWL_MQ_C1.ogv
#
# 0
# 55.17092967033386
# ffmpeg -i 2922ExFo_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2922ExFo_OutWL_LQ_C1.ogv
#
# 0
# 47.283666372299194
# ffmpeg -i 2929ExFo_OutWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2929ExFo_OutWL_HQ_C4.ogv
#
# 0
# 46.32609438896179
# ffmpeg -i 2933ExFo_OutWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2933ExFo_OutWL_MQ_C4.ogv
#
# 0
# 45.35782861709595
# ffmpeg -i 2939Pri_OutPR_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2939Pri_OutPR_C2.ogv
#
# 0
# 69.38884973526001
# ffmpeg -i 2941Exp_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2941Exp_OutPR_HQ_C1.ogv
#
# 0
# 64.12443828582764
# ffmpeg -i 2942Exp_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2942Exp_OutPR_HQ_C2.ogv
#
# 0
# 48.603862047195435
# ffmpeg -i 2944Exp_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2944Exp_OutPR_MQ_C1.ogv
#
# 0
# 60.78298568725586
# ffmpeg -i 2947Exp_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2947Exp_OutPR_LQ_C1.ogv
#
# 0
# 57.81943726539612
# ffmpeg -i 2948Exp_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2948Exp_OutPR_LQ_C2.ogv
#
# 0
# 52.69926619529724
# ffmpeg -i 2950Exp_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2950Exp_OutPR_HQ_C1.ogv
#
# 0
# 61.002219438552856
# ffmpeg -i 2951Exp_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2951Exp_OutPR_HQ_C2.ogv
#
# 0
# 52.86551594734192
# ffmpeg -i 2953Exp_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2953Exp_OutPR_MQ_C1.ogv
#
# 0
# 62.84495162963867
# ffmpeg -i 2954Exp_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2954Exp_OutPR_MQ_C2.ogv
#
# 0
# 58.742010831832886
# ffmpeg -i 2956Exp_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2956Exp_OutPR_LQ_C1.ogv
#
# 0
# 72.70602345466614
# ffmpeg -i 2957Exp_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2957Exp_OutPR_LQ_C2.ogv
#
# 0
# 59.84321165084839
# ffmpeg -i 2959Exp_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2959Exp_OutPR_HQ_C1.ogv
#
# 0
# 78.1750156879425
# ffmpeg -i 2960Exp_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2960Exp_OutPR_HQ_C2.ogv
#
# 0
# 63.29124569892883
# ffmpeg -i 2962Exp_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2962Exp_OutPR_MQ_C1.ogv
#
# 0
# 70.27883648872375
# ffmpeg -i 2963Exp_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2963Exp_OutPR_MQ_C2.ogv
#
# 0
# 61.6225950717926
# ffmpeg -i 2965Exp_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2965Exp_OutPR_LQ_C1.ogv
#
# 0
# 71.68162417411804
# ffmpeg -i 2966Exp_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2966Exp_OutPR_LQ_C2.ogv
#
# 0
# 62.92064380645752
# ffmpeg -i 2968Fo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2968Fo_OutPR_HQ_C1.ogv
#
# 0
# 55.23478555679321
# ffmpeg -i 2969Fo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2969Fo_OutPR_HQ_C2.ogv
#
# 0
# 50.66081357002258
# ffmpeg -i 2971Fo_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2971Fo_OutPR_MQ_C1.ogv
#
# 0
# 48.80707931518555
# ffmpeg -i 2972Fo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2972Fo_OutPR_MQ_C2.ogv
#
# 0
# 47.710875511169434
# ffmpeg -i 2974Fo_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2974Fo_OutPR_LQ_C1.ogv
#
# 0
# 52.60997128486633
# ffmpeg -i 2975Fo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2975Fo_OutPR_LQ_C2.ogv
#
# 0
# 47.60233783721924
# ffmpeg -i 2978Fo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2978Fo_OutPR_HQ_C2.ogv
#
# 0
# 44.575034856796265
# ffmpeg -i 2982Fo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2982Fo_OutPR_MQ_C2.ogv
#
# 0
# 43.739501953125
# ffmpeg -i 2986Fo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2986Fo_OutPR_LQ_C2.ogv
#
# 0
# 40.48039698600769
# ffmpeg -i 2990Fo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2990Fo_OutPR_HQ_C2.ogv
#
# 0
# 40.15522360801697
# ffmpeg -i 2993Fo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2993Fo_OutPR_MQ_C2.ogv
#
# 0
# 40.672194480895996
# ffmpeg -i 2996Fo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2996Fo_OutPR_LQ_C2.ogv
#
# 0
# 40.1573588848114
# ffmpeg -i 2998ExFo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2998ExFo_OutPR_HQ_C1.ogv
# 0
# 40.394874811172485
# ffmpeg -i 2999ExFo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/2999ExFo_OutPR_HQ_C2.ogv
#
# 0
# 42.856889486312866
# ffmpeg -i 3001ExFo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3001ExFo_OutPR_MQ_C2.ogv
#
# 0
# 39.48567748069763
# ffmpeg -i 3002ExFo_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3002ExFo_OutPR_LQ_C1.ogv
#
# 0
# 36.58185076713562
# ffmpeg -i 3003ExFo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3003ExFo_OutPR_LQ_C2.ogv
#
# 0
# 38.11625075340271
# ffmpeg -i 3004ExFo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3004ExFo_OutPR_HQ_C1.ogv
#
# 0
# 33.71591138839722
# ffmpeg -i 3008ExFo_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3008ExFo_OutPR_MQ_C1.ogv
#
# 0
# 32.375335693359375
# ffmpeg -i 3012ExFo_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3012ExFo_OutPR_LQ_C1.ogv
#
# 0
# 32.71345639228821
# ffmpeg -i 3018ExFo_OutPR_HQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3018ExFo_OutPR_HQ_C3.ogv
#
# 0
# 33.79180598258972
# 1623114646.7732956
