# %%
import numpy as np
import os
import time
with open('/home/r/Dropbox/Javeriana/current_work/tracker_prediction/VariacionResolucion_ImpactoTracker/script_convert_2_ogv.txt') as f:
    lines = f.readlines()
os.chdir(r'/home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos')

# %%
for i in range (1001,1385):
    start = time.time()
    print(lines[i])
    print(os.system(lines[i]))
    end = time.time()
    print(end - start)
end
# Out:
# ffmpeg -i 3026ExFo_OutPR_LQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3026ExFo_OutPR_LQ_C3.ogv
#
# 0
# 62.21626543998718
# ffmpeg -i 3121Pri_OutPPP_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3121Pri_OutPPP_C1.ogv
#
# 0
# 106.01627850532532
# ffmpeg -i 3206ExFo_OutPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3206ExFo_OutPPP_HQ_C1.ogv
#
# 0
# 61.06446933746338
# ffmpeg -i 3210ExFo_OutPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3210ExFo_OutPPP_MQ_C1.ogv
#
# 0
# 61.71461582183838
# ffmpeg -i 3214ExFo_OutPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3214ExFo_OutPPP_LQ_C1.ogv
#
# 0
# 60.40356636047363
# ffmpeg -i 3279Fo_OutRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3279Fo_OutRK_HQ_C2.ogv
#
# 0
# 61.91063165664673
# ffmpeg -i 3282Fo_OutRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3282Fo_OutRK_MQ_C2.ogv
#
# 0
# 61.55629587173462
# ffmpeg -i 3284Fo_OutRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3284Fo_OutRK_MQ_C4.ogv
#
# 0
# 63.71212840080261
# ffmpeg -i 3286Fo_OutRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3286Fo_OutRK_LQ_C2.ogv
#
# 0
# 61.822527170181274
# ffmpeg -i 3288Fo_OutRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3288Fo_OutRK_LQ_C4.ogv
#
# 0
# 59.82871913909912
# ffmpeg -i 3294Fo_OutRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3294Fo_OutRK_MQ_C2.ogv
#
# 0
# 63.26225018501282
# ffmpeg -i 3301ExFo_OutRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3301ExFo_OutRK_HQ_C1.ogv
#
# 0
# 72.4537079334259
# ffmpeg -i 3305ExFo_OutRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3305ExFo_OutRK_MQ_C1.ogv
#
# 0
# 76.20353531837463
# ffmpeg -i 3309ExFo_OutRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3309ExFo_OutRK_LQ_C1.ogv
#
# 0
# 73.45981359481812
# ffmpeg -i 3325ExFo_OutRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3325ExFo_OutRK_HQ_C1.ogv
#
# 0
# 70.04940915107727
# ffmpeg -i 3326ExFo_OutRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3326ExFo_OutRK_HQ_C2.ogv
#
# 0
# 72.6018009185791
# ffmpeg -i 3328ExFo_OutRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3328ExFo_OutRK_HQ_C4.ogv
#
# 0
# 62.8792839050293
# ffmpeg -i 3329ExFo_OutRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3329ExFo_OutRK_MQ_C1.ogv
#
# 0
# 57.7044312953949
# ffmpeg -i 3330ExFo_OutRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3330ExFo_OutRK_MQ_C2.ogv
#
# 0
# 59.318363189697266
# ffmpeg -i 3332ExFo_OutRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3332ExFo_OutRK_MQ_C4.ogv
#
# 0
# 58.87444281578064
# ffmpeg -i 3333ExFo_OutRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3333ExFo_OutRK_LQ_C1.ogv
#
# 0
# 53.825912952423096
# ffmpeg -i 3334ExFo_OutRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3334ExFo_OutRK_LQ_C2.ogv
#
# 0
# 66.80698800086975
# ffmpeg -i 3336ExFo_OutRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3336ExFo_OutRK_LQ_C4.ogv
#
# 0
# 60.52650856971741
# ffmpeg -i 3337Pri_OutFG_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3337Pri_OutFG_C1.ogv
#
# 0
# 133.00526666641235
# ffmpeg -i 3338Pri_OutFG_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3338Pri_OutFG_C2.ogv
#
# 0
# 95.75636076927185
# ffmpeg -i 3385Fo_OutFG_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3385Fo_OutFG_LQ_C2.ogv
#
# 0
# 71.53558945655823
# ffmpeg -i 3388Fo_OutFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3388Fo_OutFG_HQ_C1.ogv
#
# 0
# 70.77938055992126
# ffmpeg -i 3391Fo_OutFG_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3391Fo_OutFG_HQ_C4.ogv
#
# 0
# 73.67435121536255
# ffmpeg -i 3392Fo_OutFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3392Fo_OutFG_MQ_C1.ogv
#
# 0
# 72.95538473129272
# ffmpeg -i 3395Fo_OutFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3395Fo_OutFG_MQ_C4.ogv
#
# 0
# 73.67420649528503
# ffmpeg -i 3396Fo_OutFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3396Fo_OutFG_LQ_C1.ogv
#
# 0
# 67.10488820075989
# ffmpeg -i 3399Fo_OutFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3399Fo_OutFG_LQ_C4.ogv
#
# 0
# 67.17944002151489
# ffmpeg -i 3424ExFo_OutFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3424ExFo_OutFG_HQ_C1.ogv
#
# 0
# 65.66830039024353
# ffmpeg -i 3425ExFo_OutFG_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3425ExFo_OutFG_HQ_C2.ogv
#
# 0
# 66.44510459899902
# ffmpeg -i 3428ExFo_OutFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3428ExFo_OutFG_MQ_C1.ogv
#
# 0
# 67.69973754882812
# ffmpeg -i 3429ExFo_OutFG_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3429ExFo_OutFG_MQ_C2.ogv
#
# 0
# 65.4519534111023
# ffmpeg -i 3432ExFo_OutFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3432ExFo_OutFG_LQ_C1.ogv
#
# 0
# 65.33657836914062
# ffmpeg -i 3433ExFo_OutFG_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3433ExFo_OutFG_LQ_C2.ogv
# 0
# 75.98573517799377
# ffmpeg -i 3436ExFo_OutFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3436ExFo_OutFG_HQ_C1.ogv
#
# 0
# 57.486083030700684
# ffmpeg -i 3439ExFo_OutFG_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3439ExFo_OutFG_HQ_C4.ogv
#
# 0
# 75.34147024154663
# ffmpeg -i 3440ExFo_OutFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3440ExFo_OutFG_MQ_C1.ogv
#
# 0
# 75.17659878730774
# ffmpeg -i 3443ExFo_OutFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3443ExFo_OutFG_MQ_C4.ogv
#
# 0
# 77.38090181350708
# ffmpeg -i 3444ExFo_OutFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3444ExFo_OutFG_LQ_C1.ogv
#
# 0
# 71.5804717540741
# ffmpeg -i 3447ExFo_OutFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3447ExFo_OutFG_LQ_C4.ogv
#
# 0
# 57.53167366981506
# ffmpeg -i 3448Pri_IndPW_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3448Pri_IndPW_C1.ogv
#
# 0
# 97.99965906143188
# ffmpeg -i 3449Pri_IndPW_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3449Pri_IndPW_C2.ogv
#
# 0
# 76.13167929649353
# ffmpeg -i 3463Exp_IndPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3463Exp_IndPW_HQ_C1.ogv
#
# 0
# 62.58806228637695
# ffmpeg -i 3464Exp_IndPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3464Exp_IndPW_HQ_C2.ogv
#
# 0
# 75.69768404960632
# ffmpeg -i 3467Exp_IndPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3467Exp_IndPW_MQ_C1.ogv
#
# 0
# 77.01304793357849
# ffmpeg -i 3468Exp_IndPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3468Exp_IndPW_MQ_C2.ogv
#
# 0
# 71.16821074485779
# ffmpeg -i 3471Exp_IndPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3471Exp_IndPW_LQ_C1.ogv
#
# 0
# 66.16628241539001
# ffmpeg -i 3472Exp_IndPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3472Exp_IndPW_LQ_C2.ogv
#
# 0
# 66.70297193527222
# ffmpeg -i 3475Exp_IndPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3475Exp_IndPW_HQ_C1.ogv
#
# 0
# 69.06689214706421
# ffmpeg -i 3476Exp_IndPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3476Exp_IndPW_HQ_C2.ogv
#
# 0
# 70.0028703212738
# ffmpeg -i 3478Exp_IndPW_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3478Exp_IndPW_HQ_C4.ogv
#
# 0
# 79.91094303131104
# ffmpeg -i 3479Exp_IndPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3479Exp_IndPW_MQ_C1.ogv
#
# 0
# 80.62744545936584
# ffmpeg -i 3480Exp_IndPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3480Exp_IndPW_MQ_C2.ogv
#
# 0
# 72.7351803779602
# ffmpeg -i 3482Exp_IndPW_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3482Exp_IndPW_MQ_C4.ogv
#
# 0
# 63.88169479370117
# ffmpeg -i 3483Exp_IndPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3483Exp_IndPW_LQ_C1.ogv
#
# 0
# 72.46746492385864
# ffmpeg -i 3484Exp_IndPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3484Exp_IndPW_LQ_C2.ogv
#
# 0
# 57.796144008636475
# ffmpeg -i 3486Exp_IndPW_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3486Exp_IndPW_LQ_C4.ogv
#
# 0
# 62.85609483718872
# ffmpeg -i 3488Fo_IndPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3488Fo_IndPW_HQ_C2.ogv
#
# 0
# 66.13244009017944
# ffmpeg -i 3492Fo_IndPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3492Fo_IndPW_MQ_C2.ogv
#
# 0
# 72.19421195983887
# ffmpeg -i 3496Fo_IndPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3496Fo_IndPW_LQ_C2.ogv
#
# 0
# 79.68647527694702
# ffmpeg -i 3511Fo_IndPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3511Fo_IndPW_HQ_C1.ogv
#
# 0
# 63.8592095375061
# ffmpeg -i 3512Fo_IndPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3512Fo_IndPW_HQ_C2.ogv
#
# 0
# 59.576292991638184
# ffmpeg -i 3515Fo_IndPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3515Fo_IndPW_MQ_C1.ogv
#
# 0
# 67.59893465042114
# ffmpeg -i 3516Fo_IndPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3516Fo_IndPW_MQ_C2.ogv
#
# 0
# 64.4120523929596
# ffmpeg -i 3519Fo_IndPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3519Fo_IndPW_LQ_C1.ogv
#
# 0
# 65.51114702224731
# ffmpeg -i 3520Fo_IndPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3520Fo_IndPW_LQ_C2.ogv
#
# 0
# 60.999248027801514
# ffmpeg -i 3547ExFo_IndPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3547ExFo_IndPW_HQ_C1.ogv
#
# 0
# 71.58296322822571
# ffmpeg -i 3548ExFo_IndPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3548ExFo_IndPW_HQ_C2.ogv
#
# 0
# 64.76989245414734
# ffmpeg -i 3550ExFo_IndPW_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3550ExFo_IndPW_HQ_C4.ogv
#
# 0
# 76.36788821220398
# ffmpeg -i 3551ExFo_IndPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3551ExFo_IndPW_MQ_C1.ogv
#
# 0
# 67.39965510368347
# ffmpeg -i 3552ExFo_IndPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3552ExFo_IndPW_MQ_C2.ogv
#
# 0
# 56.99742841720581
# ffmpeg -i 3554ExFo_IndPW_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3554ExFo_IndPW_MQ_C4.ogv
# 0
# 62.39454960823059
# ffmpeg -i 3555ExFo_IndPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3555ExFo_IndPW_LQ_C1.ogv
#
# 0
# 62.35931921005249
# ffmpeg -i 3556ExFo_IndPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3556ExFo_IndPW_LQ_C2.ogv
#
# 0
# 57.69007873535156
# ffmpeg -i 3558ExFo_IndPW_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3558ExFo_IndPW_LQ_C4.ogv
#
# 0
# 57.47665762901306
# ffmpeg -i 3559Pri_IndLPP_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3559Pri_IndLPP_C1.ogv
#
# 0
# 85.55873680114746
# ffmpeg -i 3562Exp_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3562Exp_IndLPP_HQ_C1.ogv
#
# 0
# 62.303844690322876
# ffmpeg -i 3566Exp_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3566Exp_IndLPP_MQ_C1.ogv
#
# 0
# 80.77876257896423
# ffmpeg -i 3570Exp_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3570Exp_IndLPP_LQ_C1.ogv
#
# 0
# 64.41840434074402
# ffmpeg -i 3571Exp_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3571Exp_IndLPP_LQ_C2.ogv
#
# 0
# 57.00964021682739
# ffmpeg -i 3574Exp_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3574Exp_IndLPP_HQ_C1.ogv
#
# 0
# 76.80671644210815
# ffmpeg -i 3575Exp_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3575Exp_IndLPP_HQ_C2.ogv
#
# 0
# 73.9306206703186
# ffmpeg -i 3578Exp_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3578Exp_IndLPP_MQ_C1.ogv
#
# 0
# 75.99972319602966
# ffmpeg -i 3579Exp_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3579Exp_IndLPP_MQ_C2.ogv
#
# 0
# 66.49105501174927
# ffmpeg -i 3581Exp_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3581Exp_IndLPP_MQ_C4.ogv
#
# 0
# 65.8455638885498
# ffmpeg -i 3582Exp_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3582Exp_IndLPP_LQ_C1.ogv
#
# 0
# 58.655678272247314
# ffmpeg -i 3585Exp_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3585Exp_IndLPP_LQ_C4.ogv
#
# 0
# 57.77905821800232
# ffmpeg -i 3586Exp_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3586Exp_IndLPP_HQ_C1.ogv
#
# 0
# 61.565192222595215
# ffmpeg -i 3587Exp_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3587Exp_IndLPP_HQ_C2.ogv
#
# 0
# 68.41939067840576
# ffmpeg -i 3589Exp_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3589Exp_IndLPP_HQ_C4.ogv
#
# 0
# 62.80686163902283
# ffmpeg -i 3590Exp_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3590Exp_IndLPP_MQ_C1.ogv
#
# 0
# 61.814823150634766
# ffmpeg -i 3593Exp_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3593Exp_IndLPP_MQ_C4.ogv
#
# 0
# 62.13035488128662
# ffmpeg -i 3594Exp_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3594Exp_IndLPP_LQ_C1.ogv
#
# 0
# 62.25955891609192
# ffmpeg -i 3598Fo_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3598Fo_IndLPP_HQ_C1.ogv
#
# 0
# 69.70777559280396
# ffmpeg -i 3599Fo_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3599Fo_IndLPP_HQ_C2.ogv
#
# 0
# 67.9808919429779
# ffmpeg -i 3601Fo_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3601Fo_IndLPP_HQ_C4.ogv
#
# 0
# 57.73421669006348
# ffmpeg -i 3602Fo_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3602Fo_IndLPP_MQ_C1.ogv
#
# 0
# 57.197556495666504
# ffmpeg -i 3603Fo_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3603Fo_IndLPP_MQ_C2.ogv
#
# 0
# 51.530945777893066
# ffmpeg -i 3605Fo_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3605Fo_IndLPP_MQ_C4.ogv
#
# 0
# 52.371925354003906
# ffmpeg -i 3606Fo_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3606Fo_IndLPP_LQ_C1.ogv
#
# 0
# 53.14979028701782
# ffmpeg -i 3607Fo_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3607Fo_IndLPP_LQ_C2.ogv
#
# 0
# 50.930116415023804
# ffmpeg -i 3609Fo_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3609Fo_IndLPP_LQ_C4.ogv
#
# 0
# 49.723564863204956
# ffmpeg -i 3613Fo_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3613Fo_IndLPP_HQ_C4.ogv
#
# 0
# 59.101818799972534
# ffmpeg -i 3617Fo_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3617Fo_IndLPP_MQ_C4.ogv
#
# 0
# 51.19125056266785
# ffmpeg -i 3618Fo_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3618Fo_IndLPP_LQ_C1.ogv
#
# 0
# 44.716418504714966
# ffmpeg -i 3621Fo_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3621Fo_IndLPP_LQ_C4.ogv
#
# 0
# 49.19706916809082
# ffmpeg -i 3622Fo_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3622Fo_IndLPP_HQ_C1.ogv
#
# 0
# 63.36369061470032
# ffmpeg -i 3623Fo_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3623Fo_IndLPP_HQ_C2.ogv
#
# 0
# 59.56073474884033
# ffmpeg -i 3626Fo_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3626Fo_IndLPP_MQ_C1.ogv
#
# 0
# 67.4103729724884
# ffmpeg -i 3627Fo_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3627Fo_IndLPP_MQ_C2.ogv
# 0
# 70.61723208427429
# ffmpeg -i 3630Fo_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3630Fo_IndLPP_LQ_C1.ogv
#
# 0
# 58.055809020996094
# ffmpeg -i 3631Fo_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3631Fo_IndLPP_LQ_C2.ogv
#
# 0
# 55.74431228637695
# ffmpeg -i 3634ExFo_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3634ExFo_IndLPP_HQ_C1.ogv
#
# 0
# 62.36036825180054
# ffmpeg -i 3635ExFo_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3635ExFo_IndLPP_HQ_C2.ogv
#
# 0
# 55.32181262969971
# ffmpeg -i 3636ExFo_IndLPP_HQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3636ExFo_IndLPP_HQ_C3.ogv
#
# 0
# 62.023173570632935
# ffmpeg -i 3637ExFo_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3637ExFo_IndLPP_HQ_C4.ogv
#
# 0
# 55.112953186035156
# ffmpeg -i 3638ExFo_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3638ExFo_IndLPP_MQ_C1.ogv
#
# 0
# 56.13751149177551
# ffmpeg -i 3639ExFo_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3639ExFo_IndLPP_MQ_C2.ogv
#
# 0
# 56.51041531562805
# ffmpeg -i 3640ExFo_IndLPP_MQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3640ExFo_IndLPP_MQ_C3.ogv
#
# 0
# 61.01173973083496
# ffmpeg -i 3641ExFo_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3641ExFo_IndLPP_MQ_C4.ogv
#
# 0
# 55.1674120426178
# ffmpeg -i 3642ExFo_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3642ExFo_IndLPP_LQ_C1.ogv
#
# 0
# 64.68795704841614
# ffmpeg -i 3643ExFo_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3643ExFo_IndLPP_LQ_C2.ogv
#
# 0
# 59.14086699485779
# ffmpeg -i 3644ExFo_IndLPP_LQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3644ExFo_IndLPP_LQ_C3.ogv
#
# 0
# 52.11158490180969
# ffmpeg -i 3645ExFo_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3645ExFo_IndLPP_LQ_C4.ogv
#
# 0
# 51.56053328514099
# ffmpeg -i 3646ExFo_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3646ExFo_IndLPP_HQ_C1.ogv
#
# 0
# 49.34932470321655
# ffmpeg -i 3647ExFo_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3647ExFo_IndLPP_HQ_C2.ogv
#
# 0
# 46.91961717605591
# ffmpeg -i 3650ExFo_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3650ExFo_IndLPP_MQ_C1.ogv
#
# 0
# 51.15892958641052
# ffmpeg -i 3651ExFo_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3651ExFo_IndLPP_MQ_C2.ogv
#
# 0
# 46.38264751434326
# ffmpeg -i 3654ExFo_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3654ExFo_IndLPP_LQ_C1.ogv
#
# 0
# 47.44235444068909
# ffmpeg -i 3655ExFo_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3655ExFo_IndLPP_LQ_C2.ogv
#
# 0
# 48.112510681152344
# ffmpeg -i 3658ExFo_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3658ExFo_IndLPP_HQ_C1.ogv
#
# 0
# 46.49211239814758
# ffmpeg -i 3659ExFo_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3659ExFo_IndLPP_HQ_C2.ogv
#
# 0
# 46.225494384765625
# ffmpeg -i 3661ExFo_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3661ExFo_IndLPP_HQ_C4.ogv
#
# 0
# 45.367576122283936
# ffmpeg -i 3662ExFo_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3662ExFo_IndLPP_MQ_C1.ogv
#
# 0
# 49.78876042366028
# ffmpeg -i 3663ExFo_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3663ExFo_IndLPP_MQ_C2.ogv
#
# 0
# 44.2427453994751
# ffmpeg -i 3665ExFo_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3665ExFo_IndLPP_MQ_C4.ogv
#
# 0
# 43.81389856338501
# ffmpeg -i 3666ExFo_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3666ExFo_IndLPP_LQ_C1.ogv
#
# 0
# 46.36203384399414
# ffmpeg -i 3667ExFo_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3667ExFo_IndLPP_LQ_C2.ogv
#
# 0
# 42.9857919216156
# ffmpeg -i 3669ExFo_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3669ExFo_IndLPP_LQ_C4.ogv
#
# 0
# 41.663012981414795
# ffmpeg -i 3673Exp_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3673Exp_IndWL_HQ_C1.ogv
#
# 0
# 50.244755029678345
# ffmpeg -i 3674Exp_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3674Exp_IndWL_HQ_C2.ogv
#
# 0
# 47.71812295913696
# ffmpeg -i 3677Exp_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3677Exp_IndWL_MQ_C1.ogv
#
# 0
# 51.169042348861694
# ffmpeg -i 3678Exp_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3678Exp_IndWL_MQ_C2.ogv
#
# 0
# 51.830469369888306
# ffmpeg -i 3681Exp_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3681Exp_IndWL_LQ_C1.ogv
#
# 0
# 50.03770303726196
# ffmpeg -i 3682Exp_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3682Exp_IndWL_LQ_C2.ogv
#
# 0
# 42.427507400512695
# ffmpeg -i 3685Exp_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3685Exp_IndWL_HQ_C1.ogv
#
# 0
# 46.154131174087524
# ffmpeg -i 3686Exp_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3686Exp_IndWL_HQ_C2.ogv
#
# 0
# 53.812211990356445
# ffmpeg -i 3688Exp_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3688Exp_IndWL_HQ_C4.ogv
# 0
# 44.16849899291992
# ffmpeg -i 3689Exp_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3689Exp_IndWL_MQ_C1.ogv
#
# 0
# 45.55392408370972
# ffmpeg -i 3690Exp_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3690Exp_IndWL_MQ_C2.ogv
#
# 0
# 47.7208936214447
# ffmpeg -i 3692Exp_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3692Exp_IndWL_MQ_C4.ogv
#
# 0
# 44.53674507141113
# ffmpeg -i 3693Exp_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3693Exp_IndWL_LQ_C1.ogv
#
# 0
# 48.75457215309143
# ffmpeg -i 3694Exp_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3694Exp_IndWL_LQ_C2.ogv
#
# 0
# 45.56980609893799
# ffmpeg -i 3696Exp_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3696Exp_IndWL_LQ_C4.ogv
#
# 0
# 49.50407600402832
# ffmpeg -i 3697Exp_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3697Exp_IndWL_HQ_C1.ogv
#
# 0
# 48.83435606956482
# ffmpeg -i 3698Exp_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3698Exp_IndWL_HQ_C2.ogv
#
# 0
# 50.727705240249634
# ffmpeg -i 3700Exp_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3700Exp_IndWL_HQ_C4.ogv
#
# 0
# 42.899407625198364
# ffmpeg -i 3701Exp_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3701Exp_IndWL_MQ_C1.ogv
#
# 0
# 45.28586173057556
# ffmpeg -i 3702Exp_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3702Exp_IndWL_MQ_C2.ogv
#
# 0
# 51.38610076904297
# ffmpeg -i 3705Exp_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3705Exp_IndWL_LQ_C1.ogv
#
# 0
# 48.513139486312866
# ffmpeg -i 3706Exp_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3706Exp_IndWL_LQ_C2.ogv
#
# 0
# 49.42873764038086
# ffmpeg -i 3709Fo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3709Fo_IndWL_HQ_C1.ogv
#
# 0
# 53.88081407546997
# ffmpeg -i 3713Fo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3713Fo_IndWL_MQ_C1.ogv
#
# 0
# 48.1464102268219
# ffmpeg -i 3717Fo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3717Fo_IndWL_LQ_C1.ogv
#
# 0
# 51.040345907211304
# ffmpeg -i 3721Fo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3721Fo_IndWL_HQ_C1.ogv
#
# 0
# 55.01555156707764
# ffmpeg -i 3722Fo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3722Fo_IndWL_HQ_C2.ogv
#
# 0
# 45.7778959274292
# ffmpeg -i 3725Fo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3725Fo_IndWL_MQ_C1.ogv
#
# 0
# 44.75842213630676
# ffmpeg -i 3726Fo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3726Fo_IndWL_MQ_C2.ogv
#
# 0
# 43.32088780403137
# ffmpeg -i 3729Fo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3729Fo_IndWL_LQ_C1.ogv
#
# 0
# 46.09881806373596
# ffmpeg -i 3730Fo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3730Fo_IndWL_LQ_C2.ogv
#
# 0
# 47.81238269805908
# ffmpeg -i 3733Fo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3733Fo_IndWL_HQ_C1.ogv
#
# 0
# 47.84497904777527
# ffmpeg -i 3734Fo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3734Fo_IndWL_HQ_C2.ogv
#
# 0
# 44.4909188747406
# ffmpeg -i 3737Fo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3737Fo_IndWL_MQ_C1.ogv
#
# 0
# 49.914422273635864
# ffmpeg -i 3738Fo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3738Fo_IndWL_MQ_C2.ogv
#
# 0
# 52.82138466835022
# ffmpeg -i 3741Fo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3741Fo_IndWL_LQ_C1.ogv
#
# 0
# 54.79165816307068
# ffmpeg -i 3742Fo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3742Fo_IndWL_LQ_C2.ogv
#
# 0
# 54.41353154182434
# ffmpeg -i 3745ExFo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3745ExFo_IndWL_HQ_C1.ogv
#
# 0
# 55.88588762283325
# ffmpeg -i 3746ExFo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3746ExFo_IndWL_HQ_C2.ogv
#
# 0
# 57.05178880691528
# ffmpeg -i 3747ExFo_IndWL_HQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3747ExFo_IndWL_HQ_C3.ogv
#
# 0
# 57.524005651474
# ffmpeg -i 3748ExFo_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3748ExFo_IndWL_HQ_C4.ogv
#
# 0
# 54.409156799316406
# ffmpeg -i 3749ExFo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3749ExFo_IndWL_MQ_C1.ogv
#
# 0
# 55.230982065200806
# ffmpeg -i 3750ExFo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3750ExFo_IndWL_MQ_C2.ogv
#
# 0
# 59.485488414764404
# ffmpeg -i 3751ExFo_IndWL_MQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3751ExFo_IndWL_MQ_C3.ogv
#
# 0
# 58.67760252952576
# ffmpeg -i 3752ExFo_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3752ExFo_IndWL_MQ_C4.ogv
#
# 0
# 52.38924026489258
# ffmpeg -i 3753ExFo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3753ExFo_IndWL_LQ_C1.ogv
#
# 0
# 50.91503977775574
# ffmpeg -i 3754ExFo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3754ExFo_IndWL_LQ_C2.ogv
# 0
# 45.16511511802673
# ffmpeg -i 3755ExFo_IndWL_LQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3755ExFo_IndWL_LQ_C3.ogv
#
# 0
# 46.16466951370239
# ffmpeg -i 3756ExFo_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3756ExFo_IndWL_LQ_C4.ogv
#
# 0
# 44.73919486999512
# ffmpeg -i 3758ExFo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3758ExFo_IndWL_HQ_C2.ogv
#
# 0
# 50.26544809341431
# ffmpeg -i 3760ExFo_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3760ExFo_IndWL_HQ_C4.ogv
#
# 0
# 44.960241079330444
# ffmpeg -i 3762ExFo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3762ExFo_IndWL_MQ_C2.ogv
#
# 0
# 41.840646743774414
# ffmpeg -i 3764ExFo_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3764ExFo_IndWL_MQ_C4.ogv
#
# 0
# 41.1360239982605
# ffmpeg -i 3766ExFo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3766ExFo_IndWL_LQ_C2.ogv
#
# 0
# 38.294926166534424
# ffmpeg -i 3768ExFo_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3768ExFo_IndWL_LQ_C4.ogv
#
# 0
# 38.56768536567688
# ffmpeg -i 3769ExFo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3769ExFo_IndWL_HQ_C1.ogv
#
# 0
# 39.77477693557739
# ffmpeg -i 3773ExFo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3773ExFo_IndWL_MQ_C1.ogv
#
# 0
# 39.00964975357056
# ffmpeg -i 3777ExFo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3777ExFo_IndWL_LQ_C1.ogv
#
# 0
# 38.422022104263306
# ffmpeg -i 3781Pri_IndPR_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3781Pri_IndPR_C1.ogv
#
# 0
# 61.26119041442871
# ffmpeg -i 3782Pri_IndPR_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3782Pri_IndPR_C2.ogv
#
# 0
# 44.49274134635925
# ffmpeg -i 3784Exp_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3784Exp_IndPR_HQ_C1.ogv
#
# 0
# 39.59104633331299
# ffmpeg -i 3785Exp_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3785Exp_IndPR_HQ_C2.ogv
#
# 0
# 35.01813364028931
# ffmpeg -i 3788Exp_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3788Exp_IndPR_MQ_C1.ogv
#
# 0
# 34.912211418151855
# ffmpeg -i 3789Exp_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3789Exp_IndPR_MQ_C2.ogv
#
# 0
# 32.53780221939087
# ffmpeg -i 3791Exp_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3791Exp_IndPR_MQ_C4.ogv
#
# 0
# 32.77243208885193
# ffmpeg -i 3792Exp_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3792Exp_IndPR_LQ_C1.ogv
#
# 0
# 32.65282201766968
# ffmpeg -i 3793Exp_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3793Exp_IndPR_LQ_C2.ogv
#
# 0
# 29.303921699523926
# ffmpeg -i 3796Exp_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3796Exp_IndPR_HQ_C1.ogv
#
# 0
# 31.69408416748047
# ffmpeg -i 3797Exp_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3797Exp_IndPR_HQ_C2.ogv
#
# 0
# 30.46336078643799
# ffmpeg -i 3799Exp_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3799Exp_IndPR_HQ_C4.ogv
#
# 0
# 30.225982189178467
# ffmpeg -i 3800Exp_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3800Exp_IndPR_MQ_C1.ogv
#
# 0
# 30.775023937225342
# ffmpeg -i 3801Exp_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3801Exp_IndPR_MQ_C2.ogv
#
# 0
# 30.077213048934937
# ffmpeg -i 3803Exp_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3803Exp_IndPR_MQ_C4.ogv
#
# 0
# 29.834169626235962
# ffmpeg -i 3804Exp_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3804Exp_IndPR_LQ_C1.ogv
#
# 0
# 30.88967490196228
# ffmpeg -i 3805Exp_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3805Exp_IndPR_LQ_C2.ogv
#
# 0
# 30.035042762756348
# ffmpeg -i 3807Exp_IndPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3807Exp_IndPR_LQ_C4.ogv
#
# 0
# 29.23032784461975
# ffmpeg -i 3811Exp_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3811Exp_IndPR_HQ_C4.ogv
#
# 0
# 29.503061532974243
# ffmpeg -i 3815Exp_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/3815Exp_IndPR_MQ_C4.ogv
#
# 0
# 28.976210355758667
# ...
#
# 0
# 28.29915690422058
# ffmpeg -i 4089ExFo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4089ExFo_IndPPP_HQ_C1.ogv
#
# 0
# 29.678218364715576
# ffmpeg -i 4093ExFo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4093ExFo_IndPPP_MQ_C1.ogv
#
# 0
# 28.716356992721558
# ffmpeg -i 4097ExFo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4097ExFo_IndPPP_LQ_C1.ogv
#
# 0
# 28.526923418045044
# ffmpeg -i 4101ExFo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4101ExFo_IndPPP_HQ_C1.ogv
#
# 0
# 27.6680006980896
# ffmpeg -i 4102ExFo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4102ExFo_IndPPP_HQ_C2.ogv
#
# 0
# 27.370145559310913
# ffmpeg -i 4104ExFo_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4104ExFo_IndPPP_HQ_C4.ogv
#
# 0
# 28.19982933998108
# ffmpeg -i 4105ExFo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4105ExFo_IndPPP_MQ_C1.ogv
#
# 0
# 28.18501091003418
# ffmpeg -i 4106ExFo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4106ExFo_IndPPP_MQ_C2.ogv
#
# 0
# 27.532756805419922
# ffmpeg -i 4108ExFo_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4108ExFo_IndPPP_MQ_C4.ogv
#
# 0
# 27.34091806411743
# ffmpeg -i 4109ExFo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4109ExFo_IndPPP_LQ_C1.ogv
#
# 0
# 27.721957206726074
# ffmpeg -i 4110ExFo_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4110ExFo_IndPPP_LQ_C2.ogv
#
# 0
# 27.164813995361328
# ffmpeg -i 4112ExFo_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4112ExFo_IndPPP_LQ_C4.ogv
#
# 0
# 26.713902711868286
# ffmpeg -i 4113Pri_IndRK_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4113Pri_IndRK_C1.ogv
#
# 0
# 41.331926345825195
# ffmpeg -i 4114Pri_IndRK_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4114Pri_IndRK_C2.ogv
#
# 0
# 36.063576221466064
# ffmpeg -i 4120Exp_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4120Exp_IndRK_HQ_C4.ogv
#
# 0
# 29.321383953094482
# ffmpeg -i 4124Exp_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4124Exp_IndRK_MQ_C4.ogv
#
# 0
# 28.795509338378906
# ffmpeg -i 4128Exp_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4128Exp_IndRK_LQ_C4.ogv
#
# 0
# 28.177156925201416
# ffmpeg -i 4129Exp_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4129Exp_IndRK_HQ_C1.ogv
#
# 0
# 30.11660885810852
# ffmpeg -i 4130Exp_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4130Exp_IndRK_HQ_C2.ogv
#
# 0
# 29.36184787750244
# ffmpeg -i 4133Exp_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4133Exp_IndRK_MQ_C1.ogv
#
# 0
# 29.72664213180542
# ffmpeg -i 4134Exp_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4134Exp_IndRK_MQ_C2.ogv
#
# 0
# 28.96614098548889
# ffmpeg -i 4137Exp_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4137Exp_IndRK_LQ_C1.ogv
#
# 0
# 29.739707708358765
# ffmpeg -i 4138Exp_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4138Exp_IndRK_LQ_C2.ogv
#
# 0
# 28.612682819366455
# ffmpeg -i 4153Fo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4153Fo_IndRK_HQ_C1.ogv
#
# 0
# 28.958365440368652
# ffmpeg -i 4154Fo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4154Fo_IndRK_HQ_C2.ogv
#
# 0
# 28.408981561660767
# ffmpeg -i 4156Fo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4156Fo_IndRK_HQ_C4.ogv
#
# 0
# 33.52483415603638
# ffmpeg -i 4157Fo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4157Fo_IndRK_MQ_C1.ogv
#
# 0
# 29.67622447013855
# ffmpeg -i 4158Fo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4158Fo_IndRK_MQ_C2.ogv
#
# 0
# 29.056275844573975
# ffmpeg -i 4160Fo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4160Fo_IndRK_MQ_C4.ogv
#
# 0
# 30.71751594543457
# ffmpeg -i 4161Fo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4161Fo_IndRK_LQ_C1.ogv
#
# 0
# 28.902750492095947
# ffmpeg -i 4164Fo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4164Fo_IndRK_LQ_C4.ogv
# 0
# 30.52325463294983
# ffmpeg -i 4165Fo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4165Fo_IndRK_HQ_C1.ogv
#
# 0
# 30.47843337059021
# ffmpeg -i 4166Fo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4166Fo_IndRK_HQ_C2.ogv
#
# 0
# 28.015222311019897
# ffmpeg -i 4169Fo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4169Fo_IndRK_MQ_C1.ogv
#
# 0
# 29.62789511680603
# ffmpeg -i 4170Fo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4170Fo_IndRK_MQ_C2.ogv
#
# 0
# 29.234084129333496
# ffmpeg -i 4173Fo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4173Fo_IndRK_LQ_C1.ogv
#
# 0
# 28.86287522315979
# ffmpeg -i 4174Fo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4174Fo_IndRK_LQ_C2.ogv
#
# 0
# 27.797611236572266
# ffmpeg -i 4177Fo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4177Fo_IndRK_HQ_C1.ogv
#
# 0
# 29.84204649925232
# ffmpeg -i 4178Fo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4178Fo_IndRK_HQ_C2.ogv
#
# 0
# 29.04324722290039
# ffmpeg -i 4180Fo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4180Fo_IndRK_HQ_C4.ogv
#
# 0
# 33.21636605262756
# ffmpeg -i 4181Fo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4181Fo_IndRK_MQ_C1.ogv
#
# 0
# 29.334250450134277
# ffmpeg -i 4182Fo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4182Fo_IndRK_MQ_C2.ogv
#
# 0
# 28.012676239013672
# ffmpeg -i 4184Fo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4184Fo_IndRK_MQ_C4.ogv
#
# 0
# 30.820229530334473
# ffmpeg -i 4185Fo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4185Fo_IndRK_LQ_C1.ogv
#
# 0
# 28.926020622253418
# ffmpeg -i 4186Fo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4186Fo_IndRK_LQ_C2.ogv
#
# 0
# 28.35464572906494
# ffmpeg -i 4188Fo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4188Fo_IndRK_LQ_C4.ogv
#
# 0
# 28.974931478500366
# ffmpeg -i 4189ExFo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4189ExFo_IndRK_HQ_C1.ogv
#
# 0
# 30.28201985359192
# ffmpeg -i 4190ExFo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4190ExFo_IndRK_HQ_C2.ogv
#
# 0
# 28.901524305343628
# ffmpeg -i 4191ExFo_IndRK_HQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4191ExFo_IndRK_HQ_C3.ogv
#
# 0
# 31.128316402435303
# ffmpeg -i 4192ExFo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4192ExFo_IndRK_HQ_C4.ogv
#
# 0
# 28.596519231796265
# ffmpeg -i 4193ExFo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4193ExFo_IndRK_MQ_C1.ogv
#
# 0
# 29.665401458740234
# ffmpeg -i 4194ExFo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4194ExFo_IndRK_MQ_C2.ogv
#
# 0
# 28.26361584663391
# ffmpeg -i 4195ExFo_IndRK_MQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4195ExFo_IndRK_MQ_C3.ogv
#
# 0
# 31.794100284576416
# ffmpeg -i 4196ExFo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4196ExFo_IndRK_MQ_C4.ogv
#
# 0
# 28.433064222335815
# ffmpeg -i 4197ExFo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4197ExFo_IndRK_LQ_C1.ogv
#
# 0
# 30.159419059753418
# ffmpeg -i 4198ExFo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4198ExFo_IndRK_LQ_C2.ogv
#
# 0
# 28.954838275909424
# ffmpeg -i 4199ExFo_IndRK_LQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4199ExFo_IndRK_LQ_C3.ogv
#
# 0
# 31.066946744918823
# ffmpeg -i 4200ExFo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4200ExFo_IndRK_LQ_C4.ogv
#
# 0
# 28.561930418014526
# ffmpeg -i 4213ExFo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4213ExFo_IndRK_HQ_C1.ogv
#
# 0
# 28.24875783920288
# ffmpeg -i 4214ExFo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4214ExFo_IndRK_HQ_C2.ogv
#
# 0
# 27.476443767547607
# ffmpeg -i 4216ExFo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4216ExFo_IndRK_HQ_C4.ogv
#
# 0
# 28.698416233062744
# ffmpeg -i 4217ExFo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4217ExFo_IndRK_MQ_C1.ogv
#
# 0
# 28.67160415649414
# ffmpeg -i 4218ExFo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4218ExFo_IndRK_MQ_C2.ogv
#
# 0
# 28.262659072875977
# ffmpeg -i 4220ExFo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4220ExFo_IndRK_MQ_C4.ogv
#
# 0
# 27.254671812057495
# ffmpeg -i 4221ExFo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4221ExFo_IndRK_LQ_C1.ogv
#
# 0
# 28.570388078689575
# ffmpeg -i 4222ExFo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4222ExFo_IndRK_LQ_C2.ogv
#
# 0
# 27.71458101272583
# ffmpeg -i 4224ExFo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4224ExFo_IndRK_LQ_C4.ogv
#
# 0
# 28.27549648284912
# ffmpeg -i 4269Fo_IndFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4269Fo_IndFG_MQ_C1.ogv
#
# 0
# 31.29066014289856
# ffmpeg -i 4273Fo_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4273Fo_IndFG_LQ_C1.ogv
# 0
# 30.595491647720337
# ffmpeg -i 4290Fo_IndFG_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4290Fo_IndFG_HQ_C2.ogv
#
# 0
# 28.786559581756592
# ffmpeg -i 4294Fo_IndFG_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4294Fo_IndFG_MQ_C2.ogv
#
# 0
# 29.131218194961548
# ffmpeg -i 4297Fo_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4297Fo_IndFG_LQ_C1.ogv
#
# 0
# 29.66492986679077
# ffmpeg -i 4298Fo_IndFG_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/4298Fo_IndFG_LQ_C2.ogv
#
# 0
# 29.045758962631226
# 1623119806.6386964
