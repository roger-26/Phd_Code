# %%
import numpy as np
import os
import time
with open('/home/r/Dropbox/Javeriana/current_work/tracker_prediction/VariacionResolucion_ImpactoTracker/script_convert_2_ogv.txt') as f:
    lines = f.readlines()
os.chdir(r'/home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos')

# %%
for i in range (201,400):
    start = time.time()
    print(lines[i])
    print(os.system(lines[i]))
    end = time.time()
    print(end - start)
end
# Out:
# ffmpeg -i 0482Exp_IndPO_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0482Exp_IndPO_LQ_C2.ogv
#
# 0
# 36.43882656097412
# ffmpeg -i 0484Exp_IndPO_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0484Exp_IndPO_LQ_C4.ogv
#
# 0
# 42.13444542884827
# ffmpeg -i 0485Exp_IndPO_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0485Exp_IndPO_HQ_C1.ogv
#
# 0
# 44.675798654556274
# ffmpeg -i 0486Exp_IndPO_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0486Exp_IndPO_HQ_C2.ogv
#
# 0
# 52.692506074905396
# ffmpeg -i 0488Exp_IndPO_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0488Exp_IndPO_HQ_C4.ogv
#
# 0
# 61.10085868835449
# ffmpeg -i 0489Exp_IndPO_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0489Exp_IndPO_MQ_C1.ogv
#
# 0
# 61.4294707775116
# ffmpeg -i 0492Exp_IndPO_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0492Exp_IndPO_MQ_C4.ogv
#
# 0
# 61.67730379104614
# ffmpeg -i 0493Exp_IndPO_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0493Exp_IndPO_LQ_C1.ogv
#
# 0
# 57.567124366760254
# ffmpeg -i 0496Exp_IndPO_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0496Exp_IndPO_LQ_C4.ogv
#
# 0
# 54.35772514343262
# ffmpeg -i 0512Fo_IndPO_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0512Fo_IndPO_HQ_C4.ogv
#
# 0
# 59.1214644908905
# ffmpeg -i 0516Fo_IndPO_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0516Fo_IndPO_MQ_C4.ogv
#
# 0
# 60.07671022415161
# ffmpeg -i 0520Fo_IndPO_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0520Fo_IndPO_LQ_C4.ogv
#
# 0
# 60.26422905921936
# ffmpeg -i 0581Pri_IndPPP_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0581Pri_IndPPP_C1.ogv
#
# 0
# 74.9005343914032
# ffmpeg -i 0582Pri_IndPPP_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0582Pri_IndPPP_C2.ogv
#
# 0
# 73.27738189697266
# ffmpeg -i 0583Pri_IndPPP_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0583Pri_IndPPP_C4.ogv
#
# 0
# 88.09778428077698
# ffmpeg -i 0584Exp_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0584Exp_IndPPP_HQ_C1.ogv
#
# 0
# 71.06863760948181
# ffmpeg -i 0585Exp_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0585Exp_IndPPP_HQ_C2.ogv
#
# 0
# 76.31525444984436
# ffmpeg -i 0587Exp_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0587Exp_IndPPP_HQ_C4.ogv
#
# 0
# 70.49615573883057
# ffmpeg -i 0588Exp_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0588Exp_IndPPP_MQ_C1.ogv
#
# 0
# 75.25170946121216
# ffmpeg -i 0589Exp_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0589Exp_IndPPP_MQ_C2.ogv
#
# 0
# 73.3012285232544
# ffmpeg -i 0591Exp_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0591Exp_IndPPP_MQ_C4.ogv
#
# 0
# 68.31008768081665
# ffmpeg -i 0592Exp_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0592Exp_IndPPP_LQ_C1.ogv
#
# 0
# 59.80083775520325
# ffmpeg -i 0593Exp_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0593Exp_IndPPP_LQ_C2.ogv
#
# 0
# 71.0228099822998
# ffmpeg -i 0595Exp_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0595Exp_IndPPP_LQ_C4.ogv
#
# 0
# 64.54836773872375
# ffmpeg -i 0596Exp_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0596Exp_IndPPP_HQ_C1.ogv
#
# 0
# 66.40896463394165
# ffmpeg -i 0597Exp_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0597Exp_IndPPP_HQ_C2.ogv
#
# 0
# 62.69496178627014
# ffmpeg -i 0599Exp_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0599Exp_IndPPP_HQ_C4.ogv
#
# 0
# 62.493776082992554
# ffmpeg -i 0600Exp_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0600Exp_IndPPP_MQ_C1.ogv
#
# 0
# 64.71570134162903
# ffmpeg -i 0601Exp_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0601Exp_IndPPP_MQ_C2.ogv
#
# 0
# 59.01909637451172
# ffmpeg -i 0603Exp_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0603Exp_IndPPP_MQ_C4.ogv
#
# 0
# 62.998603105545044
# ffmpeg -i 0604Exp_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0604Exp_IndPPP_LQ_C1.ogv
#
# 0
# 63.73712134361267
# ffmpeg -i 0605Exp_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0605Exp_IndPPP_LQ_C2.ogv
#
# 0
# 61.36710238456726
# ffmpeg -i 0607Exp_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0607Exp_IndPPP_LQ_C4.ogv
#
# 0
# 64.8387291431427
# ffmpeg -i 0608Exp_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0608Exp_IndPPP_HQ_C1.ogv
#
# 0
# 66.31019020080566
# ffmpeg -i 0609Exp_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0609Exp_IndPPP_HQ_C2.ogv
#
# 0
# 69.40948462486267
# ffmpeg -i 0611Exp_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0611Exp_IndPPP_HQ_C4.ogv
#
# 0
# 64.05613112449646
# ffmpeg -i 0612Exp_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0612Exp_IndPPP_MQ_C1.ogv
#
# 0
# 62.93584752082825
# ffmpeg -i 0613Exp_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0613Exp_IndPPP_MQ_C2.ogv
# 0
# 62.500107526779175
# ffmpeg -i 0615Exp_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0615Exp_IndPPP_MQ_C4.ogv
#
# 0
# 65.80003929138184
# ffmpeg -i 0616Exp_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0616Exp_IndPPP_LQ_C1.ogv
#
# 0
# 70.75458145141602
# ffmpeg -i 0617Exp_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0617Exp_IndPPP_LQ_C2.ogv
#
# 0
# 62.4504132270813
# ffmpeg -i 0619Exp_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0619Exp_IndPPP_LQ_C4.ogv
#
# 0
# 70.41516256332397
# ffmpeg -i 0620Fo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0620Fo_IndPPP_HQ_C1.ogv
#
# 0
# 69.2593514919281
# ffmpeg -i 0621Fo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0621Fo_IndPPP_HQ_C2.ogv
#
# 0
# 63.713470458984375
# ffmpeg -i 0622Fo_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0622Fo_IndPPP_HQ_C4.ogv
#
# 0
# 65.428142786026
# ffmpeg -i 0623Fo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0623Fo_IndPPP_MQ_C1.ogv
#
# 0
# 70.32765889167786
# ffmpeg -i 0624Fo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0624Fo_IndPPP_MQ_C2.ogv
#
# 0
# 70.19343256950378
# ffmpeg -i 0625Fo_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0625Fo_IndPPP_MQ_C4.ogv
#
# 0
# 77.95917201042175
# ffmpeg -i 0626Fo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0626Fo_IndPPP_LQ_C1.ogv
#
# 0
# 71.88988590240479
# ffmpeg -i 0627Fo_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0627Fo_IndPPP_LQ_C2.ogv
#
# 0
# 60.594810485839844
# ffmpeg -i 0628Fo_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0628Fo_IndPPP_LQ_C4.ogv
#
# 0
# 65.94585704803467
# ffmpeg -i 0629Fo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0629Fo_IndPPP_HQ_C1.ogv
#
# 0
# 57.901652574539185
# ffmpeg -i 0630Fo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0630Fo_IndPPP_HQ_C2.ogv
#
# 0
# 61.91736364364624
# ffmpeg -i 0632Fo_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0632Fo_IndPPP_HQ_C4.ogv
#
# 0
# 68.74641990661621
# ffmpeg -i 0633Fo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0633Fo_IndPPP_MQ_C1.ogv
#
# 0
# 72.26218342781067
# ffmpeg -i 0634Fo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0634Fo_IndPPP_MQ_C2.ogv
#
# 0
# 62.72629952430725
# ffmpeg -i 0636Fo_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0636Fo_IndPPP_MQ_C4.ogv
#
# 0
# 64.69902634620667
# ffmpeg -i 0637Fo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0637Fo_IndPPP_LQ_C1.ogv
#
# 0
# 67.33934736251831
# ffmpeg -i 0638Fo_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0638Fo_IndPPP_LQ_C2.ogv
#
# 0
# 59.361098766326904
# ffmpeg -i 0640Fo_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0640Fo_IndPPP_LQ_C4.ogv
#
# 0
# 64.67171740531921
# ffmpeg -i 0641Fo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0641Fo_IndPPP_HQ_C1.ogv
#
# 0
# 66.97623920440674
# ffmpeg -i 0642Fo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0642Fo_IndPPP_HQ_C2.ogv
#
# 0
# 65.37155151367188
# ffmpeg -i 0645Fo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0645Fo_IndPPP_MQ_C1.ogv
#
# 0
# 79.36326241493225
# ffmpeg -i 0646Fo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0646Fo_IndPPP_MQ_C2.ogv
#
# 0
# 69.64408898353577
# ffmpeg -i 0649Fo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0649Fo_IndPPP_LQ_C1.ogv
#
# 0
# 61.353432178497314
# ffmpeg -i 0650Fo_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0650Fo_IndPPP_LQ_C2.ogv
#
# 0
# 60.27701282501221
# ffmpeg -i 0656ExFo_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0656ExFo_IndPPP_HQ_C4.ogv
#
# 0
# 70.18460512161255
# ffmpeg -i 0660ExFo_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0660ExFo_IndPPP_MQ_C4.ogv
#
# 0
# 65.10966324806213
# ffmpeg -i 0661ExFo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0661ExFo_IndPPP_LQ_C1.ogv
#
# 0
# 64.94837737083435
# ffmpeg -i 0664ExFo_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0664ExFo_IndPPP_LQ_C4.ogv
#
# 0
# 72.91136002540588
# ffmpeg -i 0665ExFo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0665ExFo_IndPPP_HQ_C1.ogv
#
# 0
# 66.09193277359009
# ffmpeg -i 0666ExFo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0666ExFo_IndPPP_HQ_C2.ogv
#
# 0
# 65.0259382724762
# ffmpeg -i 0668ExFo_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0668ExFo_IndPPP_HQ_C4.ogv
#
# 0
# 63.06451153755188
# ffmpeg -i 0669ExFo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0669ExFo_IndPPP_MQ_C1.ogv
#
# 0
# 61.79405355453491
# ffmpeg -i 0670ExFo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0670ExFo_IndPPP_MQ_C2.ogv
#
# 0
# 54.5127637386322
# ffmpeg -i 0672ExFo_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0672ExFo_IndPPP_MQ_C4.ogv
# 0
# 58.826664686203
# ffmpeg -i 0673ExFo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0673ExFo_IndPPP_LQ_C1.ogv
#
# 0
# 62.187352418899536
# ffmpeg -i 0674ExFo_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0674ExFo_IndPPP_LQ_C2.ogv
#
# 0
# 56.05318593978882
# ffmpeg -i 0676ExFo_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0676ExFo_IndPPP_LQ_C4.ogv
#
# 0
# 67.59052014350891
# ffmpeg -i 0677ExFo_IndPPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0677ExFo_IndPPP_HQ_C1.ogv
#
# 0
# 66.5085973739624
# ffmpeg -i 0678ExFo_IndPPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0678ExFo_IndPPP_HQ_C2.ogv
#
# 0
# 69.55687284469604
# ffmpeg -i 0680ExFo_IndPPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0680ExFo_IndPPP_HQ_C4.ogv
#
# 0
# 67.20325183868408
# ffmpeg -i 0681ExFo_IndPPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0681ExFo_IndPPP_MQ_C1.ogv
#
# 0
# 58.99835157394409
# ffmpeg -i 0682ExFo_IndPPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0682ExFo_IndPPP_MQ_C2.ogv
#
# 0
# 55.34110498428345
# ffmpeg -i 0684ExFo_IndPPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0684ExFo_IndPPP_MQ_C4.ogv
#
# 0
# 56.59367084503174
# ffmpeg -i 0685ExFo_IndPPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0685ExFo_IndPPP_LQ_C1.ogv
#
# 0
# 61.03485417366028
# ffmpeg -i 0686ExFo_IndPPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0686ExFo_IndPPP_LQ_C2.ogv
#
# 0
# 54.59376668930054
# ffmpeg -i 0688ExFo_IndPPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0688ExFo_IndPPP_LQ_C4.ogv
#
# 0
# 58.36329126358032
# ffmpeg -i 0689Pri_IndRK_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0689Pri_IndRK_C1.ogv
#
# 0
# 74.88643646240234
# ffmpeg -i 0690Pri_IndRK_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0690Pri_IndRK_C2.ogv
#
# 0
# 68.86115097999573
# ffmpeg -i 0691Pri_IndRK_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0691Pri_IndRK_C4.ogv
#
# 0
# 86.6222026348114
# ffmpeg -i 0692Exp_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0692Exp_IndRK_HQ_C1.ogv
#
# 0
# 63.27495980262756
# ffmpeg -i 0693Exp_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0693Exp_IndRK_HQ_C2.ogv
#
# 0
# 73.787677526474
# ffmpeg -i 0695Exp_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0695Exp_IndRK_HQ_C4.ogv
#
# 0
# 73.64717292785645
# ffmpeg -i 0696Exp_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0696Exp_IndRK_MQ_C1.ogv
#
# 0
# 74.48926258087158
# ffmpeg -i 0697Exp_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0697Exp_IndRK_MQ_C2.ogv
#
# 0
# 76.21077680587769
# ffmpeg -i 0699Exp_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0699Exp_IndRK_MQ_C4.ogv
#
# 0
# 67.97026538848877
# ffmpeg -i 0700Exp_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0700Exp_IndRK_LQ_C1.ogv
#
# 0
# 68.1511561870575
# ffmpeg -i 0701Exp_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0701Exp_IndRK_LQ_C2.ogv
#
# 0
# 59.18613004684448
# ffmpeg -i 0703Exp_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0703Exp_IndRK_LQ_C4.ogv
#
# 0
# 58.63619112968445
# ffmpeg -i 0704Exp_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0704Exp_IndRK_HQ_C1.ogv
#
# 0
# 58.99752926826477
# ffmpeg -i 0708Exp_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0708Exp_IndRK_MQ_C1.ogv
#
# 0
# 62.7219603061676
# ffmpeg -i 0712Exp_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0712Exp_IndRK_LQ_C1.ogv
#
# 0
# 58.66409254074097
# ffmpeg -i 0713Exp_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0713Exp_IndRK_LQ_C2.ogv
#
# 0
# 56.372568130493164
# ffmpeg -i 0716Exp_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0716Exp_IndRK_HQ_C1.ogv
#
# 0
# 59.9169807434082
# ffmpeg -i 0717Exp_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0717Exp_IndRK_HQ_C2.ogv
#
# 0
# 57.23759865760803
# ffmpeg -i 0719Exp_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0719Exp_IndRK_HQ_C4.ogv
#
# 0
# 59.216959714889526
# ffmpeg -i 0720Exp_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0720Exp_IndRK_MQ_C1.ogv
#
# 0
# 56.29680299758911
# ffmpeg -i 0721Exp_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0721Exp_IndRK_MQ_C2.ogv
#
# 0
# 50.64962935447693
# ffmpeg -i 0723Exp_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0723Exp_IndRK_MQ_C4.ogv
#
# 0
# 49.674668312072754
# ffmpeg -i 0724Exp_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0724Exp_IndRK_LQ_C1.ogv
#
# 0
# 46.52426624298096
# ffmpeg -i 0725Exp_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0725Exp_IndRK_LQ_C2.ogv
#
# 0
# 51.2815318107605
# ffmpeg -i 0727Exp_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0727Exp_IndRK_LQ_C4.ogv
#
# 0
# 46.52311944961548
# ffmpeg -i 0728Fo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0728Fo_IndRK_HQ_C1.ogv
# 0
# 47.803232192993164
# ffmpeg -i 0729Fo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0729Fo_IndRK_HQ_C2.ogv
#
# 0
# 47.13523888587952
# ffmpeg -i 0731Fo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0731Fo_IndRK_HQ_C4.ogv
#
# 0
# 51.04002547264099
# ffmpeg -i 0732Fo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0732Fo_IndRK_MQ_C1.ogv
#
# 0
# 45.12078619003296
# ffmpeg -i 0733Fo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0733Fo_IndRK_MQ_C2.ogv
#
# 0
# 49.64097189903259
# ffmpeg -i 0735Fo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0735Fo_IndRK_MQ_C4.ogv
#
# 0
# 50.613911390304565
# ffmpeg -i 0736Fo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0736Fo_IndRK_LQ_C1.ogv
#
# 0
# 44.82630157470703
# ffmpeg -i 0737Fo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0737Fo_IndRK_LQ_C2.ogv
#
# 0
# 63.962015867233276
# ffmpeg -i 0739Fo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0739Fo_IndRK_LQ_C4.ogv
#
# 0
# 58.6977596282959
# ffmpeg -i 0740Fo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0740Fo_IndRK_HQ_C1.ogv
#
# 0
# 66.23514294624329
# ffmpeg -i 0741Fo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0741Fo_IndRK_HQ_C2.ogv
#
# 0
# 59.8336980342865
# ffmpeg -i 0744Fo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0744Fo_IndRK_MQ_C1.ogv
#
# 0
# 58.27417278289795
# ffmpeg -i 0745Fo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0745Fo_IndRK_MQ_C2.ogv
#
# 0
# 59.67766714096069
# ffmpeg -i 0748Fo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0748Fo_IndRK_LQ_C1.ogv
#
# 0
# 61.19306135177612
# ffmpeg -i 0749Fo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0749Fo_IndRK_LQ_C2.ogv
#
# 0
# 54.44844055175781
# ffmpeg -i 0751Fo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0751Fo_IndRK_LQ_C4.ogv
#
# 0
# 64.69809222221375
# ffmpeg -i 0752Fo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0752Fo_IndRK_HQ_C1.ogv
#
# 0
# 58.44263672828674
# ffmpeg -i 0753Fo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0753Fo_IndRK_HQ_C2.ogv
#
# 0
# 58.293071269989014
# ffmpeg -i 0756Fo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0756Fo_IndRK_MQ_C2.ogv
#
# 0
# 54.47746753692627
# ffmpeg -i 0759Fo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0759Fo_IndRK_LQ_C2.ogv
#
# 0
# 55.47975182533264
# ffmpeg -i 0761ExFo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0761ExFo_IndRK_HQ_C1.ogv
#
# 0
# 58.33189034461975
# ffmpeg -i 0762ExFo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0762ExFo_IndRK_HQ_C2.ogv
#
# 0
# 54.84103083610535
# ffmpeg -i 0764ExFo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0764ExFo_IndRK_HQ_C4.ogv
#
# 0
# 57.651530504226685
# ffmpeg -i 0765ExFo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0765ExFo_IndRK_MQ_C1.ogv
#
# 0
# 58.155471324920654
# ffmpeg -i 0766ExFo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0766ExFo_IndRK_MQ_C2.ogv
#
# 0
# 51.11147904396057
# ffmpeg -i 0768ExFo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0768ExFo_IndRK_MQ_C4.ogv
#
# 0
# 45.39962077140808
# ffmpeg -i 0769ExFo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0769ExFo_IndRK_LQ_C1.ogv
#
# 0
# 48.65101361274719
# ffmpeg -i 0770ExFo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0770ExFo_IndRK_LQ_C2.ogv
#
# 0
# 46.32375144958496
# ffmpeg -i 0772ExFo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0772ExFo_IndRK_LQ_C4.ogv
#
# 0
# 48.74968194961548
# ffmpeg -i 0773ExFo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0773ExFo_IndRK_HQ_C1.ogv
#
# 0
# 57.61450815200806
# ffmpeg -i 0774ExFo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0774ExFo_IndRK_HQ_C2.ogv
#
# 0
# 44.46007776260376
# ffmpeg -i 0776ExFo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0776ExFo_IndRK_HQ_C4.ogv
#
# 0
# 43.198649883270264
# ffmpeg -i 0777ExFo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0777ExFo_IndRK_MQ_C1.ogv
#
# 0
# 42.65632390975952
# ffmpeg -i 0778ExFo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0778ExFo_IndRK_MQ_C2.ogv
#
# 0
# 45.43949055671692
# ffmpeg -i 0780ExFo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0780ExFo_IndRK_MQ_C4.ogv
#
# 0
# 44.577603340148926
# ffmpeg -i 0781ExFo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0781ExFo_IndRK_LQ_C1.ogv
#
# 0
# 42.522454500198364
# ffmpeg -i 0782ExFo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0782ExFo_IndRK_LQ_C2.ogv
#
# 0
# 46.8189263343811
# ffmpeg -i 0784ExFo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0784ExFo_IndRK_LQ_C4.ogv
#
# 0
# 42.28609800338745
# ffmpeg -i 0785ExFo_IndRK_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0785ExFo_IndRK_HQ_C1.ogv
# 0
# 47.027217626571655
# ffmpeg -i 0786ExFo_IndRK_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0786ExFo_IndRK_HQ_C2.ogv
#
# 0
# 43.75372004508972
# ffmpeg -i 0788ExFo_IndRK_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0788ExFo_IndRK_HQ_C4.ogv
#
# 0
# 44.228554487228394
# ffmpeg -i 0789ExFo_IndRK_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0789ExFo_IndRK_MQ_C1.ogv
#
# 0
# 42.19112515449524
# ffmpeg -i 0790ExFo_IndRK_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0790ExFo_IndRK_MQ_C2.ogv
#
# 0
# 43.912516355514526
# ffmpeg -i 0792ExFo_IndRK_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0792ExFo_IndRK_MQ_C4.ogv
#
# 0
# 43.82132053375244
# ffmpeg -i 0793ExFo_IndRK_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0793ExFo_IndRK_LQ_C1.ogv
#
# 0
# 46.19489145278931
# ffmpeg -i 0794ExFo_IndRK_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0794ExFo_IndRK_LQ_C2.ogv
#
# 0
# 41.977965354919434
# ffmpeg -i 0796ExFo_IndRK_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0796ExFo_IndRK_LQ_C4.ogv
#
# 0
# 48.03900623321533
# ffmpeg -i 0807Exp_IndFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0807Exp_IndFG_MQ_C4.ogv
#
# 0
# 45.6404025554657
# ffmpeg -i 0812Exp_IndFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0812Exp_IndFG_HQ_C1.ogv
#
# 0
# 46.33218026161194
# ffmpeg -i 0815Exp_IndFG_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0815Exp_IndFG_HQ_C4.ogv
#
# 0
# 44.17355823516846
# ffmpeg -i 0816Exp_IndFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0816Exp_IndFG_MQ_C1.ogv
#
# 0
# 51.92784237861633
# ffmpeg -i 0819Exp_IndFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0819Exp_IndFG_MQ_C4.ogv
#
# 0
# 43.12750792503357
# ffmpeg -i 0820Exp_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0820Exp_IndFG_LQ_C1.ogv
#
# 0
# 46.1381561756134
# ffmpeg -i 0823Exp_IndFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0823Exp_IndFG_LQ_C4.ogv
#
# 0
# 45.09296774864197
# ffmpeg -i 0824Exp_IndFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0824Exp_IndFG_HQ_C1.ogv
#
# 0
# 46.75684642791748
# ffmpeg -i 0828Exp_IndFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0828Exp_IndFG_MQ_C1.ogv
#
# 0
# 45.26150035858154
# ffmpeg -i 0832Exp_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0832Exp_IndFG_LQ_C1.ogv
#
# 0
# 48.811466217041016
# ffmpeg -i 0836Fo_IndFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0836Fo_IndFG_HQ_C1.ogv
#
# 0
# 53.39470982551575
# ffmpeg -i 0837Fo_IndFG_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0837Fo_IndFG_HQ_C2.ogv
#
# 0
# 48.31385040283203
# ffmpeg -i 0838Fo_IndFG_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0838Fo_IndFG_HQ_C4.ogv
#
# 0
# 49.387943506240845
# ffmpeg -i 0839Fo_IndFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0839Fo_IndFG_MQ_C1.ogv
#
# 0
# 47.070250272750854
# ffmpeg -i 0840Fo_IndFG_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0840Fo_IndFG_MQ_C2.ogv
#
# 0
# 42.933021068573
# ffmpeg -i 0841Fo_IndFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0841Fo_IndFG_MQ_C4.ogv
#
# 0
# 44.95004057884216
# ffmpeg -i 0842Fo_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0842Fo_IndFG_LQ_C1.ogv
#
# 0
# 45.510870695114136
# ffmpeg -i 0843Fo_IndFG_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0843Fo_IndFG_LQ_C2.ogv
#
# 0
# 44.45149278640747
# ffmpeg -i 0844Fo_IndFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0844Fo_IndFG_LQ_C4.ogv
#
# 0
# 46.34325385093689
# ffmpeg -i 0845Fo_IndFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0845Fo_IndFG_HQ_C1.ogv
#
# 0
# 50.89963340759277
# ffmpeg -i 0846Fo_IndFG_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0846Fo_IndFG_HQ_C2.ogv
#
# 0
# 47.54271602630615
# ffmpeg -i 0848Fo_IndFG_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0848Fo_IndFG_HQ_C4.ogv
#
# 0
# 47.80813217163086
# ffmpeg -i 0849Fo_IndFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0849Fo_IndFG_MQ_C1.ogv
#
# 0
# 53.04387068748474
# ffmpeg -i 0850Fo_IndFG_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0850Fo_IndFG_MQ_C2.ogv
#
# 0
# 47.09781765937805
# ffmpeg -i 0852Fo_IndFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0852Fo_IndFG_MQ_C4.ogv
#
# 0
# 48.203439474105835
# ffmpeg -i 0853Fo_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0853Fo_IndFG_LQ_C1.ogv
#
# 0
# 49.5869722366333
# ffmpeg -i 0854Fo_IndFG_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0854Fo_IndFG_LQ_C2.ogv
#
# 0
# 45.48692321777344
# ffmpeg -i 0856Fo_IndFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0856Fo_IndFG_LQ_C4.ogv
#
# 0
# 47.56205105781555
# ffmpeg -i 0866ExFo_IndFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0866ExFo_IndFG_HQ_C1.ogv
#
# 0
# 53.37767839431763
# ffmpeg -i 0867ExFo_IndFG_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0867ExFo_IndFG_HQ_C2.ogv
# 0
# 60.922492265701294
# ffmpeg -i 0869ExFo_IndFG_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0869ExFo_IndFG_HQ_C4.ogv
#
# 0
# 56.56089639663696
# ffmpeg -i 0870ExFo_IndFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0870ExFo_IndFG_MQ_C1.ogv
#
# 0
# 53.82763171195984
# ffmpeg -i 0871ExFo_IndFG_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0871ExFo_IndFG_MQ_C2.ogv
#
# 0
# 56.90135216712952
# ffmpeg -i 0873ExFo_IndFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0873ExFo_IndFG_MQ_C4.ogv
#
# 0
# 56.341034173965454
# ffmpeg -i 0874ExFo_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0874ExFo_IndFG_LQ_C1.ogv
#
# 0
# 64.69422030448914
# ffmpeg -i 0875ExFo_IndFG_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0875ExFo_IndFG_LQ_C2.ogv
#
# 0
# 58.176650285720825
# ffmpeg -i 0877ExFo_IndFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0877ExFo_IndFG_LQ_C4.ogv
#
# 0
# 63.3697075843811
# ffmpeg -i 0878ExFo_IndFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0878ExFo_IndFG_HQ_C1.ogv
#
# 0
# 64.03769540786743
# ffmpeg -i 0879ExFo_IndFG_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0879ExFo_IndFG_HQ_C2.ogv
#
# 0
# 53.62978768348694
# 1623113803.3686361
