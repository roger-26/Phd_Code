# %%
import numpy as np
import os
import time



with open('/home/r/Dropbox/Javeriana/current_work/tracker_prediction/VariacionResolucion_ImpactoTracker/script_convert_2_ogv.txt') as f:
    lines = f.readlines()


os.chdir(r'/home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos')

# %%
for i in range (401,600):
    start = time.time()
    print(lines[i])
    print(os.system(lines[i]))
    end = time.time()
    print(end - start)
end
# Out:
# ffmpeg -i 0882ExFo_IndFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0882ExFo_IndFG_MQ_C1.ogv
#
# 0
# 43.54798221588135
# ffmpeg -i 0883ExFo_IndFG_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0883ExFo_IndFG_MQ_C2.ogv
#
# 0
# 42.81826400756836
# ffmpeg -i 0885ExFo_IndFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0885ExFo_IndFG_MQ_C4.ogv
#
# 0
# 52.518083333969116
# ffmpeg -i 0886ExFo_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0886ExFo_IndFG_LQ_C1.ogv
#
# 0
# 61.79505681991577
# ffmpeg -i 0887ExFo_IndFG_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0887ExFo_IndFG_LQ_C2.ogv
#
# 0
# 58.94920754432678
# ffmpeg -i 0889ExFo_IndFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0889ExFo_IndFG_LQ_C4.ogv
#
# 0
# 62.99107360839844
# ffmpeg -i 0890ExFo_IndFG_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0890ExFo_IndFG_HQ_C1.ogv
#
# 0
# 58.21252417564392
# ffmpeg -i 0891ExFo_IndFG_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0891ExFo_IndFG_HQ_C2.ogv
#
# 0
# 57.20292925834656
# ffmpeg -i 0893ExFo_IndFG_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0893ExFo_IndFG_HQ_C4.ogv
#
# 0
# 58.99654841423035
# ffmpeg -i 0894ExFo_IndFG_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0894ExFo_IndFG_MQ_C1.ogv
#
# 0
# 63.20206332206726
# ffmpeg -i 0895ExFo_IndFG_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0895ExFo_IndFG_MQ_C2.ogv
#
# 0
# 61.137813329696655
# ffmpeg -i 0897ExFo_IndFG_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0897ExFo_IndFG_MQ_C4.ogv
#
# 0
# 59.01610827445984
# ffmpeg -i 0898ExFo_IndFG_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0898ExFo_IndFG_LQ_C1.ogv
#
# 0
# 59.2943594455719
# ffmpeg -i 0899ExFo_IndFG_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0899ExFo_IndFG_LQ_C2.ogv
#
# 0
# 61.76517677307129
# ffmpeg -i 0901ExFo_IndFG_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0901ExFo_IndFG_LQ_C4.ogv
#
# 0
# 56.687328577041626
# ffmpeg -i 0902Pri_OutPW_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0902Pri_OutPW_C1.ogv
#
# 0
# 124.6828875541687
# ffmpeg -i 0903Pri_OutPW_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0903Pri_OutPW_C2.ogv
#
# 0
# 97.09158492088318
# ffmpeg -i 0905Exp_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0905Exp_OutPW_HQ_C1.ogv
#
# 0
# 91.20897221565247
# ffmpeg -i 0906Exp_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0906Exp_OutPW_HQ_C2.ogv
#
# 0
# 76.54424524307251
# ffmpeg -i 0908Exp_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0908Exp_OutPW_MQ_C1.ogv
#
# 0
# 74.15281963348389
# ffmpeg -i 0909Exp_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0909Exp_OutPW_MQ_C2.ogv
#
# 0
# 65.5437695980072
# ffmpeg -i 0911Exp_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0911Exp_OutPW_LQ_C1.ogv
#
# 0
# 69.0058913230896
# ffmpeg -i 0912Exp_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0912Exp_OutPW_LQ_C2.ogv
#
# 0
# 58.658015966415405
# ffmpeg -i 0914Exp_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0914Exp_OutPW_HQ_C1.ogv
#
# 0
# 91.82244205474854
# ffmpeg -i 0915Exp_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0915Exp_OutPW_HQ_C2.ogv
#
# 0
# 72.1480941772461
# ffmpeg -i 0918Exp_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0918Exp_OutPW_MQ_C1.ogv
#
# 0
# 76.55228614807129
# ffmpeg -i 0919Exp_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0919Exp_OutPW_MQ_C2.ogv
#
# 0
# 72.52847504615784
# ffmpeg -i 0922Exp_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0922Exp_OutPW_LQ_C1.ogv
#
# 0
# 79.51546669006348
# ffmpeg -i 0923Exp_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0923Exp_OutPW_LQ_C2.ogv
#
# 0
# 68.0284903049469
# ffmpeg -i 0926Exp_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0926Exp_OutPW_HQ_C1.ogv
#
# 0
# 77.49102783203125
# ffmpeg -i 0930Exp_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0930Exp_OutPW_MQ_C1.ogv
#
# 0
# 76.37621283531189
# ffmpeg -i 0934Exp_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0934Exp_OutPW_LQ_C1.ogv
#
# 0
# 83.72242164611816
# ffmpeg -i 0938Fo_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0938Fo_OutPW_HQ_C1.ogv
#
# 0
# 72.7835431098938
# ffmpeg -i 0939Fo_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0939Fo_OutPW_HQ_C2.ogv
#
# 0
# 67.94059824943542
# ffmpeg -i 0941Fo_OutPW_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0941Fo_OutPW_HQ_C4.ogv
#
# 0
# 76.45513367652893
# ffmpeg -i 0942Fo_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0942Fo_OutPW_MQ_C1.ogv
#
# 0
# 68.45969533920288
# ffmpeg -i 0943Fo_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0943Fo_OutPW_MQ_C2.ogv
#
# 0
# 69.31862545013428
# ffmpeg -i 0945Fo_OutPW_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0945Fo_OutPW_MQ_C4.ogv
#
# 0
# 68.96471500396729
# ffmpeg -i 0946Fo_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0946Fo_OutPW_LQ_C1.ogv
# 0
# 67.46988034248352
# ffmpeg -i 0947Fo_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0947Fo_OutPW_LQ_C2.ogv
#
# 0
# 66.38447403907776
# ffmpeg -i 0949Fo_OutPW_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0949Fo_OutPW_LQ_C4.ogv
#
# 0
# 67.33975863456726
# ffmpeg -i 0950Fo_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0950Fo_OutPW_HQ_C1.ogv
#
# 0
# 74.77631664276123
# ffmpeg -i 0951Fo_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0951Fo_OutPW_HQ_C2.ogv
#
# 0
# 71.85688972473145
# ffmpeg -i 0953Fo_OutPW_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0953Fo_OutPW_HQ_C4.ogv
#
# 0
# 79.31532692909241
# ffmpeg -i 0954Fo_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0954Fo_OutPW_MQ_C1.ogv
#
# 0
# 72.90876865386963
# ffmpeg -i 0955Fo_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0955Fo_OutPW_MQ_C2.ogv
#
# 0
# 63.841471433639526
# ffmpeg -i 0957Fo_OutPW_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0957Fo_OutPW_MQ_C4.ogv
#
# 0
# 60.46232771873474
# ffmpeg -i 0958Fo_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0958Fo_OutPW_LQ_C1.ogv
#
# 0
# 61.70675539970398
# ffmpeg -i 0959Fo_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0959Fo_OutPW_LQ_C2.ogv
#
# 0
# 57.88442826271057
# ffmpeg -i 0965Fo_OutPW_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0965Fo_OutPW_HQ_C4.ogv
#
# 0
# 61.21232199668884
# ffmpeg -i 0974ExFo_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0974ExFo_OutPW_HQ_C1.ogv
#
# 0
# 71.76429033279419
# ffmpeg -i 0975ExFo_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0975ExFo_OutPW_HQ_C2.ogv
#
# 0
# 73.67989468574524
# ffmpeg -i 0978ExFo_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0978ExFo_OutPW_MQ_C1.ogv
#
# 0
# 73.47885179519653
# ffmpeg -i 0979ExFo_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0979ExFo_OutPW_MQ_C2.ogv
#
# 0
# 64.0852780342102
# ffmpeg -i 0982ExFo_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0982ExFo_OutPW_LQ_C1.ogv
#
# 0
# 77.17960333824158
# ffmpeg -i 0983ExFo_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0983ExFo_OutPW_LQ_C2.ogv
#
# 0
# 79.69467043876648
# ffmpeg -i 0987ExFo_OutPW_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0987ExFo_OutPW_HQ_C2.ogv
#
# 0
# 69.26236891746521
# ffmpeg -i 0991ExFo_OutPW_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0991ExFo_OutPW_MQ_C2.ogv
#
# 0
# 71.51330232620239
# ffmpeg -i 0995ExFo_OutPW_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0995ExFo_OutPW_LQ_C2.ogv
#
# 0
# 74.74982571601868
# ffmpeg -i 0998ExFo_OutPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0998ExFo_OutPW_HQ_C1.ogv
#
# 0
# 59.08962893486023
# ffmpeg -i 1002ExFo_OutPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1002ExFo_OutPW_MQ_C1.ogv
#
# 0
# 57.53778266906738
# ffmpeg -i 1006ExFo_OutPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1006ExFo_OutPW_LQ_C1.ogv
#
# 0
# 58.05715322494507
# ffmpeg -i 1010Pri_OutLPP_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1010Pri_OutLPP_C1.ogv
#
# 0
# 110.77772235870361
# ffmpeg -i 1011Pri_OutLPP_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1011Pri_OutLPP_C2.ogv
#
# 0
# 77.39788937568665
# ffmpeg -i 1014Exp_OutLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1014Exp_OutLPP_HQ_C1.ogv
#
# 0
# 101.54869174957275
# ffmpeg -i 1015Exp_OutLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1015Exp_OutLPP_HQ_C2.ogv
#
# 0
# 73.09000039100647
# ffmpeg -i 1017Exp_OutLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1017Exp_OutLPP_MQ_C1.ogv
#
# 0
# 85.98395776748657
# ffmpeg -i 1018Exp_OutLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1018Exp_OutLPP_MQ_C2.ogv
#
# 0
# 70.33386397361755
# ffmpeg -i 1020Exp_OutLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1020Exp_OutLPP_LQ_C1.ogv
#
# 0
# 73.83392858505249
# ffmpeg -i 1021Exp_OutLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1021Exp_OutLPP_LQ_C2.ogv
#
# 0
# 67.1563868522644
# ffmpeg -i 1023Exp_OutLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1023Exp_OutLPP_HQ_C1.ogv
#
# 0
# 75.44764709472656
# ffmpeg -i 1024Exp_OutLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1024Exp_OutLPP_HQ_C2.ogv
#
# 0
# 70.33532738685608
# ffmpeg -i 1027Exp_OutLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1027Exp_OutLPP_MQ_C1.ogv
#
# 0
# 82.44254207611084
# ffmpeg -i 1028Exp_OutLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1028Exp_OutLPP_MQ_C2.ogv
#
# 0
# 85.09628534317017
# ffmpeg -i 1031Exp_OutLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1031Exp_OutLPP_LQ_C1.ogv
#
# 0
# 79.96256375312805
# ffmpeg -i 1032Exp_OutLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1032Exp_OutLPP_LQ_C2.ogv
#
# 0
# 66.01068806648254
# ffmpeg -i 1035Exp_OutLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1035Exp_OutLPP_HQ_C1.ogv
# 0
# 73.84291291236877
# ffmpeg -i 1038Exp_OutLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1038Exp_OutLPP_MQ_C1.ogv
#
# 0
# 67.69328236579895
# ffmpeg -i 1041Exp_OutLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1041Exp_OutLPP_LQ_C1.ogv
#
# 0
# 69.07688975334167
# ffmpeg -i 1044Fo_OutLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1044Fo_OutLPP_HQ_C1.ogv
#
# 0
# 72.21772336959839
# ffmpeg -i 1045Fo_OutLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1045Fo_OutLPP_HQ_C2.ogv
#
# 0
# 73.20091772079468
# ffmpeg -i 1047Fo_OutLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1047Fo_OutLPP_HQ_C4.ogv
#
# 0
# 76.40162420272827
# ffmpeg -i 1048Fo_OutLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1048Fo_OutLPP_MQ_C1.ogv
#
# 0
# 60.452889919281006
# ffmpeg -i 1049Fo_OutLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1049Fo_OutLPP_MQ_C2.ogv
#
# 0
# 56.87565279006958
# ffmpeg -i 1051Fo_OutLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1051Fo_OutLPP_MQ_C4.ogv
#
# 0
# 69.95756912231445
# ffmpeg -i 1052Fo_OutLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1052Fo_OutLPP_LQ_C1.ogv
#
# 0
# 69.36429858207703
# ffmpeg -i 1053Fo_OutLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1053Fo_OutLPP_LQ_C2.ogv
#
# 0
# 66.86285495758057
# ffmpeg -i 1055Fo_OutLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1055Fo_OutLPP_LQ_C4.ogv
#
# 0
# 70.97205591201782
# ffmpeg -i 1080ExFo_OutLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1080ExFo_OutLPP_HQ_C1.ogv
#
# 0
# 70.21842384338379
# ffmpeg -i 1081ExFo_OutLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1081ExFo_OutLPP_HQ_C2.ogv
#
# 0
# 62.56803250312805
# ffmpeg -i 1084ExFo_OutLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1084ExFo_OutLPP_MQ_C1.ogv
#
# 0
# 61.05360174179077
# ffmpeg -i 1085ExFo_OutLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1085ExFo_OutLPP_MQ_C2.ogv
#
# 0
# 65.16880345344543
# ffmpeg -i 1088ExFo_OutLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1088ExFo_OutLPP_LQ_C1.ogv
#
# 0
# 61.02155947685242
# ffmpeg -i 1089ExFo_OutLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1089ExFo_OutLPP_LQ_C2.ogv
#
# 0
# 62.370338439941406
# ffmpeg -i 1113Pri_OutWL_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1113Pri_OutWL_C1.ogv
#
# 0
# 105.17438340187073
# ffmpeg -i 1114Pri_OutWL_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1114Pri_OutWL_C2.ogv
#
# 0
# 76.70768976211548
# ffmpeg -i 1116Exp_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1116Exp_OutWL_HQ_C1.ogv
#
# 0
# 75.85215878486633
# ffmpeg -i 1117Exp_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1117Exp_OutWL_HQ_C2.ogv
#
# 0
# 64.68512439727783
# ffmpeg -i 1119Exp_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1119Exp_OutWL_MQ_C1.ogv
#
# 0
# 66.93838357925415
# ffmpeg -i 1120Exp_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1120Exp_OutWL_MQ_C2.ogv
#
# 0
# 56.74062919616699
# ffmpeg -i 1122Exp_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1122Exp_OutWL_LQ_C1.ogv
#
# 0
# 56.68255877494812
# ffmpeg -i 1123Exp_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1123Exp_OutWL_LQ_C2.ogv
#
# 0
# 56.018213748931885
# ffmpeg -i 1125Exp_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1125Exp_OutWL_HQ_C1.ogv
#
# 0
# 64.46261239051819
# ffmpeg -i 1126Exp_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1126Exp_OutWL_HQ_C2.ogv
#
# 0
# 56.86522030830383
# ffmpeg -i 1129Exp_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1129Exp_OutWL_MQ_C1.ogv
#
# 0
# 57.86695146560669
# ffmpeg -i 1130Exp_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1130Exp_OutWL_MQ_C2.ogv
#
# 0
# 46.41627764701843
# ffmpeg -i 1133Exp_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1133Exp_OutWL_LQ_C1.ogv
#
# 0
# 50.006508588790894
# ffmpeg -i 1134Exp_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1134Exp_OutWL_LQ_C2.ogv
#
# 0
# 46.50937008857727
# ffmpeg -i 1137Exp_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1137Exp_OutWL_HQ_C1.ogv
#
# 0
# 62.52971005439758
# ffmpeg -i 1141Exp_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1141Exp_OutWL_MQ_C1.ogv
#
# 0
# 75.04911279678345
# ffmpeg -i 1145Exp_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1145Exp_OutWL_LQ_C1.ogv
#
# 0
# 72.90991592407227
# ffmpeg -i 1149Fo_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1149Fo_OutWL_HQ_C1.ogv
#
# 0
# 63.41589307785034
# ffmpeg -i 1150Fo_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1150Fo_OutWL_HQ_C2.ogv
#
# 0
# 56.21346378326416
# ffmpeg -i 1153Fo_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1153Fo_OutWL_MQ_C1.ogv
#
# 0
# 57.42058491706848
# ffmpeg -i 1154Fo_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1154Fo_OutWL_MQ_C2.ogv
# 0
# 67.5304958820343
# ffmpeg -i 1157Fo_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1157Fo_OutWL_LQ_C1.ogv
#
# 0
# 56.81633639335632
# ffmpeg -i 1158Fo_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1158Fo_OutWL_LQ_C2.ogv
#
# 0
# 69.23180747032166
# ffmpeg -i 1162Fo_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1162Fo_OutWL_HQ_C2.ogv
#
# 0
# 59.94995450973511
# ffmpeg -i 1164Fo_OutWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1164Fo_OutWL_HQ_C4.ogv
#
# 0
# 56.43140411376953
# ffmpeg -i 1166Fo_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1166Fo_OutWL_MQ_C2.ogv
#
# 0
# 67.08824682235718
# ffmpeg -i 1168Fo_OutWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1168Fo_OutWL_MQ_C4.ogv
#
# 0
# 66.46521353721619
# ffmpeg -i 1170Fo_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1170Fo_OutWL_LQ_C2.ogv
#
# 0
# 57.31997489929199
# ffmpeg -i 1174Fo_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1174Fo_OutWL_HQ_C2.ogv
#
# 0
# 72.06123948097229
# ffmpeg -i 1178Fo_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1178Fo_OutWL_MQ_C2.ogv
#
# 0
# 59.41241931915283
# ffmpeg -i 1185ExFo_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1185ExFo_OutWL_HQ_C1.ogv
#
# 0
# 65.24251627922058
# ffmpeg -i 1186ExFo_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1186ExFo_OutWL_HQ_C2.ogv
#
# 0
# 60.02476477622986
# ffmpeg -i 1189ExFo_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1189ExFo_OutWL_MQ_C1.ogv
#
# 0
# 51.04482293128967
# ffmpeg -i 1190ExFo_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1190ExFo_OutWL_MQ_C2.ogv
#
# 0
# 51.61251664161682
# ffmpeg -i 1193ExFo_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1193ExFo_OutWL_LQ_C1.ogv
#
# 0
# 53.63552975654602
# ffmpeg -i 1194ExFo_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1194ExFo_OutWL_LQ_C2.ogv
#
# 0
# 61.091137647628784
# ffmpeg -i 1197ExFo_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1197ExFo_OutWL_HQ_C1.ogv
#
# 0
# 49.837992668151855
# ffmpeg -i 1198ExFo_OutWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1198ExFo_OutWL_HQ_C2.ogv
#
# 0
# 47.99592566490173
# ffmpeg -i 1201ExFo_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1201ExFo_OutWL_MQ_C1.ogv
#
# 0
# 46.989004135131836
# ffmpeg -i 1202ExFo_OutWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1202ExFo_OutWL_MQ_C2.ogv
#
# 0
# 42.359747886657715
# ffmpeg -i 1205ExFo_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1205ExFo_OutWL_LQ_C1.ogv
#
# 0
# 48.684426069259644
# ffmpeg -i 1206ExFo_OutWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1206ExFo_OutWL_LQ_C2.ogv
#
# 0
# 43.0831241607666
# ffmpeg -i 1209ExFo_OutWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1209ExFo_OutWL_HQ_C1.ogv
#
# 0
# 41.03836989402771
# ffmpeg -i 1212ExFo_OutWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1212ExFo_OutWL_HQ_C4.ogv
#
# 0
# 48.072028160095215
# ffmpeg -i 1213ExFo_OutWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1213ExFo_OutWL_MQ_C1.ogv
#
# 0
# 39.604084730148315
# ffmpeg -i 1216ExFo_OutWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1216ExFo_OutWL_MQ_C4.ogv
#
# 0
# 43.62067413330078
# ffmpeg -i 1217ExFo_OutWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1217ExFo_OutWL_LQ_C1.ogv
#
# 0
# 41.170440673828125
# ffmpeg -i 1220ExFo_OutWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1220ExFo_OutWL_LQ_C4.ogv
#
# 0
# 43.41328144073486
# ffmpeg -i 1221Pri_OutPR_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1221Pri_OutPR_C1.ogv
#
# 0
# 83.01257109642029
# ffmpeg -i 1222Pri_OutPR_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1222Pri_OutPR_C2.ogv
#
# 0
# 55.97640585899353
# ffmpeg -i 1224Exp_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1224Exp_OutPR_HQ_C1.ogv
#
# 0
# 59.946974992752075
# ffmpeg -i 1225Exp_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1225Exp_OutPR_HQ_C2.ogv
#
# 0
# 47.98327684402466
# ffmpeg -i 1228Exp_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1228Exp_OutPR_MQ_C1.ogv
#
# 0
# 56.569374084472656
# ffmpeg -i 1229Exp_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1229Exp_OutPR_MQ_C2.ogv
#
# 0
# 51.017254114151
# ffmpeg -i 1232Exp_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1232Exp_OutPR_LQ_C1.ogv
#
# 0
# 52.98129606246948
# ffmpeg -i 1233Exp_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1233Exp_OutPR_LQ_C2.ogv
#
# 0
# 48.76967644691467
# ffmpeg -i 1236Exp_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1236Exp_OutPR_HQ_C1.ogv
#
# 0
# 57.34061646461487
# ffmpeg -i 1237Exp_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1237Exp_OutPR_HQ_C2.ogv
#
# 0
# 48.75317025184631
# ffmpeg -i 1239Exp_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1239Exp_OutPR_MQ_C1.ogv
# 0
# 59.56145477294922
# ffmpeg -i 1240Exp_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1240Exp_OutPR_MQ_C2.ogv
#
# 0
# 45.92617845535278
# ffmpeg -i 1242Exp_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1242Exp_OutPR_LQ_C1.ogv
#
# 0
# 53.025232553482056
# ffmpeg -i 1243Exp_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1243Exp_OutPR_LQ_C2.ogv
#
# 0
# 53.45148587226868
# ffmpeg -i 1245Exp_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1245Exp_OutPR_HQ_C1.ogv
#
# 0
# 60.90243101119995
# ffmpeg -i 1246Exp_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1246Exp_OutPR_HQ_C2.ogv
#
# 0
# 50.61879897117615
# ffmpeg -i 1249Exp_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1249Exp_OutPR_MQ_C1.ogv
#
# 0
# 61.50030517578125
# ffmpeg -i 1250Exp_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1250Exp_OutPR_MQ_C2.ogv
#
# 0
# 47.79828143119812
# ffmpeg -i 1253Exp_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1253Exp_OutPR_LQ_C1.ogv
#
# 0
# 53.29357695579529
# ffmpeg -i 1254Exp_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1254Exp_OutPR_LQ_C2.ogv
#
# 0
# 43.2629280090332
# ffmpeg -i 1257Fo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1257Fo_OutPR_HQ_C1.ogv
#
# 0
# 54.90019369125366
# ffmpeg -i 1258Fo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1258Fo_OutPR_HQ_C2.ogv
#
# 0
# 46.21061158180237
# ffmpeg -i 1260Fo_OutPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1260Fo_OutPR_HQ_C4.ogv
#
# 0
# 48.884780168533325
# ffmpeg -i 1261Fo_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1261Fo_OutPR_MQ_C1.ogv
#
# 0
# 44.394216537475586
# ffmpeg -i 1262Fo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1262Fo_OutPR_MQ_C2.ogv
#
# 0
# 45.1828088760376
# ffmpeg -i 1264Fo_OutPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1264Fo_OutPR_MQ_C4.ogv
#
# 0
# 44.99712014198303
# ffmpeg -i 1265Fo_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1265Fo_OutPR_LQ_C1.ogv
#
# 0
# 49.38524150848389
# ffmpeg -i 1266Fo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1266Fo_OutPR_LQ_C2.ogv
#
# 0
# 45.62500786781311
# ffmpeg -i 1268Fo_OutPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1268Fo_OutPR_LQ_C4.ogv
#
# 0
# 53.00652313232422
# ffmpeg -i 1269Fo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1269Fo_OutPR_HQ_C1.ogv
#
# 0
# 54.19436168670654
# ffmpeg -i 1270Fo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1270Fo_OutPR_HQ_C2.ogv
#
# 0
# 56.92294669151306
# ffmpeg -i 1272Fo_OutPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1272Fo_OutPR_HQ_C4.ogv
#
# 0
# 59.752976417541504
# ffmpeg -i 1273Fo_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1273Fo_OutPR_MQ_C1.ogv
#
# 0
# 52.795116901397705
# ffmpeg -i 1274Fo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1274Fo_OutPR_MQ_C2.ogv
#
# 0
# 58.53828835487366
# ffmpeg -i 1276Fo_OutPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1276Fo_OutPR_MQ_C4.ogv
#
# 0
# 64.95011758804321
# ffmpeg -i 1277Fo_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1277Fo_OutPR_LQ_C1.ogv
#
# 0
# 56.31125259399414
# ffmpeg -i 1278Fo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1278Fo_OutPR_LQ_C2.ogv
#
# 0
# 64.90730214118958
# ffmpeg -i 1280Fo_OutPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1280Fo_OutPR_LQ_C4.ogv
#
# 0
# 58.01171135902405
# ffmpeg -i 1281Fo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1281Fo_OutPR_HQ_C1.ogv
#
# 0
# 58.65245771408081
# ffmpeg -i 1282Fo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1282Fo_OutPR_HQ_C2.ogv
#
# 0
# 51.99520254135132
# ffmpeg -i 1285Fo_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1285Fo_OutPR_MQ_C1.ogv
#
# 0
# 48.759955167770386
# ffmpeg -i 1286Fo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1286Fo_OutPR_MQ_C2.ogv
#
# 0
# 46.42581295967102
# ffmpeg -i 1289Fo_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1289Fo_OutPR_LQ_C1.ogv
#
# 0
# 47.202858448028564
# ffmpeg -i 1290Fo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1290Fo_OutPR_LQ_C2.ogv
#
# 0
# 47.62596607208252
# ffmpeg -i 1293ExFo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1293ExFo_OutPR_HQ_C1.ogv
#
# 0
# 52.0962016582489
# ffmpeg -i 1294ExFo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1294ExFo_OutPR_HQ_C2.ogv
#
# 0
# 46.155991315841675
# ffmpeg -i 1297ExFo_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1297ExFo_OutPR_MQ_C1.ogv
#
# 0
# 44.909467935562134
# ffmpeg -i 1298ExFo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1298ExFo_OutPR_MQ_C2.ogv
#
# 0
# 42.6473126411438
# ffmpeg -i 1301ExFo_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1301ExFo_OutPR_LQ_C1.ogv
#
# 0
# 41.37304759025574
# ffmpeg -i 1302ExFo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1302ExFo_OutPR_LQ_C2.ogv
# 0
# 41.29007649421692
# ffmpeg -i 1305ExFo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1305ExFo_OutPR_HQ_C1.ogv
#
# 0
# 41.05905747413635
# ffmpeg -i 1306ExFo_OutPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1306ExFo_OutPR_HQ_C2.ogv
#
# 0
# 37.9769766330719
# ffmpeg -i 1309ExFo_OutPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1309ExFo_OutPR_MQ_C1.ogv
#
# 0
# 40.14242124557495
# ffmpeg -i 1310ExFo_OutPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1310ExFo_OutPR_MQ_C2.ogv
#
# 0
# 37.54671120643616
# ffmpeg -i 1313ExFo_OutPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1313ExFo_OutPR_LQ_C1.ogv
#
# 0
# 35.41130352020264
# ffmpeg -i 1314ExFo_OutPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1314ExFo_OutPR_LQ_C2.ogv
#
# 0
# 35.28892230987549
# ffmpeg -i 1317ExFo_OutPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/1317ExFo_OutPR_HQ_C1.ogv
#
# 0
# 32.145885705947876
# 1623114528.2758307
