# %%
import numpy as np
import os
import time



with open('/home/r/Dropbox/Javeriana/current_work/tracker_prediction/VariacionResolucion_ImpactoTracker/script_convert_2_ogv.txt') as f:
    lines = f.readlines()


os.chdir(r'/home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos')

# %%
for i in range (1,200):
    start = time.time()
    print(lines[i])
    print(os.system(lines[i]))
    end = time.time()
    print(end - start)
end
# Out:
# ffmpeg -i 0053Pri_IndPW_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0053Pri_IndPW_C3.ogv
#
# 0
# 57.559749364852905
# ffmpeg -i 0067Exp_IndPW_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0067Exp_IndPW_HQ_C1.ogv
#
# 0
# 41.247918128967285
# ffmpeg -i 0070Exp_IndPW_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0070Exp_IndPW_HQ_C4.ogv
#
# 0
# 47.89680600166321
# ffmpeg -i 0071Exp_IndPW_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0071Exp_IndPW_MQ_C1.ogv
#
# 0
# 57.3904972076416
# ffmpeg -i 0074Exp_IndPW_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0074Exp_IndPW_MQ_C4.ogv
#
# 0
# 59.55126476287842
# ffmpeg -i 0075Exp_IndPW_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0075Exp_IndPW_LQ_C1.ogv
#
# 0
# 59.43355584144592
# ffmpeg -i 0078Exp_IndPW_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0078Exp_IndPW_LQ_C4.ogv
#
# 0
# 65.61414313316345
# ffmpeg -i 0145ExFo_IndPW_MQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0145ExFo_IndPW_MQ_C3.ogv
#
# 0
# 55.788352489471436
# ffmpeg -i 0149ExFo_IndPW_LQ_C3.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0149ExFo_IndPW_LQ_C3.ogv
#
# 0
# 56.05962514877319
# ffmpeg -i 0163Pri_IndLPP_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0163Pri_IndLPP_C1.ogv
#
# 0
# 74.89241695404053
# ffmpeg -i 0164Pri_IndLPP_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0164Pri_IndLPP_C2.ogv
#
# 0
# 66.86436581611633
# ffmpeg -i 0165Pri_IndLPP_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0165Pri_IndLPP_C4.ogv
#
# 0
# 86.55958127975464
# ffmpeg -i 0166Exp_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0166Exp_IndLPP_HQ_C1.ogv
#
# 0
# 60.86191916465759
# ffmpeg -i 0167Exp_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0167Exp_IndLPP_HQ_C2.ogv
#
# 0
# 60.7869336605072
# ffmpeg -i 0169Exp_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0169Exp_IndLPP_HQ_C4.ogv
#
# 0
# 70.33616089820862
# ffmpeg -i 0170Exp_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0170Exp_IndLPP_MQ_C1.ogv
#
# 0
# 68.20880126953125
# ffmpeg -i 0171Exp_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0171Exp_IndLPP_MQ_C2.ogv
#
# 0
# 70.51577043533325
# ffmpeg -i 0173Exp_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0173Exp_IndLPP_MQ_C4.ogv
#
# 0
# 65.60320711135864
# ffmpeg -i 0174Exp_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0174Exp_IndLPP_LQ_C1.ogv
#
# 0
# 71.47462940216064
# ffmpeg -i 0175Exp_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0175Exp_IndLPP_LQ_C2.ogv
#
# 0
# 63.606271266937256
# ffmpeg -i 0177Exp_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0177Exp_IndLPP_LQ_C4.ogv
#
# 0
# 66.2349443435669
# ffmpeg -i 0178Exp_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0178Exp_IndLPP_HQ_C1.ogv
#
# 0
# 67.46330738067627
# ffmpeg -i 0179Exp_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0179Exp_IndLPP_HQ_C2.ogv
#
# 0
# 58.3647723197937
# ffmpeg -i 0181Exp_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0181Exp_IndLPP_HQ_C4.ogv
#
# 0
# 59.415910482406616
# ffmpeg -i 0182Exp_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0182Exp_IndLPP_MQ_C1.ogv
#
# 0
# 63.27987623214722
# ffmpeg -i 0183Exp_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0183Exp_IndLPP_MQ_C2.ogv
#
# 0
# 62.952107667922974
# ffmpeg -i 0185Exp_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0185Exp_IndLPP_MQ_C4.ogv
#
# 0
# 62.144811391830444
# ffmpeg -i 0186Exp_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0186Exp_IndLPP_LQ_C1.ogv
#
# 0
# 62.23878216743469
# ffmpeg -i 0187Exp_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0187Exp_IndLPP_LQ_C2.ogv
#
# 0
# 63.73375606536865
# ffmpeg -i 0189Exp_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0189Exp_IndLPP_LQ_C4.ogv
#
# 0
# 58.30607080459595
# ffmpeg -i 0190Exp_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0190Exp_IndLPP_HQ_C1.ogv
#
# 0
# 63.774569034576416
# ffmpeg -i 0191Exp_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0191Exp_IndLPP_HQ_C2.ogv
#
# 0
# 63.17877173423767
# ffmpeg -i 0193Exp_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0193Exp_IndLPP_HQ_C4.ogv
#
# 0
# 68.23819017410278
# ffmpeg -i 0194Exp_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0194Exp_IndLPP_MQ_C1.ogv
#
# 0
# 67.1497483253479
# ffmpeg -i 0195Exp_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0195Exp_IndLPP_MQ_C2.ogv
#
# 0
# 63.8257691860199
# ffmpeg -i 0197Exp_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0197Exp_IndLPP_MQ_C4.ogv
#
# 0
# 64.36694979667664
# ffmpeg -i 0198Exp_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0198Exp_IndLPP_LQ_C1.ogv
#
# 0
# 60.97369313240051
# ffmpeg -i 0199Exp_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0199Exp_IndLPP_LQ_C2.ogv
# 0
# 60.30625081062317
# ffmpeg -i 0201Exp_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0201Exp_IndLPP_LQ_C4.ogv
#
# 0
# 60.13633584976196
# ffmpeg -i 0202Fo_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0202Fo_IndLPP_HQ_C1.ogv
#
# 0
# 68.3096752166748
# ffmpeg -i 0203Fo_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0203Fo_IndLPP_HQ_C2.ogv
#
# 0
# 63.57481360435486
# ffmpeg -i 0205Fo_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0205Fo_IndLPP_HQ_C4.ogv
#
# 0
# 72.87905406951904
# ffmpeg -i 0206Fo_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0206Fo_IndLPP_MQ_C1.ogv
#
# 0
# 64.1802499294281
# ffmpeg -i 0207Fo_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0207Fo_IndLPP_MQ_C2.ogv
#
# 0
# 63.5367169380188
# ffmpeg -i 0209Fo_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0209Fo_IndLPP_MQ_C4.ogv
#
# 0
# 61.22057628631592
# ffmpeg -i 0210Fo_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0210Fo_IndLPP_LQ_C1.ogv
#
# 0
# 66.95893454551697
# ffmpeg -i 0211Fo_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0211Fo_IndLPP_LQ_C2.ogv
#
# 0
# 65.31390047073364
# ffmpeg -i 0213Fo_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0213Fo_IndLPP_LQ_C4.ogv
#
# 0
# 71.77602648735046
# ffmpeg -i 0214Fo_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0214Fo_IndLPP_HQ_C1.ogv
#
# 0
# 72.08215808868408
# ffmpeg -i 0215Fo_IndLPP_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0215Fo_IndLPP_HQ_C2.ogv
#
# 0
# 66.42508673667908
# ffmpeg -i 0218Fo_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0218Fo_IndLPP_MQ_C1.ogv
#
# 0
# 59.68910336494446
# ffmpeg -i 0219Fo_IndLPP_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0219Fo_IndLPP_MQ_C2.ogv
#
# 0
# 57.74150252342224
# ffmpeg -i 0223Fo_IndLPP_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0223Fo_IndLPP_LQ_C2.ogv
#
# 0
# 57.7536735534668
# ffmpeg -i 0238ExFo_IndLPP_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0238ExFo_IndLPP_HQ_C1.ogv
#
# 0
# 58.42673945426941
# ffmpeg -i 0241ExFo_IndLPP_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0241ExFo_IndLPP_HQ_C4.ogv
#
# 0
# 68.97332262992859
# ffmpeg -i 0242ExFo_IndLPP_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0242ExFo_IndLPP_MQ_C1.ogv
#
# 0
# 73.7927017211914
# ffmpeg -i 0245ExFo_IndLPP_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0245ExFo_IndLPP_MQ_C4.ogv
#
# 0
# 62.77863335609436
# ffmpeg -i 0246ExFo_IndLPP_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0246ExFo_IndLPP_LQ_C1.ogv
#
# 0
# 63.81265878677368
# ffmpeg -i 0249ExFo_IndLPP_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0249ExFo_IndLPP_LQ_C4.ogv
#
# 0
# 62.513914585113525
# ffmpeg -i 0274Pri_IndWL_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0274Pri_IndWL_C1.ogv
#
# 0
# 83.39633917808533
# ffmpeg -i 0275Pri_IndWL_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0275Pri_IndWL_C2.ogv
#
# 0
# 79.82594323158264
# ffmpeg -i 0277Pri_IndWL_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0277Pri_IndWL_C4.ogv
#
# 0
# 99.56112790107727
# ffmpeg -i 0278Exp_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0278Exp_IndWL_HQ_C1.ogv
#
# 0
# 76.57375645637512
# ffmpeg -i 0279Exp_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0279Exp_IndWL_HQ_C2.ogv
#
# 0
# 72.12752342224121
# ffmpeg -i 0281Exp_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0281Exp_IndWL_HQ_C4.ogv
#
# 0
# 62.57393980026245
# ffmpeg -i 0282Exp_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0282Exp_IndWL_MQ_C1.ogv
#
# 0
# 78.4321711063385
# ffmpeg -i 0283Exp_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0283Exp_IndWL_MQ_C2.ogv
#
# 0
# 64.73656296730042
# ffmpeg -i 0285Exp_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0285Exp_IndWL_MQ_C4.ogv
#
# 0
# 69.02405953407288
# ffmpeg -i 0286Exp_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0286Exp_IndWL_LQ_C1.ogv
#
# 0
# 68.134117603302
# ffmpeg -i 0287Exp_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0287Exp_IndWL_LQ_C2.ogv
#
# 0
# 66.20243978500366
# ffmpeg -i 0289Exp_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0289Exp_IndWL_LQ_C4.ogv
#
# 0
# 66.40591502189636
# ffmpeg -i 0290Exp_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0290Exp_IndWL_HQ_C1.ogv
#
# 0
# 69.35130524635315
# ffmpeg -i 0291Exp_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0291Exp_IndWL_HQ_C2.ogv
#
# 0
# 58.772700548172
# ffmpeg -i 0293Exp_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0293Exp_IndWL_HQ_C4.ogv
#
# 0
# 58.70422673225403
# ffmpeg -i 0294Exp_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0294Exp_IndWL_MQ_C1.ogv
#
# 0
# 59.14050030708313
# ffmpeg -i 0295Exp_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0295Exp_IndWL_MQ_C2.ogv
# 0
# 59.776689529418945
# ffmpeg -i 0297Exp_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0297Exp_IndWL_MQ_C4.ogv
#
# 0
# 65.47071146965027
# ffmpeg -i 0298Exp_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0298Exp_IndWL_LQ_C1.ogv
#
# 0
# 68.89855766296387
# ffmpeg -i 0299Exp_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0299Exp_IndWL_LQ_C2.ogv
#
# 0
# 59.665345907211304
# ffmpeg -i 0301Exp_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0301Exp_IndWL_LQ_C4.ogv
#
# 0
# 66.93148922920227
# ffmpeg -i 0302Exp_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0302Exp_IndWL_HQ_C1.ogv
#
# 0
# 73.34022331237793
# ffmpeg -i 0303Exp_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0303Exp_IndWL_HQ_C2.ogv
#
# 0
# 64.97642350196838
# ffmpeg -i 0305Exp_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0305Exp_IndWL_HQ_C4.ogv
#
# 0
# 61.79682469367981
# ffmpeg -i 0306Exp_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0306Exp_IndWL_MQ_C1.ogv
#
# 0
# 61.273191928863525
# ffmpeg -i 0307Exp_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0307Exp_IndWL_MQ_C2.ogv
#
# 0
# 56.45400953292847
# ffmpeg -i 0309Exp_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0309Exp_IndWL_MQ_C4.ogv
#
# 0
# 65.73467946052551
# ffmpeg -i 0310Exp_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0310Exp_IndWL_LQ_C1.ogv
#
# 0
# 57.25411581993103
# ffmpeg -i 0311Exp_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0311Exp_IndWL_LQ_C2.ogv
#
# 0
# 53.1316237449646
# ffmpeg -i 0313Exp_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0313Exp_IndWL_LQ_C4.ogv
#
# 0
# 56.61803102493286
# ffmpeg -i 0314Fo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0314Fo_IndWL_HQ_C1.ogv
#
# 0
# 58.34658479690552
# ffmpeg -i 0315Fo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0315Fo_IndWL_HQ_C2.ogv
#
# 0
# 58.646708726882935
# ffmpeg -i 0318Fo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0318Fo_IndWL_MQ_C1.ogv
#
# 0
# 66.41158890724182
# ffmpeg -i 0319Fo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0319Fo_IndWL_MQ_C2.ogv
#
# 0
# 54.70669960975647
# ffmpeg -i 0322Fo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0322Fo_IndWL_LQ_C1.ogv
#
# 0
# 66.58836340904236
# ffmpeg -i 0323Fo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0323Fo_IndWL_LQ_C2.ogv
#
# 0
# 70.36467409133911
# ffmpeg -i 0326Fo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0326Fo_IndWL_HQ_C1.ogv
#
# 0
# 73.7235357761383
# ffmpeg -i 0327Fo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0327Fo_IndWL_HQ_C2.ogv
#
# 0
# 65.32218146324158
# ffmpeg -i 0329Fo_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0329Fo_IndWL_HQ_C4.ogv
#
# 0
# 61.021474838256836
# ffmpeg -i 0330Fo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0330Fo_IndWL_MQ_C1.ogv
#
# 0
# 59.512818574905396
# ffmpeg -i 0331Fo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0331Fo_IndWL_MQ_C2.ogv
#
# 0
# 58.17344379425049
# ffmpeg -i 0333Fo_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0333Fo_IndWL_MQ_C4.ogv
#
# 0
# 56.007182359695435
# ffmpeg -i 0334Fo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0334Fo_IndWL_LQ_C1.ogv
#
# 0
# 64.05032253265381
# ffmpeg -i 0335Fo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0335Fo_IndWL_LQ_C2.ogv
#
# 0
# 62.98366618156433
# ffmpeg -i 0337Fo_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0337Fo_IndWL_LQ_C4.ogv
#
# 0
# 59.2877197265625
# ffmpeg -i 0341Fo_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0341Fo_IndWL_HQ_C4.ogv
#
# 0
# 56.040077209472656
# ffmpeg -i 0350ExFo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0350ExFo_IndWL_HQ_C1.ogv
#
# 0
# 61.27126908302307
# ffmpeg -i 0351ExFo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0351ExFo_IndWL_HQ_C2.ogv
#
# 0
# 60.38535165786743
# ffmpeg -i 0353ExFo_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0353ExFo_IndWL_HQ_C4.ogv
#
# 0
# 58.38452625274658
# ffmpeg -i 0354ExFo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0354ExFo_IndWL_MQ_C1.ogv
#
# 0
# 57.971940755844116
# ffmpeg -i 0355ExFo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0355ExFo_IndWL_MQ_C2.ogv
#
# 0
# 46.760915756225586
# ffmpeg -i 0357ExFo_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0357ExFo_IndWL_MQ_C4.ogv
#
# 0
# 47.007888078689575
# ffmpeg -i 0358ExFo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0358ExFo_IndWL_LQ_C1.ogv
#
# 0
# 46.89014959335327
# ffmpeg -i 0359ExFo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0359ExFo_IndWL_LQ_C2.ogv
#
# 0
# 49.36985635757446
# ffmpeg -i 0361ExFo_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0361ExFo_IndWL_LQ_C4.ogv
# 0
# 48.83877491950989
# ffmpeg -i 0362ExFo_IndWL_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0362ExFo_IndWL_HQ_C1.ogv
#
# 0
# 47.0333354473114
# ffmpeg -i 0363ExFo_IndWL_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0363ExFo_IndWL_HQ_C2.ogv
#
# 0
# 47.47105693817139
# ffmpeg -i 0365ExFo_IndWL_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0365ExFo_IndWL_HQ_C4.ogv
#
# 0
# 49.900633811950684
# ffmpeg -i 0366ExFo_IndWL_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0366ExFo_IndWL_MQ_C1.ogv
#
# 0
# 47.25682330131531
# ffmpeg -i 0367ExFo_IndWL_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0367ExFo_IndWL_MQ_C2.ogv
#
# 0
# 41.43588328361511
# ffmpeg -i 0369ExFo_IndWL_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0369ExFo_IndWL_MQ_C4.ogv
#
# 0
# 41.88819074630737
# ffmpeg -i 0370ExFo_IndWL_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0370ExFo_IndWL_LQ_C1.ogv
#
# 0
# 55.25825572013855
# ffmpeg -i 0371ExFo_IndWL_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0371ExFo_IndWL_LQ_C2.ogv
#
# 0
# 54.23764896392822
# ffmpeg -i 0373ExFo_IndWL_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0373ExFo_IndWL_LQ_C4.ogv
#
# 0
# 55.92809534072876
# ffmpeg -i 0374Pri_IndPR_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0374Pri_IndPR_C1.ogv
#
# 0
# 82.89237570762634
# ffmpeg -i 0375Pri_IndPR_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0375Pri_IndPR_C2.ogv
#
# 0
# 65.77508592605591
# ffmpeg -i 0377Exp_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0377Exp_IndPR_HQ_C1.ogv
#
# 0
# 61.91575574874878
# ffmpeg -i 0378Exp_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0378Exp_IndPR_HQ_C2.ogv
#
# 0
# 57.14601945877075
# ffmpeg -i 0380Exp_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0380Exp_IndPR_HQ_C4.ogv
#
# 0
# 57.104546546936035
# ffmpeg -i 0381Exp_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0381Exp_IndPR_MQ_C1.ogv
#
# 0
# 62.741864919662476
# ffmpeg -i 0382Exp_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0382Exp_IndPR_MQ_C2.ogv
#
# 0
# 54.203022718429565
# ffmpeg -i 0384Exp_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0384Exp_IndPR_MQ_C4.ogv
#
# 0
# 56.902610063552856
# ffmpeg -i 0385Exp_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0385Exp_IndPR_LQ_C1.ogv
#
# 0
# 62.663090229034424
# ffmpeg -i 0386Exp_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0386Exp_IndPR_LQ_C2.ogv
#
# 0
# 55.372366428375244
# ffmpeg -i 0388Exp_IndPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0388Exp_IndPR_LQ_C4.ogv
#
# 0
# 60.720120668411255
# ffmpeg -i 0389Exp_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0389Exp_IndPR_HQ_C1.ogv
#
# 0
# 64.13178992271423
# ffmpeg -i 0390Exp_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0390Exp_IndPR_HQ_C2.ogv
#
# 0
# 56.67796993255615
# ffmpeg -i 0392Exp_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0392Exp_IndPR_HQ_C4.ogv
#
# 0
# 60.31877541542053
# ffmpeg -i 0393Exp_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0393Exp_IndPR_MQ_C1.ogv
#
# 0
# 53.3822124004364
# ffmpeg -i 0394Exp_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0394Exp_IndPR_MQ_C2.ogv
#
# 0
# 50.25580382347107
# ffmpeg -i 0396Exp_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0396Exp_IndPR_MQ_C4.ogv
#
# 0
# 47.84853482246399
# ffmpeg -i 0397Exp_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0397Exp_IndPR_LQ_C1.ogv
#
# 0
# 49.809831619262695
# ffmpeg -i 0398Exp_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0398Exp_IndPR_LQ_C2.ogv
#
# 0
# 46.29940485954285
# ffmpeg -i 0400Exp_IndPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0400Exp_IndPR_LQ_C4.ogv
#
# 0
# 47.58543133735657
# ffmpeg -i 0401Exp_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0401Exp_IndPR_HQ_C1.ogv
#
# 0
# 47.824498891830444
# ffmpeg -i 0402Exp_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0402Exp_IndPR_HQ_C2.ogv
#
# 0
# 45.891605377197266
# ffmpeg -i 0404Exp_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0404Exp_IndPR_HQ_C4.ogv
#
# 0
# 46.67415237426758
# ffmpeg -i 0405Exp_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0405Exp_IndPR_MQ_C1.ogv
#
# 0
# 42.26861882209778
# ffmpeg -i 0406Exp_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0406Exp_IndPR_MQ_C2.ogv
#
# 0
# 46.64992880821228
# ffmpeg -i 0408Exp_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0408Exp_IndPR_MQ_C4.ogv
#
# 0
# 41.45882248878479
# ffmpeg -i 0409Exp_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0409Exp_IndPR_LQ_C1.ogv
#
# 0
# 43.15557336807251
# ffmpeg -i 0410Exp_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0410Exp_IndPR_LQ_C2.ogv
#
# 0
# 40.951037645339966
# ffmpeg -i 0412Exp_IndPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0412Exp_IndPR_LQ_C4.ogv
# 0
# 41.43718433380127
# ffmpeg -i 0413Fo_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0413Fo_IndPR_HQ_C1.ogv
#
# 0
# 45.991591930389404
# ffmpeg -i 0414Fo_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0414Fo_IndPR_HQ_C2.ogv
#
# 0
# 43.840816020965576
# ffmpeg -i 0415Fo_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0415Fo_IndPR_HQ_C4.ogv
#
# 0
# 48.214345932006836
# ffmpeg -i 0416Fo_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0416Fo_IndPR_MQ_C1.ogv
#
# 0
# 48.544347286224365
# ffmpeg -i 0417Fo_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0417Fo_IndPR_MQ_C2.ogv
#
# 0
# 48.64630079269409
# ffmpeg -i 0418Fo_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0418Fo_IndPR_MQ_C4.ogv
#
# 0
# 52.84335803985596
# ffmpeg -i 0419Fo_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0419Fo_IndPR_LQ_C1.ogv
#
# 0
# 48.996037006378174
# ffmpeg -i 0420Fo_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0420Fo_IndPR_LQ_C2.ogv
#
# 0
# 49.86696410179138
# ffmpeg -i 0421Fo_IndPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0421Fo_IndPR_LQ_C4.ogv
#
# 0
# 49.295689821243286
# ffmpeg -i 0422Fo_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0422Fo_IndPR_HQ_C1.ogv
#
# 0
# 48.48253583908081
# ffmpeg -i 0423Fo_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0423Fo_IndPR_HQ_C2.ogv
#
# 0
# 49.57905387878418
# ffmpeg -i 0425Fo_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0425Fo_IndPR_HQ_C4.ogv
#
# 0
# 43.19078707695007
# ffmpeg -i 0426Fo_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0426Fo_IndPR_MQ_C1.ogv
#
# 0
# 49.54405641555786
# ffmpeg -i 0427Fo_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0427Fo_IndPR_MQ_C2.ogv
#
# 0
# 45.36178970336914
# ffmpeg -i 0429Fo_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0429Fo_IndPR_MQ_C4.ogv
#
# 0
# 42.689534187316895
# ffmpeg -i 0430Fo_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0430Fo_IndPR_LQ_C1.ogv
#
# 0
# 43.891016721725464
# ffmpeg -i 0431Fo_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0431Fo_IndPR_LQ_C2.ogv
#
# 0
# 43.125072717666626
# ffmpeg -i 0433Fo_IndPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0433Fo_IndPR_LQ_C4.ogv
#
# 0
# 49.358458518981934
# ffmpeg -i 0434Fo_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0434Fo_IndPR_HQ_C1.ogv
#
# 0
# 45.501498222351074
# ffmpeg -i 0435Fo_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0435Fo_IndPR_HQ_C2.ogv
#
# 0
# 42.72290253639221
# ffmpeg -i 0437Fo_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0437Fo_IndPR_HQ_C4.ogv
#
# 0
# 45.99769377708435
# ffmpeg -i 0438Fo_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0438Fo_IndPR_MQ_C1.ogv
#
# 0
# 49.89996027946472
# ffmpeg -i 0439Fo_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0439Fo_IndPR_MQ_C2.ogv
#
# 0
# 48.123899936676025
# ffmpeg -i 0441Fo_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0441Fo_IndPR_MQ_C4.ogv
#
# 0
# 48.37122178077698
# ffmpeg -i 0442Fo_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0442Fo_IndPR_LQ_C1.ogv
#
# 0
# 43.27879190444946
# ffmpeg -i 0443Fo_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0443Fo_IndPR_LQ_C2.ogv
#
# 0
# 41.53228259086609
# ffmpeg -i 0445Fo_IndPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0445Fo_IndPR_LQ_C4.ogv
#
# 0
# 43.330262422561646
# ffmpeg -i 0446ExFo_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0446ExFo_IndPR_HQ_C1.ogv
#
# 0
# 52.838706254959106
# ffmpeg -i 0447ExFo_IndPR_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0447ExFo_IndPR_HQ_C2.ogv
#
# 0
# 43.30807566642761
# ffmpeg -i 0449ExFo_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0449ExFo_IndPR_HQ_C4.ogv
#
# 0
# 45.71019268035889
# ffmpeg -i 0450ExFo_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0450ExFo_IndPR_MQ_C1.ogv
#
# 0
# 46.16404128074646
# ffmpeg -i 0451ExFo_IndPR_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0451ExFo_IndPR_MQ_C2.ogv
#
# 0
# 43.76834487915039
# ffmpeg -i 0453ExFo_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0453ExFo_IndPR_MQ_C4.ogv
#
# 0
# 45.298290729522705
# ffmpeg -i 0454ExFo_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0454ExFo_IndPR_LQ_C1.ogv
#
# 0
# 44.76854467391968
# ffmpeg -i 0455ExFo_IndPR_LQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0455ExFo_IndPR_LQ_C2.ogv
#
# 0
# 43.95975971221924
# ffmpeg -i 0457ExFo_IndPR_LQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0457ExFo_IndPR_LQ_C4.ogv
#
# 0
# 51.372304916381836
# ffmpeg -i 0458ExFo_IndPR_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0458ExFo_IndPR_HQ_C1.ogv
#
# 0
# 46.73217988014221
# ffmpeg -i 0461ExFo_IndPR_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0461ExFo_IndPR_HQ_C4.ogv
#
# 0
# 52.378379583358765
# ffmpeg -i 0462ExFo_IndPR_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0462ExFo_IndPR_MQ_C1.ogv
# 0
# 60.74199056625366
# ffmpeg -i 0465ExFo_IndPR_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0465ExFo_IndPR_MQ_C4.ogv
#
# 0
# 51.46193480491638
# ffmpeg -i 0466ExFo_IndPR_LQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0466ExFo_IndPR_LQ_C1.ogv
#
# 0
# 56.176204681396484
# ffmpeg -i 0473Exp_IndPO_HQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0473Exp_IndPO_HQ_C1.ogv
#
# 0
# 61.74569487571716
# ffmpeg -i 0474Exp_IndPO_HQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0474Exp_IndPO_HQ_C2.ogv
#
# 0
# 64.98010587692261
# ffmpeg -i 0476Exp_IndPO_HQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0476Exp_IndPO_HQ_C4.ogv
#
# 0
# 66.79202008247375
# ffmpeg -i 0477Exp_IndPO_MQ_C1.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0477Exp_IndPO_MQ_C1.ogv
#
# 0
# 56.465405225753784
# ffmpeg -i 0478Exp_IndPO_MQ_C2.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0478Exp_IndPO_MQ_C2.ogv
#
# 0
# 55.46834993362427
# ffmpeg -i 0480Exp_IndPO_MQ_C4.mp4 -c:v libtheora -q:v 10 -c:a libvorbis -q:a 10 /home/r/Dropbox/Javeriana/datasets/AD-VSD/surveillanceVideosDataset/surveillanceVideos_ogv/0480Exp_IndPO_MQ_C4.ogv
#
# 0
# 57.710904121398926
# 1623113751.7988892
